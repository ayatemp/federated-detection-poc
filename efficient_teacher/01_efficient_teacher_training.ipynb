# %% [markdown]
# # 01 EfficientTeacher Single-Client Training
#
# This notebook runs the EfficientTeacher baseline under the same practical conditions as the guarded DQA run: YOLOv5L, BDD100K paper20k, one pseudo-label client epoch per round, and one labeled server-GT epoch after every round. The only intentional change is `NUM_CLIENTS = 1`.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
from __future__ import annotations

import json
import subprocess
import sys
from datetime import datetime, timezone
from pathlib import Path
from typing import Optional

import pandas as pd


def find_repo_root(start: Optional[Path] = None) -> Path:
    start = Path.cwd().resolve() if start is None else Path(start).resolve()
    required = (
        "efficient_teacher/run_efficient_teacher_single_client.py",
        "navigating_data_heterogeneity/setup_fedsto_exact_reproduction.py",
        "navigating_data_heterogeneity/vendor/efficientteacher/train.py",
    )
    candidates = []
    for base in (start, *start.parents):
        candidates.extend([base, base / "Object_Detection"])
    for candidate in candidates:
        if all((candidate / marker).exists() for marker in required):
            return candidate.resolve()
    raise FileNotFoundError("Could not locate the Object_Detection repository root.")


REPO_ROOT = find_repo_root()
ET_ROOT = REPO_ROOT / "efficient_teacher"
DQA_ROOT = REPO_ROOT / "dynamic_quality_aware_classwise_aggregation"
RUN_SCRIPT = ET_ROOT / "run_efficient_teacher_single_client.py"
WORK_ROOT = ET_ROOT / "efficientteacher_single_client"
PSEUDO_STATS_ROOT = WORK_ROOT / "pseudo_stats"
DQA_WARMUP_CHECKPOINT = (
    DQA_ROOT
    / "efficientteacher_dqa_cwa_corrected_12h"
    / "global_checkpoints"
    / "round000_warmup.pt"
)
PYTHON_BIN = Path(sys.executable)
TRAIN_LOG = WORK_ROOT / "efficientteacher_latest.log"

pd.options.display.max_columns = 200
print("repo:", REPO_ROOT)
print("workspace:", WORK_ROOT)
# Out:
# repo: /app/Object_Detection
# workspace: /app/Object_Detection/efficient_teacher/efficientteacher_single_client

# %% [markdown]
# ## 1. One-Hour Pilot Configuration
#
# The defaults target roughly one hour on 2 GPUs while keeping the rest of the DQA conditions aligned. Switch `SCHEDULE_PRESET` to `dqa_matched_full` if you want the original `14 + 27` round schedule.

# %%
CLIENT_ID = 0
CLIENT_WEATHER = None
SCHEDULE_PRESET = "one_hour_pilot"
if SCHEDULE_PRESET == "one_hour_pilot":
    WARMUP_EPOCHS = 15
    PHASE1_ROUNDS = 4
    PHASE2_ROUNDS = 7
elif SCHEDULE_PRESET == "dqa_matched_full":
    WARMUP_EPOCHS = 15
    PHASE1_ROUNDS = 14
    PHASE2_ROUNDS = 27
else:
    raise ValueError(f"Unknown SCHEDULE_PRESET: {SCHEDULE_PRESET}")
BATCH_SIZE = 64
WORKERS = 0
REQUESTED_GPUS = 2
MASTER_PORT = 29520
MIN_FREE_GIB = 70
LOCAL_EMA = False
USE_DQA_WARMUP_CHECKPOINT = True
WARMUP_CHECKPOINT = DQA_WARMUP_CHECKPOINT if USE_DQA_WARMUP_CHECKPOINT else None
APPEND_TRAIN_LOG = False
EXTRA_RUN_ARGS = []

try:
    import torch

    AVAILABLE_CUDA_GPUS = torch.cuda.device_count()
except Exception as exc:
    AVAILABLE_CUDA_GPUS = 0
    print("Could not inspect CUDA devices:", exc)

GPUS = min(REQUESTED_GPUS, AVAILABLE_CUDA_GPUS) if AVAILABLE_CUDA_GPUS else 1
if GPUS != REQUESTED_GPUS:
    print(f"Requested {REQUESTED_GPUS} GPU(s), but {AVAILABLE_CUDA_GPUS} visible; using {GPUS}.")

config_summary = {
    "client_id": CLIENT_ID,
    "client_weather": CLIENT_WEATHER or "from manifest",
    "schedule_preset": SCHEDULE_PRESET,
    "warmup_epochs": WARMUP_EPOCHS,
    "phase1_rounds": PHASE1_ROUNDS,
    "phase2_rounds": PHASE2_ROUNDS,
    "phase1_train_scope": "backbone",
    "phase2_train_scope": "all",
    "phase2_orthogonal_weight": 1e-4,
    "batch_size": BATCH_SIZE,
    "workers": WORKERS,
    "gpus": GPUS,
    "local_ema": LOCAL_EMA,
    "warmup_checkpoint": str(WARMUP_CHECKPOINT) if WARMUP_CHECKPOINT else None,
    "workspace": str(WORK_ROOT),
}
config_summary
# Out:
# {'client_id': 0,
#  'client_weather': 'from manifest',
#  'schedule_preset': 'one_hour_pilot',
#  'warmup_epochs': 15,
#  'phase1_rounds': 4,
#  'phase2_rounds': 7,
#  'phase1_train_scope': 'backbone',
#  'phase2_train_scope': 'all',
#  'phase2_orthogonal_weight': 0.0001,
#  'batch_size': 64,
#  'workers': 0,
#  'gpus': 2,
#  'local_ema': False,
#  'warmup_checkpoint': '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/efficientteacher_dqa_cwa_corrected_12h/global_checkpoints/round000_warmup.pt',
#  'workspace': '/app/Object_Detection/efficient_teacher/efficientteacher_single_client'}

# %% [markdown]
# ## 2. Build Data Lists and Configs
#
# This uses the same `setup_fedsto_exact_reproduction.py` path as DQA/FedSTO, but patches the client list down to one selected client inside the runner.

# %%
setup_cmd = [
    str(PYTHON_BIN),
    str(RUN_SCRIPT),
    "--setup-only",
    "--workspace-root",
    str(WORK_ROOT),
    "--pseudo-stats-root",
    str(PSEUDO_STATS_ROOT),
    "--client-id",
    str(CLIENT_ID),
]
if CLIENT_WEATHER:
    setup_cmd.extend(["--client-weather", CLIENT_WEATHER])

subprocess.run(setup_cmd, cwd=REPO_ROOT, check=True)

manifest_path = WORK_ROOT / "manifest.json"
manifest = json.loads(manifest_path.read_text(encoding="utf-8"))
manifest_summary = {
    "classes": manifest["classes"],
    "server_train_images": manifest["server"]["train_images"],
    "server_val_images": manifest["server"]["val_images"],
    "clients": manifest["clients"],
    "paper_schedule": manifest["paper_schedule"],
}
manifest_summary
# Out:
# {
#   "manifest": {
#     "paper": "Navigating Data Heterogeneity in Federated Learning: A Semi-Supervised Federated Object Detection",
#     "official_ssfod_repo": "https://github.com/Kthyeon/ssfod",
#     "official_ssfod_sha": "9611977db135bfc2947555bb3c3de452ec730343",
#     "efficientteacher_repo": "https://github.com/AlibabaResearch/efficientteacher",
#     "efficientteacher_sha": "9611977db135bfc2947555bb3c3de452ec730343",
#     "server": {
#       "weather": "cloudy represented by BDD100K Kaggle weather='partly cloudy'",
#       "train_list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/server_cloudy_train.txt",
#       "val_list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/server_cloudy_val.txt",
#       "train_images": 4881,
#       "val_images": 738
#     },
#     "clients": [
#       {
#         "id": 0,
#         "weather": "overcast",
#         "list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/client_0_overcast_target.txt",
#         "images": 5000
#       }
#     ],
#     "paper_evaluation": {
#       "splits": [
#         {
#           "name": "cloudy",
#           "raw_weather": "partly cloudy",
#           "list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/paper_eval_cloudy_val.txt",
#           "images": 738,
#           "boxes": 14937,
#           "class_counts": {
#             "car": 8622,
#             "person": 1052,
#             "traffic light": 1619,
#             "traffic sign": 2845,
#             "truck": 467,
#             "bus": 151,
#             "motor": 65,
#             "bike": 70,
#             "rider": 44,
#             "train": 2
#           }
#         },
#         {
#           "name": "overcast",
#           "raw_weather": "overcast",
#           "list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/paper_eval_overcast_val.txt",
#           "images": 1239,
#           "boxes": 25686,
#           "class_counts": {
#             "traffic sign": 4809,
#             "traffic light": 3179,
#             "car": 14504,
#             "rider": 106,
#             "motor": 71,
#             "truck": 657,
#             "person": 1935,
#             "bus": 278,
#             "bike": 145,
#             "train": 2
#           }
#         },
#         {
#           "name": "rainy",
#           "raw_weather": "rainy",
#           "list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/paper_eval_rainy_val.txt",
#           "images": 738,
#           "boxes": 13160,
#           "class_counts": {
#             "car": 6937,
#             "traffic sign": 2529,
#             "truck": 358,
#             "bus": 129,
#             "traffic light": 2237,
#             "person": 835,
#             "rider": 44,
#             "bike": 59,
#             "motor": 31,
#             "train": 1
#           }
#         },
#         {
#           "name": "snowy",
#           "raw_weather": "snowy",
#           "list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/paper_eval_snowy_val.txt",
#           "images": 769,
#           "boxes": 14321,
#           "class_counts": {
#             "car": 7536,
#             "truck": 351,
#             "traffic sign": 2697,
#             "traffic light": 2304,
#             "person": 1157,
#             "bike": 89,
#             "rider": 38,
#             "bus": 135,
#             "train": 5,
#             "motor": 9
#           }
#         }
#       ],
#       "total": {
#         "name": "total",
#         "list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/paper_eval_total_val.txt",
#         "images": 3484,
#         "source_splits": [
#           "cloudy",
#           "overcast",
#           "rainy",
#           "snowy"
#         ]
#       }
#     },
#     "classes": [
#       "person",
#       "rider",
#       "car",
#       "bus",
#       "truck",
#       "bike",
#       "motor",
#       "traffic light",
#       "traffic sign",
#       "train"
#     ],
#     "paper_schedule": {
#       "warmup_epochs": 50,
#       "phase1_rounds": 100,
#       "phase2_rounds": 150,
#       "local_epochs": 1
#     }
#   },
#   "configs": {
#     "server_warmup": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/server_warmup_yolov5l_bdd100k.yaml",
#     "client_0_phase1": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/client_0_overcast_phase1.yaml",
#     "client_0_phase2": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/client_0_overcast_phase2.yaml",
#     "server_phase1": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/server_phase1_backbone.yaml",
#     "server_phase2": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/server_phase2_orthogonal.yaml"
#   }
# }
# {'classes': ['person',
#   'rider',
#   'car',
#   'bus',
#   'truck',
#   'bike',
#   'motor',
#   'traffic light',
#   'traffic sign',
#   'train'],
#  'server_train_images': 4881,
#  'server_val_images': 738,
#  'clients': [{'id': 0,
#    'weather': 'overcast',
#    'list': '/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/client_0_overcast_target.txt',
#    'images': 5000}],
#  'paper_schedule': {'warmup_epochs': 50,
#   'phase1_rounds': 100,
#   'phase2_rounds': 150,
#   'local_epochs': 1}}

# %% [markdown]
# ## 3. Dependency and Dry-Run Check
#
# The dry run generates runtime commands and YAMLs without launching training.

# %%
import importlib.util

required = {
    "yaml": "PyYAML",
    "cv2": "opencv-python",
    "thop": "thop",
    "tensorboard": "tensorboard",
    "sklearn": "scikit-learn",
    "pandas": "pandas",
}
missing = [package for module, package in required.items() if importlib.util.find_spec(module) is None]
if missing:
    raise ModuleNotFoundError("Missing runtime dependencies: " + ", ".join(missing))

dry_run_cmd = [
    str(PYTHON_BIN),
    str(RUN_SCRIPT),
    "--dry-run",
    "--workspace-root",
    str(WORK_ROOT),
    "--pseudo-stats-root",
    str(PSEUDO_STATS_ROOT),
    "--client-id",
    str(CLIENT_ID),
    "--warmup-epochs",
    str(WARMUP_EPOCHS),
    "--phase1-rounds",
    str(PHASE1_ROUNDS),
    "--phase2-rounds",
    str(PHASE2_ROUNDS),
    "--batch-size",
    str(BATCH_SIZE),
    "--workers",
    str(WORKERS),
    "--gpus",
    str(GPUS),
    "--master-port",
    str(MASTER_PORT),
    "--min-free-gib",
    str(MIN_FREE_GIB),
]
if CLIENT_WEATHER:
    dry_run_cmd.extend(["--client-weather", CLIENT_WEATHER])
dry_run_cmd.append("--local-ema" if LOCAL_EMA else "--no-local-ema")
if WARMUP_CHECKPOINT is not None:
    dry_run_cmd.extend(["--warmup-checkpoint", str(WARMUP_CHECKPOINT)])

subprocess.run(dry_run_cmd, cwd=REPO_ROOT, check=True)
# Out:
# {
#   "manifest": {
#     "paper": "Navigating Data Heterogeneity in Federated Learning: A Semi-Supervised Federated Object Detection",
#     "official_ssfod_repo": "https://github.com/Kthyeon/ssfod",
#     "official_ssfod_sha": "9611977db135bfc2947555bb3c3de452ec730343",
#     "efficientteacher_repo": "https://github.com/AlibabaResearch/efficientteacher",
#     "efficientteacher_sha": "9611977db135bfc2947555bb3c3de452ec730343",
#     "server": {
#       "weather": "cloudy represented by BDD100K Kaggle weather='partly cloudy'",
#       "train_list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/server_cloudy_train.txt",
#       "val_list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/server_cloudy_val.txt",
#       "train_images": 4881,
#       "val_images": 738
#     },
#     "clients": [
#       {
#         "id": 0,
#         "weather": "overcast",
#         "list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/client_0_overcast_target.txt",
#         "images": 5000
#       }
#     ],
#     "paper_evaluation": {
#       "splits": [
#         {
#           "name": "cloudy",
#           "raw_weather": "partly cloudy",
#           "list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/paper_eval_cloudy_val.txt",
#           "images": 738,
#           "boxes": 14937,
#           "class_counts": {
#             "car": 8622,
#             "person": 1052,
#             "traffic light": 1619,
#             "traffic sign": 2845,
#             "truck": 467,
#             "bus": 151,
#             "motor": 65,
#             "bike": 70,
#             "rider": 44,
#             "train": 2
#           }
#         },
#         {
#           "name": "overcast",
#           "raw_weather": "overcast",
#           "list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/paper_eval_overcast_val.txt",
#           "images": 1239,
#           "boxes": 25686,
#           "class_counts": {
#             "traffic sign": 4809,
#             "traffic light": 3179,
#             "car": 14504,
#             "rider": 106,
#             "motor": 71,
#             "truck": 657,
#             "person": 1935,
#             "bus": 278,
#             "bike": 145,
#             "train": 2
#           }
#         },
#         {
#           "name": "rainy",
#           "raw_weather": "rainy",
#           "list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/paper_eval_rainy_val.txt",
#           "images": 738,
#           "boxes": 13160,
#           "class_counts": {
#             "car": 6937,
#             "traffic sign": 2529,
#             "truck": 358,
#             "bus": 129,
#             "traffic light": 2237,
#             "person": 835,
#             "rider": 44,
#             "bike": 59,
#             "motor": 31,
#             "train": 1
#           }
#         },
#         {
#           "name": "snowy",
#           "raw_weather": "snowy",
#           "list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/paper_eval_snowy_val.txt",
#           "images": 769,
#           "boxes": 14321,
#           "class_counts": {
#             "car": 7536,
#             "truck": 351,
#             "traffic sign": 2697,
#             "traffic light": 2304,
#             "person": 1157,
#             "bike": 89,
#             "rider": 38,
#             "bus": 135,
#             "train": 5,
#             "motor": 9
#           }
#         }
#       ],
#       "total": {
#         "name": "total",
#         "list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/paper_eval_total_val.txt",
#         "images": 3484,
#         "source_splits": [
#           "cloudy",
#           "overcast",
#           "rainy",
#           "snowy"
#         ]
#       }
#     },
#     "classes": [
#       "person",
#       "rider",
#       "car",
#       "bus",
#       "truck",
#       "bike",
#       "motor",
#       "traffic light",
#       "traffic sign",
#       "train"
#     ],
#     "paper_schedule": {
#       "warmup_epochs": 50,
#       "phase1_rounds": 100,
#       "phase2_rounds": 150,
#       "local_epochs": 1
#     }
#   },
#   "configs": {
#     "server_warmup": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/server_warmup_yolov5l_bdd100k.yaml",
#     "client_0_phase1": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/client_0_overcast_phase1.yaml",
#     "client_0_phase2": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/client_0_overcast_phase2.yaml",
#     "server_phase1": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/server_phase1_backbone.yaml",
#     "server_phase2": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/server_phase2_orthogonal.yaml"
#   }
# }
# Running EfficientTeacher single-client protocol with client_0_overcast.
# Dry run: would seed warm-up from /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/efficientteacher_dqa_cwa_corrected_12h/global_checkpoints/round000_warmup.pt
# /root/micromamba/envs/al_yolov8/bin/python -m torch.distributed.run --nproc_per_node 2 --master_port 29520 train.py --cfg /app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/runtime_server_warmup.yaml
# Dry run complete. EfficientTeacher single-client workspace: /app/Object_Detection/efficient_teacher/efficientteacher_single_client
# Selected client: client_0_overcast
# CompletedProcess(args=['/root/micromamba/envs/al_yolov8/bin/python', '/app/Object_Detection/efficient_teacher/run_efficient_teacher_single_client.py', '--dry-run', '--workspace-root', '/app/Object_Detection/efficient_teacher/efficientteacher_single_client', '--pseudo-stats-root', '/app/Object_Detection/efficient_teacher/efficientteacher_single_client/pseudo_stats', '--client-id', '0', '--warmup-epochs', '15', '--phase1-rounds', '4', '--phase2-rounds', '7', '--batch-size', '64', '--workers', '0', '--gpus', '2', '--master-port', '29520', '--min-free-gib', '70', '--no-local-ema', '--warmup-checkpoint', '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/efficientteacher_dqa_cwa_corrected_12h/global_checkpoints/round000_warmup.pt'], returncode=0)

# %% [markdown]
# ## 4. Start or Resume Training
#
# This cell is restartable. The runner reuses valid checkpoints, appends compact status to notebook output, and writes full EfficientTeacher logs to `efficientteacher_latest.log`.
#
# When `WARMUP_CHECKPOINT` points at the DQA warm-up checkpoint, the run skips raw-pretrained warm-up training and seeds `round000_warmup.pt` from that DQA artifact instead. The runner also skips EfficientTeacher's redundant final `best.pt` validation pass by default, which avoids the Ada multi-GPU fuse crash seen in this workspace.
#
# Phase 2 uses `train_scope="all"` with the DQA/FedSTO-matched `orthogonal_weight=1e-4`; older phase-2 checkpoints without that setting are ignored by the updated runner, while the warm-up checkpoint remains reused.

# %%
RUN_FULL_REPRODUCTION = True
ALLOW_CPU_TRAINING = False
FORCE_RESTART = False
FORCE_WARMUP = False
FORCE_RETRAIN = False

train_cmd = [
    str(PYTHON_BIN),
    "-u",
    str(RUN_SCRIPT),
    "--workspace-root",
    str(WORK_ROOT),
    "--pseudo-stats-root",
    str(PSEUDO_STATS_ROOT),
    "--client-id",
    str(CLIENT_ID),
    "--warmup-epochs",
    str(WARMUP_EPOCHS),
    "--phase1-rounds",
    str(PHASE1_ROUNDS),
    "--phase2-rounds",
    str(PHASE2_ROUNDS),
    "--batch-size",
    str(BATCH_SIZE),
    "--workers",
    str(WORKERS),
    "--gpus",
    str(GPUS),
    "--master-port",
    str(MASTER_PORT),
    "--min-free-gib",
    str(MIN_FREE_GIB),
]
if CLIENT_WEATHER:
    train_cmd.extend(["--client-weather", CLIENT_WEATHER])
train_cmd.append("--local-ema" if LOCAL_EMA else "--no-local-ema")
if WARMUP_CHECKPOINT is not None:
    train_cmd.extend(["--warmup-checkpoint", str(WARMUP_CHECKPOINT)])
if APPEND_TRAIN_LOG:
    train_cmd.append("--append-train-log")
if FORCE_RESTART:
    train_cmd.append("--force-restart")
if FORCE_WARMUP:
    train_cmd.append("--force-warmup")
if FORCE_RETRAIN:
    train_cmd.append("--force-retrain")
train_cmd.extend(EXTRA_RUN_ARGS)

if RUN_FULL_REPRODUCTION and AVAILABLE_CUDA_GPUS < 1 and not ALLOW_CPU_TRAINING:
    print("No CUDA GPU is visible, so the run was not started.")
elif RUN_FULL_REPRODUCTION:
    print("starting:", " ".join(train_cmd))
    subprocess.run(train_cmd, cwd=REPO_ROOT, check=True)
else:
    print("Set RUN_FULL_REPRODUCTION = True to launch or resume training.")

print("train log:", TRAIN_LOG)
# Out:
# starting: /root/micromamba/envs/al_yolov8/bin/python -u /app/Object_Detection/efficient_teacher/run_efficient_teacher_single_client.py --workspace-root /app/Object_Detection/efficient_teacher/efficientteacher_single_client --pseudo-stats-root /app/Object_Detection/efficient_teacher/efficientteacher_single_client/pseudo_stats --client-id 0 --warmup-epochs 15 --phase1-rounds 4 --phase2-rounds 7 --batch-size 64 --workers 0 --gpus 2 --master-port 29520 --min-free-gib 70 --no-local-ema --warmup-checkpoint /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/efficientteacher_dqa_cwa_corrected_12h/global_checkpoints/round000_warmup.pt
# {
#   "manifest": {
#     "paper": "Navigating Data Heterogeneity in Federated Learning: A Semi-Supervised Federated Object Detection",
#     "official_ssfod_repo": "https://github.com/Kthyeon/ssfod",
#     "official_ssfod_sha": "9611977db135bfc2947555bb3c3de452ec730343",
#     "efficientteacher_repo": "https://github.com/AlibabaResearch/efficientteacher",
#     "efficientteacher_sha": "9611977db135bfc2947555bb3c3de452ec730343",
#     "server": {
#       "weather": "cloudy represented by BDD100K Kaggle weather='partly cloudy'",
#       "train_list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/server_cloudy_train.txt",
#       "val_list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/server_cloudy_val.txt",
#       "train_images": 4881,
#       "val_images": 738
#     },
#     "clients": [
#       {
#         "id": 0,
#         "weather": "overcast",
#         "list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/client_0_overcast_target.txt",
#         "images": 5000
#       }
#     ],
#     "paper_evaluation": {
#       "splits": [
#         {
#           "name": "cloudy",
#           "raw_weather": "partly cloudy",
#           "list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/paper_eval_cloudy_val.txt",
#           "images": 738,
#           "boxes": 14937,
#           "class_counts": {
#             "car": 8622,
#             "person": 1052,
#             "traffic light": 1619,
#             "traffic sign": 2845,
#             "truck": 467,
#             "bus": 151,
#             "motor": 65,
#             "bike": 70,
#             "rider": 44,
#             "train": 2
#           }
#         },
#         {
#           "name": "overcast",
#           "raw_weather": "overcast",
#           "list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/paper_eval_overcast_val.txt",
#           "images": 1239,
#           "boxes": 25686,
#           "class_counts": {
#             "traffic sign": 4809,
#             "traffic light": 3179,
#             "car": 14504,
#             "rider": 106,
#             "motor": 71,
#             "truck": 657,
#             "person": 1935,
#             "bus": 278,
#             "bike": 145,
#             "train": 2
#           }
#         },
#         {
#           "name": "rainy",
#           "raw_weather": "rainy",
#           "list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/paper_eval_rainy_val.txt",
#           "images": 738,
#           "boxes": 13160,
#           "class_counts": {
#             "car": 6937,
#             "traffic sign": 2529,
#             "truck": 358,
#             "bus": 129,
#             "traffic light": 2237,
#             "person": 835,
#             "rider": 44,
#             "bike": 59,
#             "motor": 31,
#             "train": 1
#           }
#         },
#         {
#           "name": "snowy",
#           "raw_weather": "snowy",
#           "list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/paper_eval_snowy_val.txt",
#           "images": 769,
#           "boxes": 14321,
#           "class_counts": {
#             "car": 7536,
#             "truck": 351,
#             "traffic sign": 2697,
#             "traffic light": 2304,
#             "person": 1157,
#             "bike": 89,
#             "rider": 38,
#             "bus": 135,
#             "train": 5,
#             "motor": 9
#           }
#         }
#       ],
#       "total": {
#         "name": "total",
#         "list": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/data_lists/paper_eval_total_val.txt",
#         "images": 3484,
#         "source_splits": [
#           "cloudy",
#           "overcast",
#           "rainy",
#           "snowy"
#         ]
#       }
#     },
#     "classes": [
#       "person",
#       "rider",
#       "car",
#       "bus",
#       "truck",
#       "bike",
#       "motor",
#       "traffic light",
#       "traffic sign",
#       "train"
#     ],
#     "paper_schedule": {
#       "warmup_epochs": 50,
#       "phase1_rounds": 100,
#       "phase2_rounds": 150,
#       "local_epochs": 1
#     }
#   },
#   "configs": {
#     "server_warmup": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/server_warmup_yolov5l_bdd100k.yaml",
#     "client_0_phase1": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/client_0_overcast_phase1.yaml",
#     "client_0_phase2": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/client_0_overcast_phase2.yaml",
#     "server_phase1": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/server_phase1_backbone.yaml",
#     "server_phase2": "/app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/server_phase2_orthogonal.yaml"
#   }
# }
# Running EfficientTeacher single-client protocol with client_0_overcast.
# Seeding warm-up from external checkpoint: /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/efficientteacher_dqa_cwa_corrected_12h/global_checkpoints/round000_warmup.pt
# Reusing completed warm-up checkpoint: /app/Object_Detection/efficient_teacher/efficientteacher_single_client/global_checkpoints/round000_warmup.pt
# Resuming EfficientTeacher single-client after 5 completed rounds from phase 2 round 2.
# Current global checkpoint: /app/Object_Detection/efficient_teacher/efficientteacher_single_client/global_checkpoints/phase2_round001_global.pt
# /root/micromamba/envs/al_yolov8/bin/python -m torch.distributed.run --nproc_per_node 2 --master_port 29520 train.py --cfg /app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/runtime_phase2_client_round2_et_phase2_round002_client0_overcast.yaml
# Training output appended to /app/Object_Detection/efficient_teacher/efficientteacher_single_client/efficientteacher_latest.log
# /root/micromamba/envs/al_yolov8/bin/python -m torch.distributed.run --nproc_per_node 2 --master_port 29520 train.py --cfg /app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/runtime_phase2_server_round2_et_phase2_round002_server.yaml
# Training output appended to /app/Object_Detection/efficient_teacher/efficientteacher_single_client/efficientteacher_latest.log
# Completed EfficientTeacher phase 2 round 2: /app/Object_Detection/efficient_teacher/efficientteacher_single_client/global_checkpoints/phase2_round002_global.pt
# /root/micromamba/envs/al_yolov8/bin/python -m torch.distributed.run --nproc_per_node 2 --master_port 29520 train.py --cfg /app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/runtime_phase2_client_round3_et_phase2_round003_client0_overcast.yaml
# Training output appended to /app/Object_Detection/efficient_teacher/efficientteacher_single_client/efficientteacher_latest.log
# /root/micromamba/envs/al_yolov8/bin/python -m torch.distributed.run --nproc_per_node 2 --master_port 29520 train.py --cfg /app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/runtime_phase2_server_round3_et_phase2_round003_server.yaml
# Training output appended to /app/Object_Detection/efficient_teacher/efficientteacher_single_client/efficientteacher_latest.log
# Completed EfficientTeacher phase 2 round 3: /app/Object_Detection/efficient_teacher/efficientteacher_single_client/global_checkpoints/phase2_round003_global.pt
# /root/micromamba/envs/al_yolov8/bin/python -m torch.distributed.run --nproc_per_node 2 --master_port 29520 train.py --cfg /app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/runtime_phase2_client_round4_et_phase2_round004_client0_overcast.yaml
# Training output appended to /app/Object_Detection/efficient_teacher/efficientteacher_single_client/efficientteacher_latest.log
# /root/micromamba/envs/al_yolov8/bin/python -m torch.distributed.run --nproc_per_node 2 --master_port 29520 train.py --cfg /app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/runtime_phase2_server_round4_et_phase2_round004_server.yaml
# Training output appended to /app/Object_Detection/efficient_teacher/efficientteacher_single_client/efficientteacher_latest.log
# Completed EfficientTeacher phase 2 round 4: /app/Object_Detection/efficient_teacher/efficientteacher_single_client/global_checkpoints/phase2_round004_global.pt
# /root/micromamba/envs/al_yolov8/bin/python -m torch.distributed.run --nproc_per_node 2 --master_port 29520 train.py --cfg /app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/runtime_phase2_client_round5_et_phase2_round005_client0_overcast.yaml
# Training output appended to /app/Object_Detection/efficient_teacher/efficientteacher_single_client/efficientteacher_latest.log
# /root/micromamba/envs/al_yolov8/bin/python -m torch.distributed.run --nproc_per_node 2 --master_port 29520 train.py --cfg /app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/runtime_phase2_server_round5_et_phase2_round005_server.yaml
# Training output appended to /app/Object_Detection/efficient_teacher/efficientteacher_single_client/efficientteacher_latest.log
# Completed EfficientTeacher phase 2 round 5: /app/Object_Detection/efficient_teacher/efficientteacher_single_client/global_checkpoints/phase2_round005_global.pt
# /root/micromamba/envs/al_yolov8/bin/python -m torch.distributed.run --nproc_per_node 2 --master_port 29520 train.py --cfg /app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/runtime_phase2_client_round6_et_phase2_round006_client0_overcast.yaml
# Training output appended to /app/Object_Detection/efficient_teacher/efficientteacher_single_client/efficientteacher_latest.log
# /root/micromamba/envs/al_yolov8/bin/python -m torch.distributed.run --nproc_per_node 2 --master_port 29520 train.py --cfg /app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/runtime_phase2_server_round6_et_phase2_round006_server.yaml
# Training output appended to /app/Object_Detection/efficient_teacher/efficientteacher_single_client/efficientteacher_latest.log
# Completed EfficientTeacher phase 2 round 6: /app/Object_Detection/efficient_teacher/efficientteacher_single_client/global_checkpoints/phase2_round006_global.pt
# /root/micromamba/envs/al_yolov8/bin/python -m torch.distributed.run --nproc_per_node 2 --master_port 29520 train.py --cfg /app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/runtime_phase2_client_round7_et_phase2_round007_client0_overcast.yaml
# Training output appended to /app/Object_Detection/efficient_teacher/efficientteacher_single_client/efficientteacher_latest.log
# /root/micromamba/envs/al_yolov8/bin/python -m torch.distributed.run --nproc_per_node 2 --master_port 29520 train.py --cfg /app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/runtime_phase2_server_round7_et_phase2_round007_server.yaml
# Training output appended to /app/Object_Detection/efficient_teacher/efficientteacher_single_client/efficientteacher_latest.log
# Completed EfficientTeacher phase 2 round 7: /app/Object_Detection/efficient_teacher/efficientteacher_single_client/global_checkpoints/phase2_round007_global.pt
# train log: /app/Object_Detection/efficient_teacher/efficientteacher_single_client/efficientteacher_latest.log

# %% [markdown]
# ## 5. Progress Snapshot

# %%
def modified_utc(path: Path) -> str:
    if not path.exists():
        return ""
    return datetime.fromtimestamp(path.stat().st_mtime, tz=timezone.utc).isoformat()


history_path = WORK_ROOT / "history.json"
history = json.loads(history_path.read_text(encoding="utf-8")) if history_path.exists() else []
completed_phase1 = sum(1 for entry in history if int(entry.get("phase", 0)) == 1)
completed_phase2 = sum(1 for entry in history if int(entry.get("phase", 0)) == 2)
display(
    pd.DataFrame(
        [
            {"phase": "phase1", "completed": completed_phase1, "target": PHASE1_ROUNDS},
            {"phase": "phase2", "completed": completed_phase2, "target": PHASE2_ROUNDS},
        ]
    )
)

artifacts = [
    WORK_ROOT / "manifest.json",
    WORK_ROOT / "history.json",
    WORK_ROOT / "global_checkpoints" / "round000_warmup.pt",
    WORK_ROOT / "global_checkpoints" / f"phase2_round{PHASE2_ROUNDS:03d}_global.pt",
    TRAIN_LOG,
    PSEUDO_STATS_ROOT,
]
display(
    pd.DataFrame(
        [
            {
                "path": str(path),
                "exists": path.exists(),
                "bytes": path.stat().st_size if path.exists() and path.is_file() else "",
                "modified_utc": modified_utc(path),
            }
            for path in artifacts
        ]
    )
)
display(pd.DataFrame(history).tail(10) if history else pd.DataFrame())
# Out:
#     phase  completed  target
# 0  phase1          4       4
# 1  phase2          7       7
#                                                 path  exists     bytes  \
# 0  /app/Object_Detection/efficient_teacher/effici...    True      3796
# 1  /app/Object_Detection/efficient_teacher/effici...    True      2794
# 2  /app/Object_Detection/efficient_teacher/effici...    True  93044157
# 3  /app/Object_Detection/efficient_teacher/effici...    True  93048418
# 4  /app/Object_Detection/efficient_teacher/effici...    True   1229122
# 5  /app/Object_Detection/efficient_teacher/effici...    True
#
#                        modified_utc
# 0  2026-04-27T08:52:40.762985+00:00
# 1  2026-04-27T09:29:42.429777+00:00
# 2  2026-04-27T08:52:43.001975+00:00
# 3  2026-04-27T09:29:42.428777+00:00
# 4  2026-04-27T09:29:41.921779+00:00
# 5  2026-04-27T09:26:56.674538+00:00
#     phase  round                                             global  \
# 1       1      2  /app/Object_Detection/efficient_teacher/effici...
# 2       1      3  /app/Object_Detection/efficient_teacher/effici...
# 3       1      4  /app/Object_Detection/efficient_teacher/effici...
# 4       2      1  /app/Object_Detection/efficient_teacher/effici...
# 5       2      2  /app/Object_Detection/efficient_teacher/effici...
# 6       2      3  /app/Object_Detection/efficient_teacher/effici...
# 7       2      4  /app/Object_Detection/efficient_teacher/effici...
# 8       2      5  /app/Object_Detection/efficient_teacher/effici...
# 9       2      6  /app/Object_Detection/efficient_teacher/effici...
# 10      2      7  /app/Object_Detection/efficient_teacher/effici...
#
#                                              protocol
# 1   efficientteacher_single_client_dqa_matched_no_...
# 2   efficientteacher_single_client_dqa_matched_no_...
# 3   efficientteacher_single_client_dqa_matched_no_...
# 4   efficientteacher_single_client_dqa_matched_pha...
# 5   efficientteacher_single_client_dqa_matched_pha...
# 6   efficientteacher_single_client_dqa_matched_pha...
# 7   efficientteacher_single_client_dqa_matched_pha...
# 8   efficientteacher_single_client_dqa_matched_pha...
# 9   efficientteacher_single_client_dqa_matched_pha...
# 10  efficientteacher_single_client_dqa_matched_pha...

# %% [markdown]
# ## 6. Recent Logs

# %%
def tail(path: Path, lines: int = 80) -> str:
    if not path.exists():
        return f"{path} does not exist yet."
    result = subprocess.run(["tail", "-n", str(lines), str(path)], capture_output=True, text=True)
    return result.stdout


print(tail(TRAIN_LOG, 80))
# Out:
#   with amp.autocast(enabled=self.cuda):
# /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
#
#        0/0     18.2G      1199       640   0.03759   0.03075  0.003604     2.302:  79%|███████▉  | 61/77 [01:35<00:15,  1.01it/s]
#        0/0     18.2G      1199       640   0.03759   0.03075  0.003604     2.302:  81%|████████  | 62/77 [01:35<00:15,  1.00s/it]/app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
# /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
#
#        0/0     18.2G      1134       640   0.03759   0.03072  0.003612     2.302:  81%|████████  | 62/77 [01:36<00:15,  1.00s/it]
#        0/0     18.2G      1134       640   0.03759   0.03072  0.003612     2.302:  82%|████████▏ | 63/77 [01:36<00:13,  1.01it/s]/app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
# /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
#
#        0/0     18.2G       967       640   0.03755   0.03064  0.003609     2.297:  82%|████████▏ | 63/77 [01:37<00:13,  1.01it/s]
#        0/0     18.2G       967       640   0.03755   0.03064  0.003609     2.297:  83%|████████▎ | 64/77 [01:37<00:13,  1.02s/it]/app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
# /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
#
#        0/0     18.2G      1154       640   0.03753   0.03065  0.003615     2.298:  83%|████████▎ | 64/77 [01:38<00:13,  1.02s/it]
#        0/0     18.2G      1154       640   0.03753   0.03065  0.003615     2.298:  84%|████████▍ | 65/77 [01:38<00:12,  1.01s/it]/app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
# /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
#
#        0/0     18.2G      1195       640   0.03748   0.03062   0.00361     2.295:  84%|████████▍ | 65/77 [01:39<00:12,  1.01s/it]
#        0/0     18.2G      1195       640   0.03748   0.03062   0.00361     2.295:  86%|████████▌ | 66/77 [01:39<00:10,  1.00it/s]/app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
# /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
#
#        0/0     18.2G      1176       640   0.03746   0.03066  0.003606     2.295:  86%|████████▌ | 66/77 [01:40<00:10,  1.00it/s]
#        0/0     18.2G      1176       640   0.03746   0.03066  0.003606     2.295:  87%|████████▋ | 67/77 [01:40<00:10,  1.00s/it]/app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
# /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
#
#        0/0     18.2G      1483       640   0.03746   0.03075  0.003611     2.298:  87%|████████▋ | 67/77 [01:41<00:10,  1.00s/it]
#        0/0     18.2G      1483       640   0.03746   0.03075  0.003611     2.298:  88%|████████▊ | 68/77 [01:41<00:09,  1.01s/it]/app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
# /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
#
#        0/0     18.2G      1247       640   0.03746   0.03074   0.00362     2.298:  88%|████████▊ | 68/77 [01:42<00:09,  1.01s/it]
#        0/0     18.2G      1247       640   0.03746   0.03074   0.00362     2.298:  90%|████████▉ | 69/77 [01:42<00:07,  1.00it/s]/app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
# /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
#
#        0/0     18.2G      1109       640   0.03744   0.03075  0.003612     2.297:  90%|████████▉ | 69/77 [01:43<00:07,  1.00it/s]
#        0/0     18.2G      1109       640   0.03744   0.03075  0.003612     2.297:  91%|█████████ | 70/77 [01:43<00:06,  1.02it/s]/app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
# /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
#
#        0/0     18.2G      1242       640   0.03739   0.03081  0.003617     2.298:  91%|█████████ | 70/77 [01:44<00:06,  1.02it/s]
#        0/0     18.2G      1242       640   0.03739   0.03081  0.003617     2.298:  92%|█████████▏| 71/77 [01:44<00:05,  1.02it/s]/app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
# /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
#
#        0/0     18.2G      1104       640   0.03738   0.03085  0.003624       2.3:  92%|█████████▏| 71/77 [01:45<00:05,  1.02it/s]
#        0/0     18.2G      1104       640   0.03738   0.03085  0.003624       2.3:  94%|█████████▎| 72/77 [01:45<00:04,  1.01it/s]/app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
# /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
#
#        0/0     18.2G      1060       640   0.03736   0.03088  0.003639       2.3:  94%|█████████▎| 72/77 [01:46<00:04,  1.01it/s]
#        0/0     18.2G      1060       640   0.03736   0.03088  0.003639       2.3:  95%|█████████▍| 73/77 [01:46<00:04,  1.00s/it]/app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
# /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
#
#        0/0     18.2G      1151       640   0.03736   0.03092  0.003634     2.301:  95%|█████████▍| 73/77 [01:47<00:04,  1.00s/it]
#        0/0     18.2G      1151       640   0.03736   0.03092  0.003634     2.301:  96%|█████████▌| 74/77 [01:47<00:03,  1.02s/it]/app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
# /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
#
#        0/0     18.2G      1213       640   0.03738   0.03105  0.003637     2.306:  96%|█████████▌| 74/77 [01:48<00:03,  1.02s/it]
#        0/0     18.2G      1213       640   0.03738   0.03105  0.003637     2.306:  97%|█████████▋| 75/77 [01:48<00:02,  1.03s/it]/app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
# /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
#
#        0/0     2.11G       411       640   0.03737   0.03132  0.003639     2.287:  97%|█████████▋| 75/77 [02:20<00:02,  1.03s/it]
#        0/0     2.11G       411       640   0.03737   0.03132  0.003639     2.287:  99%|█████████▊| 76/77 [02:20<00:10, 10.26s/it]/app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
# /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/trainer/trainer.py:439: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.cuda):
#
#        0/0     18.5G      1130       640   0.03741   0.03148  0.003661     2.294:  99%|█████████▊| 76/77 [02:21<00:10, 10.26s/it]
#        0/0     18.5G      1130       640   0.03741   0.03148  0.003661     2.294: 100%|██████████| 77/77 [02:21<00:00,  7.55s/it]
#        0/0     18.5G      1130       640   0.03741   0.03148  0.003661     2.294: 100%|██████████| 77/77 [02:21<00:00,  1.84s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/12 [00:00<?, ?it/s]/root/micromamba/envs/al_yolov8/lib/python3.10/site-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4381.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   8%|▊         | 1/12 [00:01<00:15,  1.44s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  17%|█▋        | 2/12 [00:01<00:08,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  25%|██▌       | 3/12 [00:02<00:06,  1.47it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  33%|███▎      | 4/12 [00:02<00:04,  1.76it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  42%|████▏     | 5/12 [00:03<00:03,  1.98it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|█████     | 6/12 [00:03<00:02,  2.15it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  58%|█████▊    | 7/12 [00:03<00:02,  2.28it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  67%|██████▋   | 8/12 [00:04<00:01,  2.36it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  75%|███████▌  | 9/12 [00:04<00:01,  2.43it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  83%|████████▎ | 10/12 [00:05<00:00,  2.45it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  92%|█████████▏| 11/12 [00:05<00:00,  2.48it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 12/12 [00:06<00:00,  2.17it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 12/12 [00:06<00:00,  1.97it/s]
#                  all        738      14937      0.605      0.395        0.4      0.218
# Optimizer stripped from /app/Object_Detection/efficient_teacher/efficientteacher_single_client/runs/et_phase2_round007_server/weights/last.pt, 93.0MB
# Optimizer stripped from /app/Object_Detection/efficient_teacher/efficientteacher_single_client/runs/et_phase2_round007_server/weights/best.pt, 93.0MB
#
# Skipping final best-checkpoint validation for /app/Object_Detection/efficient_teacher/efficientteacher_single_client/runs/et_phase2_round007_server/weights/best.pt because ET_SKIP_AFTER_TRAIN_BEST_VAL is enabled.
# Results saved to /app/Object_Detection/efficient_teacher/efficientteacher_single_client/runs/et_phase2_round007_server
#
# 1 epochs completed in 0.042 hours.
# Destroying process group...
# [rank0]:[W427 09:29:39.200651097 ProcessGroupNCCL.cpp:1553] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())
#
# ====================================================================================================
# /root/micromamba/envs/al_yolov8/bin/python -m torch.distributed.run --nproc_per_node 2 --master_port 29520 train.py --cfg /app/Object_Detection/efficient_teacher/efficientteacher_single_client/configs/runtime_phase2_server_round7_et_phase2_round007_server.yaml
