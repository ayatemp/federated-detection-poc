# %% [markdown]
# # 01 Aggressive DQA-MoX Until Target
#
# Goal: run aggressive DQA-MoX trials from warmup through client adaptation and server repair, stopping when total mAP50 reaches 0.60 or when the current trial budget is exhausted.
#
# This notebook intentionally does not mix old outputs into the working area.  New artifacts are written under `../output/24_aggressive_until_target`, and compact summaries are written under `../reports`.
#
# Design shift from the defensive runs:
# - lower server anchor and lower minimum server alpha,
# - higher pseudoGT repeat ratio,
# - looser pseudoGT admission after the first client-dominant phase,
# - one or more attack-style schedules that let client domains move the DQA-MoX detector more strongly,
# - still evaluate with the paper-style scene/client protocol.

# %%
from pathlib import Path
import os
import sys

NOTEBOOK = Path.cwd()
REPO_ROOT = NOTEBOOK
while REPO_ROOT.name != 'Object_Detection' and REPO_ROOT.parent != REPO_ROOT:
    REPO_ROOT = REPO_ROOT.parent
os.chdir(REPO_ROOT)
sys.path.insert(0, str(REPO_ROOT))
print('repo_root =', REPO_ROOT)

# %%
# !python dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/scripts/run_aggressive_dqamox_until_target.py --max-trials 0 --target-map50 0.60

# %%
import pandas as pd
summary = Path('dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/reports/24_aggressive_until_target_summary.csv')
if summary.exists():
    display(pd.read_csv(summary))
else:
    print('No summary yet:', summary)
