# %% [markdown]
# # 27u COCO Bridge MoE
#
# 27t showed that routing among existing DQA experts is saturated. This notebook tests a more external MoE expert: remap the COCO-pretrained Efficient-YOLOv5l initialization to BDD10 and fuse it with the best routed DQA-MoE at low score.

# %%
from pathlib import Path
import subprocess

repo = Path('/app/Object_Detection')
script = repo / 'dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/scripts/build_eval_27u_coco_bridge_moe.py'
workspace = repo / 'dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27u_coco_bridge_moe_r1'
cmd = [
    '/root/micromamba/envs/al_yolov8/bin/python',
    str(script),
    '--workspace', str(workspace),
    '--target-map50', '0.60',
    '--previous-best-map50', '0.52939',
    '--gate-images', '1200',
    '--min-gate-gain', '0.010',
]
print(' '.join(cmd))
result = subprocess.run(cmd, cwd=repo)
print('returncode:', result.returncode)
# Out:
# /root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/scripts/build_eval_27u_coco_bridge_moe.py --workspace /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27u_coco_bridge_moe_r1 --target-map50 0.60 --previous-best-map50 0.52939 --gate-images 1200 --min-gate-gain 0.010
# EfficientTeacher  618670a torch 2.8.0+cu128 CUDA:0 (NVIDIA RTX 6000 Ada Generation, 48508.9375MB)
#
# 27u: Scanning '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27u_coco_bridge_moe_r1/data_lists/paper_eval_scene_daynight_total_val' images and labels...2114 found, 0 missing, 0 empty, 0 corrupted:  23%|██▎       | 2114/9087 [00:00<00:00, 20540.74it/s]
# ...
