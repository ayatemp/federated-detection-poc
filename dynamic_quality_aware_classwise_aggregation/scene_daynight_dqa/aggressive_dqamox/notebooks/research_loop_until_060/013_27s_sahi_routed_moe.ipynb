# %% [markdown]
# # 27s SAHI Routed MoE
#
# 27p/27q showed that resolution was the strongest lever. This notebook tests SAHI-style tiled inference around the current best routed MoE, using a gate subset before a full total-split run.

# %%
from pathlib import Path
import subprocess
import sys

repo = Path('/app/Object_Detection')
script = repo / 'dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/scripts/build_eval_27s_sahi_routed_moe.py'
workspace = repo / 'dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27s_sahi_routed_moe_r1'
cmd = [
    '/root/micromamba/envs/al_yolov8/bin/python',
    str(script),
    '--workspace', str(workspace),
    '--target-map50', '0.60',
    '--previous-best-map50', '0.523',
    '--gate-images', '1200',
    '--min-gate-gain', '0.010',
]
print(' '.join(cmd))
raise SystemExit(subprocess.run(cmd, cwd=repo).returncode)
