# %% [markdown]
# # 27f Post-hoc Expert Graft
#
# 27b-27e は warmup を少しだけ超えるが、平均 aggregation で local expert が薄まっている。FedDG-MoE の test-time adapter fusion と、pseudo-label quality/long-tail weighting 系の示唆を使い、学習を増やす前に client MoE residual を単一 checkpoint の expert slot に詰め替えて total mAP50 を評価する。

# %%
import subprocess, sys
from pathlib import Path

ROOT = Path('/app/Object_Detection')
SCRIPT = ROOT / 'dynamic_quality_aware_classwise_aggregation' / 'scene_daynight_dqa' / 'aggressive_dqamox' / 'scripts' / 'build_eval_27f_posthoc_expert_graft.py'
cmd = [sys.executable, str(SCRIPT), '--target-map50', '0.60', '--splits', 'total', '--batch-size', '16']
print(' '.join(cmd))
subprocess.run(cmd, cwd=ROOT, check=True)
# Out:
# /opt/venv/bin/python3 /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/scripts/build_eval_27f_posthoc_expert_graft.py --target-map50 0.60 --splits total --batch-size 16
# building 27f_day3_nightblend_s1p0 -> /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27f_posthoc_expert_graft/checkpoints/27f_day3_nightblend_s1p0.pt
# building 27f_day3_nightblend_s1p8 -> /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27f_posthoc_expert_graft/checkpoints/27f_day3_nightblend_s1p8.pt
# building 27f_night3_dayblend_s1p4 -> /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27f_posthoc_expert_graft/checkpoints/27f_night3_dayblend_s1p4.pt
# ...

# %%
import pandas as pd
from pathlib import Path

summary = Path('/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27f_posthoc_expert_graft/stats/27f_posthoc_expert_graft_total_metrics.csv')
df = pd.read_csv(summary)
display(df.sort_values('map50', ascending=False))
# Out:
#            checkpoint_label  map50  map50_95  precision  recall  \
# 1          27d_final_repair  0.462     0.259      0.688   0.429
# 2          27e_final_repair  0.462     0.259      0.688   0.429
# 3  27f_day3_nightblend_s1p0  0.462     0.259      0.690   0.429
# 0             warmup_global  0.460     0.259      0.681   0.427
# 6   27f_27d_tail_slots_s1p5  0.454     0.236      0.689   0.417
# 5  27f_night3_dayblend_s1p4  0.446     0.221      0.693   0.405
# 4  27f_day3_nightblend_s1p8  0.437     0.212      0.662   0.407
#
#                                      checkpoint_path
# 1  /app/Object_Detection/dynamic_quality_aware_cl...
# 2  /app/Object_Detection/dynamic_quality_aware_cl...
# 3  /app/Object_Detection/dynamic_quality_aware_cl...
# 0  /app/Object_Detection/dynamic_quality_aware_cl...
# 6  /app/Object_Detection/dynamic_quality_aware_cl...
# 5  /app/Object_Detection/dynamic_quality_aware_cl...
# 4  /app/Object_Detection/dynamic_quality_aware_cl...
