# %% [markdown]
# # 27p High-Resolution / NMS-Calibrated Routed MoE
#
# 27k-27o showed that hard routed model-level MoE plus score calibration is useful, but extra leaked boxes and night enhancement do not improve AP. This run keeps the best 27o routed experts fixed and searches test-time resolution/NMS policy for small-object recovery.

# %%
from pathlib import Path
import subprocess
import sys

repo = Path('/app/Object_Detection')
script = repo / 'dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/scripts/build_eval_27p_highres_nms_routed_moe.py'
workspace = repo / 'dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27p_highres_nms_routed_moe_r1'
cmd = [sys.executable, str(script), '--target-map50', '0.60', '--workspace', str(workspace)]
print('Running:', ' '.join(cmd))
result = subprocess.run(cmd, cwd=repo)
if result.returncode not in (0, 2):
    raise SystemExit(result.returncode)
print('27p completed with returncode', result.returncode)
# Out:
# Running: /opt/venv/bin/python3 /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/scripts/build_eval_27p_highres_nms_routed_moe.py --target-map50 0.60 --workspace /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27p_highres_nms_routed_moe_r1
# DiscordNotifyResult(ok=True, chunks_sent=1, status_codes=(204,), dry_run=False, error=None)
# baseline_640_iou060 total status=ok imgsz=640 nms_iou=0.6 mAP50=0.472 mAP50:95=0.267
# nms_tight_640_iou055 total status=ok imgsz=640 nms_iou=0.55 mAP50=0.474 mAP50:95=0.266
# nms_loose_640_iou065 total status=ok imgsz=640 nms_iou=0.65 mAP50=0.468 mAP50:95=0.267
# highres_768_iou060 total status=ok imgsz=768 nms_iou=0.6 mAP50=0.495 mAP50:95=0.281
# highres_896_iou060 total status=ok imgsz=896 nms_iou=0.6 mAP50=0.511 mAP50:95=0.29
# highres_896_iou065 total status=ok imgsz=896 nms_iou=0.65 mAP50=0.508 mAP50:95=0.29
# ...
