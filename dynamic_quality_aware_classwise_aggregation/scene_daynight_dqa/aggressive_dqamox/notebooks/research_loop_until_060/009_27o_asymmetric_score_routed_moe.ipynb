# %% [markdown]
# # 27o Asymmetric Score-Scaled Routed MoE
#
# 27n improved total mAP by making the routed ensemble anchor-dominant, but night highway weakened. This run applies anchor-dominant scaling mainly to day experts while keeping night routing safer.

# %%
from pathlib import Path
import subprocess
import sys

repo = Path('/app/Object_Detection')
script = repo / 'dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/scripts/build_eval_27o_asymmetric_score_routed_moe.py'
workspace = repo / 'dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27o_asymmetric_score_routed_moe_r1'
cmd = [sys.executable, str(script), '--target-map50', '0.60', '--workspace', str(workspace)]
print('Running:', ' '.join(cmd))
result = subprocess.run(cmd, cwd=repo)
if result.returncode not in (0, 2):
    raise SystemExit(result.returncode)
print('27o completed with returncode', result.returncode)
# Out:
# Running: /opt/venv/bin/python3 /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/scripts/build_eval_27o_asymmetric_score_routed_moe.py --target-map50 0.60 --workspace /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27o_asymmetric_score_routed_moe_r1
# DiscordNotifyResult(ok=True, chunks_sent=1, status_codes=(204,), dry_run=False, error=None)
# hard_reference_t0.32 total status=ok mAP50=0.47 mAP50:95=0.266
# day_anchor_night_hard total status=ok mAP50=0.472 mAP50:95=0.266
# day_anchor_night_precision total status=ok mAP50=0.472 mAP50:95=0.265
# day_anchor_night_light total status=ok mAP50=0.472 mAP50:95=0.266
# day_light_night_hard total status=ok mAP50=0.472 mAP50:95=0.267
# day_light_night_hard highway_day status=ok mAP50=0.458 mAP50:95=0.257
# day_light_night_hard highway_night status=ok mAP50=0.311 mAP50:95=0.182
# ...
