# %% [markdown]
# # 27r 1024px Policy Recalibration
#
# 27q found a 1024px plateau around mAP50 0.522. This run holds resolution fixed and tests whether NMS, TTA, hard routing, anchor-dominant scaling, or the strongest single teacher is the real best policy.

# %%
from pathlib import Path
import subprocess
import sys

repo = Path('/app/Object_Detection')
script = repo / 'dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/scripts/build_eval_27r_1024_policy_recalibration.py'
workspace = repo / 'dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27r_1024_policy_recalibration_r1'
cmd = [sys.executable, str(script), '--target-map50', '0.60', '--workspace', str(workspace), '--previous-best-map50', '0.522']
print('Running:', ' '.join(cmd))
result = subprocess.run(cmd, cwd=repo)
if result.returncode not in (0, 2):
    raise SystemExit(result.returncode)
print('27r completed with returncode', result.returncode)
