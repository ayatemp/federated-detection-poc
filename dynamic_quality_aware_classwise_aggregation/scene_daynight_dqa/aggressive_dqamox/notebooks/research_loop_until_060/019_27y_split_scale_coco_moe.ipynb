# %% [markdown]
# # 27y Split-Scale COCO Bridge MoE
#
# 27u showed global COCO union is the best full-set result so far, while 27w/27x showed class-level COCO routing overfits. 27y keeps the same output-level MoE but changes the COCO score scale by scene/day-night split, protecting night/highway when useful.

# %%
# %cd /app/Object_Detection
# Out:
# /app/Object_Detection

# %%
# !python dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/scripts/build_eval_27y_split_scale_coco_moe.py \
  --workspace dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27y_split_scale_coco_moe_r1
# Out:
# EfficientTeacher  618670a torch 2.8.0+cu128 CUDA:0 (NVIDIA RTX 6000 Ada Generation, 48508.9375MB)
# 27y: Scanning '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation
# 27y: Scanning '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation
# 27y: Scanning '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation
# 27y: Scanning '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation
# 27y: Scanning '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation
# 27y: New cache created: /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27y_split_scale_coco_moe_r1/data_lists/paper_eval_scene_daynight_total_val.cache
# cls gt ratio(positive): (12313.00-0) (610.00-1) (93070.00-2) (1514.00-3) (3858.00-4) (972.00-5) (427.00-6) (24640.00-7) (32001.00-8) (14.00-9)
# cls gt total number: 169419.0 label number per image: 18.644106965995377
# ...

# %%
import pandas as pd
metrics = "dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27y_split_scale_coco_moe_r1/stats/27y_split_scale_coco_moe_metrics.csv"
df = pd.read_csv(metrics)
display(df[df["split"].eq("scene_daynight_total")].sort_values("map50", ascending=False))
# Out:
#                                   candidate             phase  \
# 42                      day_s035_night_s020  full_split_scale
# 35                       day_s050_night_ref  full_split_scale
# 21                           all_union_s050  full_split_scale
# 28                       day_s035_night_ref  full_split_scale
# 14                           all_union_s035  full_split_scale
# 7                            all_union_s020  full_split_scale
# 63    res_day_s050_city_day_s035_night_s020  full_split_scale
# 56  cityres_day_s050_highway_s020_night_ref  full_split_scale
# 49              cityres_day_s035_others_ref  full_split_scale
# 0                         ref1024_reference  full_split_scale
#
#                    split  images  labels  precision    recall     map50  \
# 42  scene_daynight_total    9087  169419   0.708765  0.488331  0.531249
# 35  scene_daynight_total    9087  169419   0.575627  0.536204  0.530958
# ...
