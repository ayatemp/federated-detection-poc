# %% [markdown]
# # 27m Night-Enhanced Routed MoE
#
# 27k improved the total score by routing day/night images to disjoint specialist pools, but night splits remain weak. This run keeps that MoE and applies inference-only gamma/gain enhancement before the night expert pool sees dark images.

# %%
from pathlib import Path
import subprocess
import sys

repo = Path('/app/Object_Detection')
script = repo / 'dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/scripts/build_eval_27m_night_enhanced_routed_moe.py'
workspace = repo / 'dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27m_night_enhanced_routed_moe_r1'
cmd = [sys.executable, str(script), '--target-map50', '0.60', '--workspace', str(workspace)]
print('Running:', ' '.join(cmd))
result = subprocess.run(cmd, cwd=repo)
if result.returncode not in (0, 2):
    raise SystemExit(result.returncode)
print('27m completed with returncode', result.returncode)
