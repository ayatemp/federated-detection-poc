# %% [markdown]
# # 27q High-Resolution Tight-NMS Routed MoE Grid
#
# 27p found the first large gain: high-resolution routed MoE moved total mAP50 from 0.472 to 0.517. Loose NMS was weaker, so this run focuses on 0.55/0.60 NMS at 896-1280px and keeps split evaluation off until a stronger total candidate is found.

# %%
from pathlib import Path
import subprocess
import sys

repo = Path('/app/Object_Detection')
script = repo / 'dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/scripts/build_eval_27q_highres_tight_grid_routed_moe.py'
workspace = repo / 'dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27q_highres_tight_grid_routed_moe_r1'
cmd = [sys.executable, str(script), '--target-map50', '0.60', '--workspace', str(workspace), '--previous-best-map50', '0.517']
print('Running:', ' '.join(cmd))
result = subprocess.run(cmd, cwd=repo)
if result.returncode not in (0, 2):
    raise SystemExit(result.returncode)
print('27q completed with returncode', result.returncode)
# Out:
# Running: /opt/venv/bin/python3 /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/scripts/build_eval_27q_highres_tight_grid_routed_moe.py --target-map50 0.60 --workspace /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27q_highres_tight_grid_routed_moe_r1 --previous-best-map50 0.517
# DiscordNotifyResult(ok=True, chunks_sent=1, status_codes=(204,), dry_run=False, error=None)
# highres_896_iou055 total status=ok imgsz=896 nms_iou=0.55 mAP50=0.513 mAP50:95=0.289
# highres_1024_iou060 total status=ok imgsz=1024 nms_iou=0.6 mAP50=0.521 mAP50:95=0.294
# highres_1024_iou055 total status=ok imgsz=1024 nms_iou=0.55 mAP50=0.522 mAP50:95=0.294
# highres_1152_iou060 total status=ok imgsz=1152 nms_iou=0.6 mAP50=0.52 mAP50:95=0.294
# highres_1152_iou055 total status=ok imgsz=1152 nms_iou=0.55 mAP50=0.522 mAP50:95=0.293
# ...
