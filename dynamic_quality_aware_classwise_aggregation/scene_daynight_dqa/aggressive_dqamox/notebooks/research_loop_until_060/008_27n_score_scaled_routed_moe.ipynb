# %% [markdown]
# # 27n Score-Scaled Routed MoE
#
# 27k found that disjoint day/night specialist routing helps. 27l and 27m showed that adding more boxes or brightening night inputs hurts precision. This run keeps the same routed MoE but calibrates expert objectness scores to improve AP ranking.

# %%
from pathlib import Path
import subprocess
import sys

repo = Path('/app/Object_Detection')
script = repo / 'dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/scripts/build_eval_27n_score_scaled_routed_moe.py'
workspace = repo / 'dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27n_score_scaled_routed_moe_r1'
cmd = [sys.executable, str(script), '--target-map50', '0.60', '--workspace', str(workspace)]
print('Running:', ' '.join(cmd))
result = subprocess.run(cmd, cwd=repo)
if result.returncode not in (0, 2):
    raise SystemExit(result.returncode)
print('27n completed with returncode', result.returncode)
# Out:
# Running: /opt/venv/bin/python3 /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/scripts/build_eval_27n_score_scaled_routed_moe.py --target-map50 0.60 --workspace /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27n_score_scaled_routed_moe_r1
# DiscordNotifyResult(ok=True, chunks_sent=1, status_codes=(204,), dry_run=False, error=None)
# hard_reference_t0.32 total status=ok mAP50=0.47 mAP50:95=0.266
# precision_clients_down total status=ok mAP50=0.471 mAP50:95=0.266
# client_boost total status=ok mAP50=0.47 mAP50:95=0.262
# repair_confident total status=ok mAP50=0.471 mAP50:95=0.262
# anchor_dominant total status=ok mAP50=0.472 mAP50:95=0.265
# anchor_dominant highway_day status=ok mAP50=0.458 mAP50:95=0.256
# anchor_dominant highway_night status=ok mAP50=0.309 mAP50:95=0.177
# anchor_dominant citystreet_day status=ok mAP50=0.511 mAP50:95=0.293
# anchor_dominant citystreet_night status=ok mAP50=0.397 mAP50:95=0.214
# anchor_dominant residential_day status=ok mAP50=0.536 mAP50:95=0.315
# anchor_dominant residential_night status=ok mAP50=0.417 mAP50:95=0.227
# anchor_dominant scene_daynight_total status=ok mAP50=0.472 mAP50:95=0.265
# 27n finished. Best total candidate: anchor_dominant
# - total mAP50=0.472 / mAP50:95=0.265
# - hard routed reference mAP50=0.470; gain=+0.002
# - total CSV: /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27n_score_scaled_routed_moe_r1/stats/27n_score_scaled_total_metrics.csv
# - full split CSV: /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27n_score_scaled_routed_moe_r1/stats/27n_score_scaled_best_split_metrics.csv
# Decision: target 0.600 not reached; continue with a different strategy.
# DiscordNotifyResult(ok=True, chunks_sent=1, status_codes=(204,), dry_run=False, error=None)
# 27n completed with returncode 2
