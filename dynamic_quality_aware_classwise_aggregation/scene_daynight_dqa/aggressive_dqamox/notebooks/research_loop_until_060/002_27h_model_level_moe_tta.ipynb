# %% [markdown]
# # 27h Model-Level MoE / TTA Probe
#
# Prediction-level MoE probe inspired by model-level object-detection MoE and FedDG-MoE test-time fusion. This notebook evaluates total split first and only expands if the result is promising.

# %%
from pathlib import Path
import subprocess
import sys

REPO_ROOT = Path('/app/Object_Detection')
SCRIPT = REPO_ROOT / 'dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/scripts/build_eval_27h_model_level_moe.py'
cmd = [
    sys.executable,
    str(SCRIPT),
    '--batch-size', '16',
    '--target-map50', '0.60',
]
print('Running:', ' '.join(cmd))
proc = subprocess.run(cmd, cwd=REPO_ROOT, text=True)
print('Return code:', proc.returncode)
if proc.returncode == 0:
    print('Target reached by 27h.')
else:
    print('Target not reached by 27h; continue with the next idea.')
# Out:
# Running: /opt/venv/bin/python3 /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/scripts/build_eval_27h_model_level_moe.py --batch-size 16 --target-map50 0.60
# DiscordNotifyResult(ok=True, chunks_sent=1, status_codes=(204,), dry_run=False, error=None)
# warmup_single total status=ok mAP50=0.46 mAP50:95=0.259
# warmup_tta total status=ok mAP50=0.46 mAP50:95=0.259
# repair_pool_warmup_27d_27e_27g total status=ok mAP50=0.463 mAP50:95=0.261
# repair_pool_warmup_27d_27e_27g_tta total status=ok mAP50=0.463 mAP50:95=0.261
# client_pool_27g_all total status=ok mAP50=0.461 mAP50:95=0.26
# client_pool_27g_all_plus_warmup total status=ok mAP50=0.463 mAP50:95=0.261
# broad_pool_repairs_clients_warmup total status=ok mAP50=0.464 mAP50:95=0.262
# broad_pool_repairs_clients_warmup highway_day status=ok mAP50=0.451 mAP50:95=0.254
# broad_pool_repairs_clients_warmup highway_night status=ok mAP50=0.311 mAP50:95=0.181
# broad_pool_repairs_clients_warmup citystreet_day status=ok mAP50=0.503 mAP50:95=0.289
# broad_pool_repairs_clients_warmup citystreet_night status=ok mAP50=0.387 mAP50:95=0.207
# broad_pool_repairs_clients_warmup residential_day status=ok mAP50=0.527 mAP50:95=0.313
# broad_pool_repairs_clients_warmup residential_night status=ok mAP50=0.411 mAP50:95=0.226
# broad_pool_repairs_clients_warmup scene_daynight_total status=ok mAP50=0.464 mAP50:95=0.262
# 27h finished. Best total candidate: broad_pool_repairs_clients_warmup
# - total mAP50=0.464 / mAP50:95=0.262
# - warmup total mAP50=0.460; gain=+0.004
# - total CSV: /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27h_model_level_moe_tta/stats/27h_model_level_moe_total_metrics.csv
# - full split CSV: /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27h_model_level_moe_tta/stats/27h_model_level_moe_best_split_metrics.csv
# Decision: target 0.600 not reached; next loop should move beyond output-level fusion.
# DiscordNotifyResult(ok=True, chunks_sent=1, status_codes=(204,), dry_run=False, error=None)
# Return code: 2
# Target not reached by 27h; continue with the next idea.
