# %% [markdown]
# # 27x Guarded Residual Class MoE
#
# 27w found that free per-class routing overfits the gate: raw class-channel MoE reached +0.019 gate gain but regressed on the full set. 27x distills only the robust class signals: bike COCO residuals and optional bus COCO-union residuals, while all other classes remain the routed DQA reference.

# %%
# %cd /app/Object_Detection
# Out:
# /app/Object_Detection

# %%
# !python dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/scripts/build_eval_27x_guarded_residual_class_moe.py \
  --workspace dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27x_guarded_residual_class_moe_r1
# Out:
# EfficientTeacher  618670a torch 2.8.0+cu128 CUDA:0 (NVIDIA RTX 6000 Ada Generation, 48508.9375MB)
# 27x: Scanning '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation
# 27x: Scanning '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation
# 27x: Scanning '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation
# 27x: Scanning '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation
# 27x: Scanning '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation
# 27x: New cache created: /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27x_guarded_residual_class_moe_r1/data_lists/paper_eval_scene_daynight_total_val.cache
# cls gt ratio(positive): (12313.00-0) (610.00-1) (93070.00-2) (1514.00-3) (3858.00-4) (972.00-5) (427.00-6) (24640.00-7) (32001.00-8) (14.00-9)
# cls gt total number: 169419.0 label number per image: 18.644106965995377
# ...

# %%
import pandas as pd
metrics = "dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27x_guarded_residual_class_moe_r1/stats/27x_guarded_residual_class_moe_metrics.csv"
df = pd.read_csv(metrics)
display(df[df["split"].eq("scene_daynight_total")].sort_values("map50", ascending=False))
# Out:
#                          candidate                  phase  \
# 56  bike_union_s035_bus_union_s035  full_guarded_residual
# 35                 bike_union_s050  full_guarded_residual
# 49   bike_coco_s050_bus_union_s050  full_guarded_residual
# 42   bike_coco_s035_bus_union_s035  full_guarded_residual
# 28                 bike_union_s035  full_guarded_residual
# 14                  bike_coco_s035  full_guarded_residual
# 7                   bike_coco_s020  full_guarded_residual
# 21                  bike_coco_s050  full_guarded_residual
# 0                ref1024_reference  full_guarded_residual
#
#                    split  images  labels  precision    recall     map50  \
# 56  scene_daynight_total    9087  169419   0.708765  0.488331  0.522774
# 35  scene_daynight_total    9087  169419   0.708770  0.488335  0.522106
# 49  scene_daynight_total    9087  169419   0.670041  0.499491  0.522071
# 42  scene_daynight_total    9087  169419   0.747216  0.444743  0.521860
# ...
