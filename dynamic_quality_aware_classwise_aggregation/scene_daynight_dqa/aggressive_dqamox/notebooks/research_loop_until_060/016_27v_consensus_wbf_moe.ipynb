# %% [markdown]
# # 27v Consensus WBF MoE
#
# 27u showed that adding COCO boxes can look spectacular on the gate set but barely moves full mAP. This notebook tests a stricter output-MoE: Soft-NMS and Weighted Boxes Fusion (WBF) re-rank boxes only when DQA and COCO agree, with one rare-class branch for person/rider/bike/motor/traffic categories.

# %%
from pathlib import Path
import subprocess

repo = Path('/app/Object_Detection')
script = repo / 'dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/scripts/build_eval_27v_consensus_wbf_moe.py'
workspace = repo / 'dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/output/27v_consensus_wbf_moe_r1'
cmd = [
    '/root/micromamba/envs/al_yolov8/bin/python',
    str(script),
    '--workspace', str(workspace),
    '--target-map50', '0.60',
    '--previous-best-map50', '0.52939',
    '--gate-images', '120',
    '--min-gate-gain', '0.020',
]
print(' '.join(cmd))
result = subprocess.run(cmd, cwd=repo)
print('returncode:', result.returncode)
