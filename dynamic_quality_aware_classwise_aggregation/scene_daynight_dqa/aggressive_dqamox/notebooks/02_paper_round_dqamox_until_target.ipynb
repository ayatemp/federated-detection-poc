# %% [markdown]
# # 02 Paper-Round DQA-MoX Until Target
#
# FedMoX/FedSTO の論文設定に寄せた continuation notebook。
#
# - FedMoX: warmup 50 epochs, FL 50 rounds, 33% online clients, 1 epoch/round
# - FedSTO: 2-stage training. main setting は Phase1 100 / Phase2 150
# - この notebook では実行可能な本番形として、FedMoX の total 50 FL rounds に FedSTO 比率を写し、Phase1 20 / Phase2 30 にする
# - 評価は paper protocol の total と各 scene/day-night split を見る
#
# 詳細な設計メモ: `../PAPER_ROUND_PROTOCOL.md`

# %%
# !python dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/aggressive_dqamox/scripts/run_paper_round_dqamox_until_target.py \
  --max-trials 0 \
  --target-map50 0.60 \
  --notify-first-progress-hours 1 \
  --notify-progress-interval-hours 1
