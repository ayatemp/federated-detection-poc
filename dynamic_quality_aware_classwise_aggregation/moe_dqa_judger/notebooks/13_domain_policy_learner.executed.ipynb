# %% [markdown]
# # 13 Domain Policy Learner
#
# 12 showed that weighted soup does not preserve each domain winner's peak.  This
# notebook trains a small machine-learning judger to select a checkpoint/policy
# conditioned on domain metadata, using only accumulated self-generated scores.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path('/app/Object_Detection')
PROJECT = ROOT / 'dynamic_quality_aware_classwise_aggregation' / 'moe_dqa_judger'
OUT = PROJECT / 'output' / '13_domain_policy_learner'
OUT
# Out:
# PosixPath('/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/13_domain_policy_learner')

# %%
import subprocess, sys

cmd = [
    sys.executable,
    str(PROJECT / 'scripts' / 'run_13_domain_policy_learner.py'),
    '--workspace-root', str(OUT),
    '--max-total-drop', '0.0011',
    '--notify-discord',
]
print(' '.join(cmd))
subprocess.run(cmd, cwd=ROOT, check=True)
# Out:
# /opt/venv/bin/python3 /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/scripts/run_13_domain_policy_learner.py --workspace-root /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/13_domain_policy_learner --max-total-drop 0.0011 --notify-discord
# {
#   "policy": [
#     {
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_scaled04_best00_rand008_050.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/citystreet_day.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r004_scaled04_best00_rand008_050_citystreet_day --exist-ok --no-plots",
#       "domain": "citystreet_day",
#       "domain_score": 0.63105,
#       "group": "day",
#       "images": "3067.0",
#       "label": "r004_scaled04_best00_rand008_050",
#       "labels": "69855.0",
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r004_scaled04_best00_rand008_050_citystreet_day.log",
#       "map50": 0.506,
#       "map50_95": 0.291,
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_scaled04_best00_rand008_050.pt",
#       "precision": 0.733,
#       "recall": 0.464,
#       "returncode": "0",
#       "source": "07_incumbent_delta",
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "total_score": 0.5741,
#       "scene": "citystreet",
#       "time": "day",
#       "is_night": 0.0,
#       "is_day": 1.0,
#       "round_num": 4.0,
#       "is_soup": 0.0,
#       "is_scaled": 1.0,
#       "is_repair": 0.0,
#       "is_resprec": 0.0,
#       "pred_domain_score": 0.5849802833333311
#     },
#     {
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r019_full_r019_residential_night_precision.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/configs/citystreet_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_runs --name highway11_full_domain_r019_residential_night_precision_citystreet_night --exist-ok --no-plots",
#       "domain": "citystreet_night",
#       "domain_score": 0.4657,
#       "group": "night",
#       "images": "2582.0",
#       "label": "r019_residential_night_precision",
#       "labels": "47259.0",
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_logs/highway11_full_domain_r019_residential_night_precision_citystreet_night.log",
#       "map50": 0.377,
#       "map50_95": 0.2,
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r019_full_r019_residential_night_precision.pt",
#       "precision": 0.603,
#       "recall": 0.374,
#       "returncode": "0",
#       "source": "11_highway_night_full",
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "total_score": 0.57455,
#       "scene": "citystreet",
#       "time": "night",
#       "is_night": 1.0,
#       "is_day": 0.0,
#       "round_num": 19.0,
#       "is_soup": 0.0,
#       "is_scaled": 0.0,
#       "is_repair": 0.0,
#       "is_resprec": 1.0,
#       "pred_domain_score": 0.39821722916666685
#     },
#     {
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r021_full_r021_tiny_repair_delta.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/configs/highway_day.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_runs --name highway11_full_domain_r021_tiny_repair_delta_highway_day --exist-ok --no-plots",
#       "domain": "highway_day",
#       "domain_score": 0.5477,
#       "group": "day",
#       "images": "1290.0",
#       "label": "r021_tiny_repair_delta",
#       "labels": "20532.0",
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_logs/highway11_full_domain_r021_tiny_repair_delta_highway_day.log",
#       "map50": 0.441,
#       "map50_95": 0.249,
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r021_full_r021_tiny_repair_delta.pt",
#       "precision": 0.784,
#       "recall": 0.391,
#       "returncode": "0",
#       "source": "11_highway_night_full",
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "total_score": 0.5745,
#       "scene": "highway",
#       "time": "day",
#       "is_night": 0.0,
#       "is_day": 1.0,
#       "round_num": 21.0,
#       "is_soup": 0.0,
#       "is_scaled": 0.0,
#       "is_repair": 1.0,
#       "is_resprec": 0.0,
#       "pred_domain_score": 0.6579083402777833
#     },
#     {
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/10_night_targeted_delta_optimizer/candidates/r015_full_r015_residential_night_precision.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/10_night_targeted_delta_optimizer/configs/highway_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/10_night_targeted_delta_optimizer/validation_runs --name night10_full_domain_r015_residential_night_precision_highway_night --exist-ok --no-plots",
#       "domain": "highway_night",
#       "domain_score": 0.38425,
#       "group": "night",
#       "images": "1007.0",
#       "label": "r015_residential_night_precision",
#       "labels": "12708.0",
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/10_night_targeted_delta_optimizer/validation_logs/night10_full_domain_r015_residential_night_precision_highway_night.log",
#       "map50": 0.308,
#       "map50_95": 0.177,
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/10_night_targeted_delta_optimizer/candidates/r015_full_r015_residential_night_precision.pt",
#       "precision": 0.539,
#       "recall": 0.286,
#       "returncode": "0",
#       "source": "10_night_targeted_delta",
#       "total_map50": 0.461,
#       "total_map50_95": 0.26,
#       "total_score": 0.57355,
#       "scene": "highway",
#       "time": "night",
#       "is_night": 1.0,
#       "is_day": 0.0,
#       "round_num": 15.0,
#       "is_soup": 0.0,
#       "is_scaled": 0.0,
#       "is_repair": 0.0,
#       "is_resprec": 1.0,
#       "pred_domain_score": 0.47273052500000207
#     },
#     {
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_scaled04_best01_rand000_050.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/residential_day.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r006_scaled04_best01_rand000_050_residential_day --exist-ok --no-plots",
#       "domain": "residential_day",
#       "domain_score": 0.67195,
#       "group": "day",
#       "images": "862.0",
#       "label": "r006_scaled04_best01_rand000_050",
#       "labels": "14881.0",
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r006_scaled04_best01_rand000_050_residential_day.log",
#       "map50": 0.538,
#       "map50_95": 0.315,
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_scaled04_best01_rand000_050.pt",
#       "precision": 0.704,
#       "recall": 0.474,
#       "returncode": "0",
#       "source": "07_incumbent_delta",
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "total_score": 0.5741,
#       "scene": "residential",
#       "time": "day",
#       "is_night": 0.0,
#       "is_day": 1.0,
#       "round_num": 6.0,
#       "is_soup": 0.0,
#       "is_scaled": 1.0,
#       "is_repair": 0.0,
#       "is_resprec": 0.0,
#       "pred_domain_score": 0.5862102083333323
#     },
#     {
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r019_full_r019_residential_night_precision.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/configs/residential_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_runs --name highway11_full_domain_r019_residential_night_precision_residential_night --exist-ok --no-plots",
#       "domain": "residential_night",
#       "domain_score": 0.4764,
#       "group": "night",
#       "images": "279.0",
#       "label": "r019_residential_night_precision",
#       "labels": "4184.0",
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_logs/highway11_full_domain_r019_residential_night_precision_residential_night.log",
#       "map50": 0.389,
#       "map50_95": 0.202,
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r019_full_r019_residential_night_precision.pt",
#       "precision": 0.656,
#       "recall": 0.334,
#       "returncode": "0",
#       "source": "11_highway_night_full",
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "total_score": 0.57455,
#       "scene": "residential",
#       "time": "night",
#       "is_night": 1.0,
#       "is_day": 0.0,
#       "round_num": 19.0,
#       "is_soup": 0.0,
#       "is_scaled": 0.0,
#       "is_repair": 0.0,
#       "is_resprec": 1.0,
#       "pred_domain_score": 0.4219584513888901
#     }
#   ],
#   "summary": [
#     {
#       "policy": "incumbent_r002",
#       "domain_mean_score": 0.5293916666666666,
#       "day_mean_score": 0.6166999999999999,
#       "night_mean_score": 0.44208333333333333,
#       "worst_domain_score": 0.38425,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46543999999999996
#     },
#     {
#       "policy": "learned_groupcv_policy",
#       "domain_mean_score": 0.5295083333333334,
#       "day_mean_score": 0.6169,
#       "night_mean_score": 0.44211666666666666,
#       "worst_domain_score": 0.38425,
#       "domain_mean_map50": 0.42650000000000005,
#       "night_mean_map50": 0.35800000000000004,
#       "group_dro_score": 0.4655
#     },
#     {
#       "policy": "oracle_policy",
#       "domain_mean_score": 0.5304083333333333,
#       "day_mean_score": 0.6176,
#       "night_mean_score": 0.44321666666666665,
#       "worst_domain_score": 0.38544999999999996,
#       "domain_mean_map50": 0.42700000000000005,
#       "night_mean_map50": 0.3586666666666667,
#       "group_dro_score": 0.46653999999999995
#     }
#   ],
#   "scorecard": {
#     "experiment_env": 93,
#     "root_cause_analysis": 89,
#     "judge_stability": 90,
#     "accuracy_improvement": 56,
#     "final_goal": 79,
#     "cv_mae": 0.07533750888888957,
#     "learned_night_delta": 3.333333333332966e-05,
#     "learned_worst_delta": 0.0,
#     "learned_dro_delta": 6.0000000000060005e-05,
#     "oracle_dro_delta": 0.0010999999999999899
#   },
#   "report": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/13_domain_policy_learner/13_domain_policy_learner_report.md"
# }
# CompletedProcess(args=['/opt/venv/bin/python3', '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/scripts/run_13_domain_policy_learner.py', '--workspace-root', '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/13_domain_policy_learner', '--max-total-drop', '0.0011', '--notify-discord'], returncode=0)

# %%
policy = pd.read_csv(OUT / 'stats' / '13_policy_rows.csv')
display(policy[['domain','label','domain_score','pred_domain_score','map50','total_score']])

summary = pd.read_csv(OUT / 'stats' / '13_policy_summary.csv')
display(summary)

print((OUT / '13_domain_policy_learner_report.md').read_text())
# Out:
#               domain                             label  domain_score  \
# 0     citystreet_day  r004_scaled04_best00_rand008_050       0.63105
# 1   citystreet_night  r019_residential_night_precision       0.46570
# 2        highway_day            r021_tiny_repair_delta       0.54770
# 3      highway_night  r015_residential_night_precision       0.38425
# 4    residential_day  r006_scaled04_best01_rand000_050       0.67195
# 5  residential_night  r019_residential_night_precision       0.47640
#
#    pred_domain_score  map50  total_score
# 0           0.584980  0.506      0.57410
# 1           0.398217  0.377      0.57455
# 2           0.657908  0.441      0.57450
# 3           0.472731  0.308      0.57355
# 4           0.586210  0.538      0.57410
# 5           0.421958  0.389      0.57455
#    day_mean_score  domain_mean_map50  domain_mean_score  group_dro_score  \
# 0          0.6167           0.426333           0.529392          0.46544
# 1          0.6169           0.426500           0.529508          0.46550
# 2          0.6176           0.427000           0.530408          0.46654
#
#    night_mean_map50  night_mean_score                  policy  \
# 0          0.357667          0.442083          incumbent_r002
# 1          0.358000          0.442117  learned_groupcv_policy
# 2          0.358667          0.443217           oracle_policy
#
#    worst_domain_score
# 0             0.38425
# 1             0.38425
# 2             0.38545
# # DQA-SoftMoX Domain Policy Learner 13
#
# - created_utc: 2026-05-13T17:56:40.750246+00:00
# - rows: 150
# - max_total_drop: 0.0011
# - GroupKFold domain CV MAE: 0.075338
#
# ## Learned Policy
#
# | domain | selected | actual score | predicted | mAP50 | total |
# |---|---|---:|---:|---:|---:|
# | citystreet_day | r004_scaled04_best00_rand008_050 | 0.63105 | 0.58498 | 0.506 | 0.57410 |
# | citystreet_night | r019_residential_night_precision | 0.46570 | 0.39822 | 0.377 | 0.57455 |
# | highway_day | r021_tiny_repair_delta | 0.54770 | 0.65791 | 0.441 | 0.57450 |
# | highway_night | r015_residential_night_precision | 0.38425 | 0.47273 | 0.308 | 0.57355 |
# | residential_day | r006_scaled04_best01_rand000_050 | 0.67195 | 0.58621 | 0.538 | 0.57410 |
# | residential_night | r019_residential_night_precision | 0.47640 | 0.42196 | 0.389 | 0.57455 |
#
# ## Summary
#
# | policy | mean | day | night | worst | DRO | night mAP50 |
# |---|---:|---:|---:|---:|---:|---:|
# | incumbent_r002 | 0.52939 | 0.61670 | 0.44208 | 0.38425 | 0.46544 | 0.358 |
# | learned_groupcv_policy | 0.52951 | 0.61690 | 0.44212 | 0.38425 | 0.46550 | 0.358 |
# | oracle_policy | 0.53041 | 0.61760 | 0.44322 | 0.38545 | 0.46654 | 0.359 |
#
# ## Codex Goal Scores
#
# - 実験環境: 93/100
# - 原因分析: 89/100
# - judge の安定化: 90/100
# - 精度向上: 56/100
# - 最終ゴール達成度: 79/100
