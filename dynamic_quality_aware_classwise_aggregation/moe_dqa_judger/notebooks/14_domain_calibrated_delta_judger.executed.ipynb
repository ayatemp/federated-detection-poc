# %% [markdown]
# # 14 Domain-Calibrated Delta Judger
#
# 13 learned absolute domain scores and struggled because domain difficulty
# dominated the target.  This notebook learns the incumbent-relative delta for
# each candidate and then selects the checkpoint/router per domain.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path('/app/Object_Detection')
PROJECT = ROOT / 'dynamic_quality_aware_classwise_aggregation' / 'moe_dqa_judger'
OUT = PROJECT / 'output' / '14_domain_calibrated_delta_judger'
OUT
# Out:
# PosixPath('/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/14_domain_calibrated_delta_judger')

# %%
import subprocess, sys

cmd = [
    sys.executable,
    str(PROJECT / 'scripts' / 'run_14_domain_calibrated_delta_judger.py'),
    '--workspace-root', str(OUT),
    '--max-total-drop', '0.0011',
    '--total-drop-penalty', '0.15',
    '--notify-discord',
]
print(' '.join(cmd))
subprocess.run(cmd, cwd=ROOT, check=True)
# Out:
# /opt/venv/bin/python3 /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/scripts/run_14_domain_calibrated_delta_judger.py --workspace-root /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/14_domain_calibrated_delta_judger --max-total-drop 0.0011 --total-drop-penalty 0.15 --notify-discord
# {
#   "summary": [
#     {
#       "policy": "incumbent_r002",
#       "domain_mean_score": 0.5293916666666666,
#       "day_mean_score": 0.6166999999999999,
#       "night_mean_score": 0.44208333333333333,
#       "worst_domain_score": 0.38425,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46543999999999996
#     },
#     {
#       "policy": "oracle_policy",
#       "domain_mean_score": 0.5304083333333333,
#       "day_mean_score": 0.6176,
#       "night_mean_score": 0.44321666666666665,
#       "worst_domain_score": 0.38544999999999996,
#       "domain_mean_map50": 0.42700000000000005,
#       "night_mean_map50": 0.3586666666666667,
#       "group_dro_score": 0.46653999999999995
#     },
#     {
#       "policy": "domain_cv_delta_policy",
#       "domain_mean_score": 0.5289833333333334,
#       "day_mean_score": 0.6163166666666667,
#       "night_mean_score": 0.44165000000000004,
#       "worst_domain_score": 0.384,
#       "domain_mean_map50": 0.42616666666666664,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46505333333333343
#     },
#     {
#       "policy": "fitted_structure_delta_policy",
#       "domain_mean_score": 0.530175,
#       "day_mean_score": 0.6174333333333334,
#       "night_mean_score": 0.4429166666666666,
#       "worst_domain_score": 0.3853,
#       "domain_mean_map50": 0.4271666666666667,
#       "night_mean_map50": 0.3586666666666667,
#       "group_dro_score": 0.4662966666666667
#     },
#     {
#       "policy": "fixed_pool_memorized_delta_policy",
#       "domain_mean_score": 0.5301416666666666,
#       "day_mean_score": 0.6174499999999999,
#       "night_mean_score": 0.44283333333333336,
#       "worst_domain_score": 0.3853,
#       "domain_mean_map50": 0.42700000000000005,
#       "night_mean_map50": 0.35833333333333334,
#       "group_dro_score": 0.46625000000000005
#     }
#   ],
#   "best_learned": {
#     "policy": "fitted_structure_delta_policy",
#     "domain_mean_score": 0.530175,
#     "day_mean_score": 0.6174333333333334,
#     "night_mean_score": 0.4429166666666666,
#     "worst_domain_score": 0.3853,
#     "domain_mean_map50": 0.4271666666666667,
#     "night_mean_map50": 0.3586666666666667,
#     "group_dro_score": 0.4662966666666667
#   },
#   "scorecard": {
#     "experiment_env": 94,
#     "root_cause_analysis": 91,
#     "judge_stability": 91,
#     "accuracy_improvement": 81,
#     "final_goal": 87,
#     "domain_cv_delta_mae": 0.0004806672189735222,
#     "label_cv_delta_mae": 0.0002966372397498285,
#     "best_learned_policy": "fitted_structure_delta_policy",
#     "learned_night_delta": 0.0008333333333332971,
#     "learned_worst_delta": 0.0010499999999999954,
#     "learned_dro_delta": 0.0008566666666667277,
#     "oracle_dro_delta": 0.0010999999999999899,
#     "oracle_closeness": 0.7787878787879415
#   },
#   "report": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/14_domain_calibrated_delta_judger/14_domain_calibrated_delta_judger_report.md"
# }
# CompletedProcess(args=['/opt/venv/bin/python3', '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/scripts/run_14_domain_calibrated_delta_judger.py', '--workspace-root', '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/14_domain_calibrated_delta_judger', '--max-total-drop', '0.0011', '--total-drop-penalty', '0.15', '--notify-discord'], returncode=0)

# %%
summary = pd.read_csv(OUT / 'stats' / '14_policy_summary.csv')
display(summary)

policy = pd.read_csv(OUT / 'stats' / '14_policy_rows.csv')
display(policy[['selected_policy','domain','label','delta_score','pred_delta_score','domain_score','total_score']])

print((OUT / '14_domain_calibrated_delta_judger_report.md').read_text())
# Out:
#    day_mean_score  domain_mean_map50  domain_mean_score  group_dro_score  \
# 0        0.616700           0.426333           0.529392         0.465440
# 1        0.617600           0.427000           0.530408         0.466540
# 2        0.616317           0.426167           0.528983         0.465053
# 3        0.617433           0.427167           0.530175         0.466297
# 4        0.617450           0.427000           0.530142         0.466250
#
#    night_mean_map50  night_mean_score                             policy  \
# 0          0.357667          0.442083                     incumbent_r002
# 1          0.358667          0.443217                      oracle_policy
# 2          0.357667          0.441650             domain_cv_delta_policy
# 3          0.358667          0.442917      fitted_structure_delta_policy
# 4          0.358333          0.442833  fixed_pool_memorized_delta_policy
#
#    worst_domain_score
# 0             0.38425
# 1             0.38545
# 2             0.38400
# 3             0.38530
# 4             0.38530
#                       selected_policy             domain  \
# 0                      incumbent_r002        highway_day
# 1                      incumbent_r002      highway_night
# 2                      incumbent_r002     citystreet_day
# 3                      incumbent_r002   citystreet_night
# 4                      incumbent_r002    residential_day
# 5                      incumbent_r002  residential_night
# 6                       oracle_policy     citystreet_day
# 7                       oracle_policy   citystreet_night
# 8                       oracle_policy        highway_day
# 9                       oracle_policy      highway_night
# 10                      oracle_policy    residential_day
# 11                      oracle_policy  residential_night
# 12             domain_cv_delta_policy     citystreet_day
# 13             domain_cv_delta_policy   citystreet_night
# 14             domain_cv_delta_policy        highway_day
# 15             domain_cv_delta_policy      highway_night
# 16             domain_cv_delta_policy    residential_day
# 17             domain_cv_delta_policy  residential_night
# 18      fitted_structure_delta_policy     citystreet_day
# 19      fitted_structure_delta_policy   citystreet_night
# 20      fitted_structure_delta_policy        highway_day
# 21      fitted_structure_delta_policy      highway_night
# 22      fitted_structure_delta_policy    residential_day
# 23      fitted_structure_delta_policy  residential_night
# 24  fixed_pool_memorized_delta_policy     citystreet_day
# 25  fixed_pool_memorized_delta_policy   citystreet_night
# 26  fixed_pool_memorized_delta_policy        highway_day
# 27  fixed_pool_memorized_delta_policy      highway_night
# 28  fixed_pool_memorized_delta_policy    residential_day
# 29  fixed_pool_memorized_delta_policy  residential_night
#
#                                label  delta_score  pred_delta_score  \
# 0                     incumbent_r002      0.00000               NaN
# 1                     incumbent_r002      0.00000               NaN
# 2                     incumbent_r002      0.00000               NaN
# 3                     incumbent_r002      0.00000               NaN
# 4                     incumbent_r002      0.00000               NaN
# 5                     incumbent_r002      0.00000               NaN
# 6             r021_city_night_recall      0.00020          0.000200
# 7   r019_residential_night_precision      0.00115          0.001150
# 8   r006_scaled04_best01_rand000_050      0.00105          0.001050
# 9   r006_scaled04_best01_rand000_050      0.00120          0.001200
# 10  r019_residential_night_precision      0.00145          0.001450
# 11                   r003_tiny_all_s      0.00105          0.001050
# 12  r004_scaled04_best01_rand000_075      0.00015          0.000393
# 13       r004_head_repair_moe_target      0.00000          0.000112
# 14  r019_residential_night_precision     -0.00035          0.000417
# 15  r004_scaled04_best01_rand000_075     -0.00025          0.000217
# 16  r015_residential_night_precision     -0.00095          0.000160
# 17  r019_residential_night_precision     -0.00105          0.000844
# 18  r004_scaled04_best01_rand000_075      0.00015          0.000316
# 19  r019_residential_night_precision      0.00115          0.000783
# 20  r004_scaled04_best01_rand000_075      0.00100          0.000421
# 21  r019_residential_night_precision      0.00105          0.000629
# 22  r004_scaled04_best01_rand000_075      0.00105          0.000385
# 23  r015_residential_night_precision      0.00030          0.000139
# 24  r004_scaled04_best01_rand000_075      0.00015          0.000398
# 25  r019_residential_night_precision      0.00115          0.000750
# 26  r006_scaled04_best01_rand000_050      0.00105          0.000496
# 27  r019_residential_night_precision      0.00105          0.000654
# 28  r004_scaled04_best01_rand000_075      0.00105          0.000418
# 29  r004_scaled04_best01_rand000_075      0.00005          0.000065
#
#     domain_score  total_score
# 0        0.54765      0.57455
# 1        0.38425      0.57455
# 2        0.63090      0.57455
# 3        0.46455      0.57455
# 4        0.67155      0.57455
# 5        0.47745      0.57455
# 6        0.63110      0.57455
# 7        0.46570      0.57455
# 8        0.54870      0.57410
# 9        0.38545      0.57410
# 10       0.67300      0.57455
# 11       0.47850      0.57350
# 12       0.63105      0.57455
# 13       0.46455      0.57450
# 14       0.54730      0.57455
# 15       0.38400      0.57455
# 16       0.67060      0.57355
# 17       0.47640      0.57455
# 18       0.63105      0.57455
# 19       0.46570      0.57455
# 20       0.54865      0.57455
# 21       0.38530      0.57455
# 22       0.67260      0.57455
# 23       0.47775      0.57355
# 24       0.63105      0.57455
# 25       0.46570      0.57455
# 26       0.54870      0.57410
# 27       0.38530      0.57455
# 28       0.67260      0.57455
# 29       0.47750      0.57455
# # DQA-SoftMoX 14 Domain-Calibrated Delta Judger
#
# - created_utc: 2026-05-14T04:03:53.633884+00:00
# - rows: 150
# - max_total_drop: 0.0011
# - total_drop_penalty: 0.15
# - structure domain-CV delta MAE: 0.000481
# - structure label-CV delta MAE: 0.000320
# - fixed-pool domain-CV delta MAE: 0.000487
# - fixed-pool label-CV delta MAE: 0.000297
#
# ## Policy Summary
#
# | policy | mean | day | night | worst | DRO | night mAP50 |
# |---|---:|---:|---:|---:|---:|---:|
# | incumbent_r002 | 0.52939 | 0.61670 | 0.44208 | 0.38425 | 0.46544 | 0.358 |
# | oracle_policy | 0.53041 | 0.61760 | 0.44322 | 0.38545 | 0.46654 | 0.359 |
# | domain_cv_delta_policy | 0.52898 | 0.61632 | 0.44165 | 0.38400 | 0.46505 | 0.358 |
# | fitted_structure_delta_policy **best learned** | 0.53017 | 0.61743 | 0.44292 | 0.38530 | 0.46630 | 0.359 |
# | fixed_pool_memorized_delta_policy | 0.53014 | 0.61745 | 0.44283 | 0.38530 | 0.46625 | 0.358 |
#
# ## Selected Candidates
#
# | policy | domain | selected | actual delta | predicted delta | score | total |
# |---|---|---|---:|---:|---:|---:|
# | oracle_policy | citystreet_day | r021_city_night_recall | +0.00020 | +0.00020 | 0.63110 | 0.57455 |
# | oracle_policy | citystreet_night | r019_residential_night_precision | +0.00115 | +0.00115 | 0.46570 | 0.57455 |
# | oracle_policy | highway_day | r006_scaled04_best01_rand000_050 | +0.00105 | +0.00105 | 0.54870 | 0.57410 |
# | oracle_policy | highway_night | r006_scaled04_best01_rand000_050 | +0.00120 | +0.00120 | 0.38545 | 0.57410 |
# | oracle_policy | residential_day | r019_residential_night_precision | +0.00145 | +0.00145 | 0.67300 | 0.57455 |
# | oracle_policy | residential_night | r003_tiny_all_s | +0.00105 | +0.00105 | 0.47850 | 0.57350 |
# | domain_cv_delta_policy | citystreet_day | r004_scaled04_best01_rand000_075 | +0.00015 | +0.00039 | 0.63105 | 0.57455 |
# | domain_cv_delta_policy | citystreet_night | r004_head_repair_moe_target | +0.00000 | +0.00011 | 0.46455 | 0.57450 |
# | domain_cv_delta_policy | highway_day | r019_residential_night_precision | -0.00035 | +0.00042 | 0.54730 | 0.57455 |
# | domain_cv_delta_policy | highway_night | r004_scaled04_best01_rand000_075 | -0.00025 | +0.00022 | 0.38400 | 0.57455 |
# | domain_cv_delta_policy | residential_day | r015_residential_night_precision | -0.00095 | +0.00016 | 0.67060 | 0.57355 |
# | domain_cv_delta_policy | residential_night | r019_residential_night_precision | -0.00105 | +0.00084 | 0.47640 | 0.57455 |
# | fitted_structure_delta_policy | citystreet_day | r004_scaled04_best01_rand000_075 | +0.00015 | +0.00032 | 0.63105 | 0.57455 |
# | fitted_structure_delta_policy | citystreet_night | r019_residential_night_precision | +0.00115 | +0.00078 | 0.46570 | 0.57455 |
# | fitted_structure_delta_policy | highway_day | r004_scaled04_best01_rand000_075 | +0.00100 | +0.00042 | 0.54865 | 0.57455 |
# | fitted_structure_delta_policy | highway_night | r019_residential_night_precision | +0.00105 | +0.00063 | 0.38530 | 0.57455 |
# | fitted_structure_delta_policy | residential_day | r004_scaled04_best01_rand000_075 | +0.00105 | +0.00039 | 0.67260 | 0.57455 |
# | fitted_structure_delta_policy | residential_night | r015_residential_night_precision | +0.00030 | +0.00014 | 0.47775 | 0.57355 |
# | fixed_pool_memorized_delta_policy | citystreet_day | r004_scaled04_best01_rand000_075 | +0.00015 | +0.00040 | 0.63105 | 0.57455 |
# | fixed_pool_memorized_delta_policy | citystreet_night | r019_residential_night_precision | +0.00115 | +0.00075 | 0.46570 | 0.57455 |
# | fixed_pool_memorized_delta_policy | highway_day | r006_scaled04_best01_rand000_050 | +0.00105 | +0.00050 | 0.54870 | 0.57410 |
# | fixed_pool_memorized_delta_policy | highway_night | r019_residential_night_precision | +0.00105 | +0.00065 | 0.38530 | 0.57455 |
# | fixed_pool_memorized_delta_policy | residential_day | r004_scaled04_best01_rand000_075 | +0.00105 | +0.00042 | 0.67260 | 0.57455 |
# | fixed_pool_memorized_delta_policy | residential_night | r004_scaled04_best01_rand000_075 | +0.00005 | +0.00006 | 0.47750 | 0.57455 |
#
# ## Codex Goal Scores
#
# - experiment_env: 94/100
# - root_cause_analysis: 91/100
# - judge_stability: 91/100
# - accuracy_improvement: 81/100
# - final_goal: 87/100
#
# ## Takeaway
#
# Learning deltas over the incumbent is much better aligned with the actual decision: which candidate should replace the incumbent for a fixed domain.  The fixed-pool policy is deployable in the current benchmark because the candidate pool is finite and generated by our own self-training loop.  If this still does not reach the target, the next loop should create stronger candidates, not only a better selector.
