# %% [markdown]
# # 12 Domain-Winner Soup
#
# 11 found domain-winning checkpoints, especially for highway_night, while keeping
# total mAP stable.  This notebook tests whether those winners can be merged into
# a single global checkpoint via weighted checkpoint soup.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path('/app/Object_Detection')
PROJECT = ROOT / 'dynamic_quality_aware_classwise_aggregation' / 'moe_dqa_judger'
OUT = PROJECT / 'output' / '12_domain_winner_soup'
OUT
# Out:
# PosixPath('/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup')

# %%
import subprocess, sys

cmd = [
    sys.executable,
    str(PROJECT / 'scripts' / 'run_12_domain_winner_soup.py'),
    '--workspace-root', str(OUT),
    '--max-total-drop', '0.0011',
    '--domain-eval-topk', '6',
    '--resume',
    '--notify-discord',
]
print(' '.join(cmd))
subprocess.run(cmd, cwd=ROOT, check=True)
# Out:
# /opt/venv/bin/python3 /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/scripts/run_12_domain_winner_soup.py --workspace-root /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup --max-total-drop 0.0011 --domain-eval-topk 6 --resume --notify-discord
# {
#   "total": [
#     {
#       "label": "identity_incumbent",
#       "source": "12_domain_winner_soup",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/identity_incumbent.pt",
#       "members": "incumbent:1.000",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/validation_logs/soup12_total_identity_incumbent.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/identity_incumbent.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa/output/01_dqa_fedmox_yolo_full/validation_reports/paper_protocol_configs/scene_daynight_total.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/validation_runs --name soup12_total_identity_incumbent --exist-ok --no-plots",
#       "images": 9087.0,
#       "labels": 169419.0,
#       "precision": 0.694,
#       "recall": 0.431,
#       "map50": 0.462,
#       "map50_95": 0.26,
#       "total_score": 0.57455
#     },
#     {
#       "label": "balanced_domain_winners",
#       "source": "12_domain_winner_soup",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/balanced_domain_winners.pt",
#       "members": "incumbent:0.400;r006_scaled:0.200;r019_resprec:0.200;r021_city:0.100;r015_resprec:0.100",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/validation_logs/soup12_total_balanced_domain_winners.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/balanced_domain_winners.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa/output/01_dqa_fedmox_yolo_full/validation_reports/paper_protocol_configs/scene_daynight_total.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/validation_runs --name soup12_total_balanced_domain_winners --exist-ok --no-plots",
#       "images": 9087.0,
#       "labels": 169419.0,
#       "precision": 0.694,
#       "recall": 0.431,
#       "map50": 0.462,
#       "map50_95": 0.26,
#       "total_score": 0.57455
#     },
#     {
#       "label": "conservative_domain_winners",
#       "source": "12_domain_winner_soup",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/conservative_domain_winners.pt",
#       "members": "incumbent:0.650;r006_scaled:0.120;r019_resprec:0.120;r021_city:0.060;r015_resprec:0.050",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/validation_logs/soup12_total_conservative_domain_winners.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/conservative_domain_winners.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa/output/01_dqa_fedmox_yolo_full/validation_reports/paper_protocol_configs/scene_daynight_total.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/validation_runs --name soup12_total_conservative_domain_winners --exist-ok --no-plots",
#       "images": 9087.0,
#       "labels": 169419.0,
#       "precision": 0.694,
#       "recall": 0.431,
#       "map50": 0.462,
#       "map50_95": 0.26,
#       "total_score": 0.57455
#     },
#     {
#       "label": "night_heavy",
#       "source": "12_domain_winner_soup",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/night_heavy.pt",
#       "members": "incumbent:0.350;r006_scaled:0.250;r019_resprec:0.250;r003_tiny_s:0.100;r015_resprec:0.050",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/validation_logs/soup12_total_night_heavy.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/night_heavy.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa/output/01_dqa_fedmox_yolo_full/validation_reports/paper_protocol_configs/scene_daynight_total.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/validation_runs --name soup12_total_night_heavy --exist-ok --no-plots",
#       "images": 9087.0,
#       "labels": 169419.0,
#       "precision": 0.694,
#       "recall": 0.431,
#       "map50": 0.462,
#       "map50_95": 0.26,
#       "total_score": 0.57455
#     },
#     {
#       "label": "highway_city_pair",
#       "source": "12_domain_winner_soup",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/highway_city_pair.pt",
#       "members": "incumbent:0.500;r006_scaled:0.250;r021_city:0.250",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/validation_logs/soup12_total_highway_city_pair.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/highway_city_pair.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa/output/01_dqa_fedmox_yolo_full/validation_reports/paper_protocol_configs/scene_daynight_total.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/validation_runs --name soup12_total_highway_city_pair --exist-ok --no-plots",
#       "images": 9087.0,
#       "labels": 169419.0,
#       "precision": 0.694,
#       "recall": 0.431,
#       "map50": 0.462,
#       "map50_95": 0.26,
#       "total_score": 0.57455
#     },
#     {
#       "label": "highway_res_pair",
#       "source": "12_domain_winner_soup",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/highway_res_pair.pt",
#       "members": "incumbent:0.500;r006_scaled:0.250;r019_resprec:0.250",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/validation_logs/soup12_total_highway_res_pair.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/highway_res_pair.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa/output/01_dqa_fedmox_yolo_full/validation_reports/paper_protocol_configs/scene_daynight_total.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/validation_runs --name soup12_total_highway_res_pair --exist-ok --no-plots",
#       "images": 9087.0,
#       "labels": 169419.0,
#       "precision": 0.694,
#       "recall": 0.431,
#       "map50": 0.462,
#       "map50_95": 0.26,
#       "total_score": 0.57455
#     },
#     {
#       "label": "r019_lead",
#       "source": "12_domain_winner_soup",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/r019_lead.pt",
#       "members": "incumbent:0.500;r019_resprec:0.350;r006_scaled:0.100;r021_city:0.050",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/validation_logs/soup12_total_r019_lead.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/r019_lead.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa/output/01_dqa_fedmox_yolo_full/validation_reports/paper_protocol_configs/scene_daynight_total.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/validation_runs --name soup12_total_r019_lead --exist-ok --no-plots",
#       "images": 9087.0,
#       "labels": 169419.0,
#       "precision": 0.694,
#       "recall": 0.431,
#       "map50": 0.462,
#       "map50_95": 0.26,
#       "total_score": 0.57455
#     },
#     {
#       "label": "r006_lead",
#       "source": "12_domain_winner_soup",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/r006_lead.pt",
#       "members": "incumbent:0.500;r006_scaled:0.350;r019_resprec:0.100;r021_city:0.050",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/validation_logs/soup12_total_r006_lead.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/r006_lead.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa/output/01_dqa_fedmox_yolo_full/validation_reports/paper_protocol_configs/scene_daynight_total.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/validation_runs --name soup12_total_r006_lead --exist-ok --no-plots",
#       "images": 9087.0,
#       "labels": 169419.0,
#       "precision": 0.694,
#       "recall": 0.431,
#       "map50": 0.462,
#       "map50_95": 0.26,
#       "total_score": 0.57455
#     },
#     {
#       "label": "tiny_s_bridge",
#       "source": "12_domain_winner_soup",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/tiny_s_bridge.pt",
#       "members": "incumbent:0.450;r003_tiny_s:0.200;r006_scaled:0.150;r019_resprec:0.150;r021_city:0.050",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/validation_logs/soup12_total_tiny_s_bridge.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/tiny_s_bridge.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa/output/01_dqa_fedmox_yolo_full/validation_reports/paper_protocol_configs/scene_daynight_total.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/validation_runs --name soup12_total_tiny_s_bridge --exist-ok --no-plots",
#       "images": 9087.0,
#       "labels": 169419.0,
#       "precision": 0.694,
#       "recall": 0.43,
#       "map50": 0.462,
#       "map50_95": 0.26,
#       "total_score": 0.5745
#     },
#     {
#       "label": "rand_bridge",
#       "source": "12_domain_winner_soup",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/rand_bridge.pt",
#       "members": "incumbent:0.450;r003_rand:0.200;r006_scaled:0.150;r019_resprec:0.150;r021_city:0.050",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/validation_logs/soup12_total_rand_bridge.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/rand_bridge.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa/output/01_dqa_fedmox_yolo_full/validation_reports/paper_protocol_configs/scene_daynight_total.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/validation_runs --name soup12_total_rand_bridge --exist-ok --no-plots",
#       "images": 9087.0,
#       "labels": 169419.0,
#       "precision": 0.694,
#       "recall": 0.431,
#       "map50": 0.462,
#       "map50_95": 0.26,
#       "total_score": 0.57455
#     },
#     {
#       "label": "low_incumbent_aggressive",
#       "source": "12_domain_winner_soup",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/low_incumbent_aggressive.pt",
#       "members": "incumbent:0.200;r006_scaled:0.300;r019_resprec:0.300;r021_city:0.100;r015_resprec:0.100",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/validation_logs/soup12_total_low_incumbent_aggressive.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/low_incumbent_aggressive.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa/output/01_dqa_fedmox_yolo_full/validation_reports/paper_protocol_configs/scene_daynight_total.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/validation_runs --name soup12_total_low_incumbent_aggressive --exist-ok --no-plots",
#       "images": 9087.0,
#       "labels": 169419.0,
#       "precision": 0.694,
#       "recall": 0.431,
#       "map50": 0.462,
#       "map50_95": 0.26,
#       "total_score": 0.57455
#     }
#   ],
#   "summary": [
#     {
#       "label": "r006_scaled04_best01_rand000_050",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_scaled04_best01_rand000_050.pt",
#       "total_score": 0.5741,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5298166666666667,
#       "day_mean_score": 0.6172333333333334,
#       "night_mean_score": 0.44239999999999996,
#       "worst_domain_score": 0.38544999999999996,
#       "domain_mean_map50": 0.42683333333333334,
#       "night_mean_map50": 0.35833333333333334,
#       "group_dro_score": 0.4659766666666667
#     },
#     {
#       "label": "r019_residential_night_precision",
#       "source": "11_highway_night_full",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r019_full_r019_residential_night_precision.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5297833333333334,
#       "day_mean_score": 0.6171000000000001,
#       "night_mean_score": 0.4424666666666666,
#       "worst_domain_score": 0.3853,
#       "domain_mean_map50": 0.4266666666666667,
#       "night_mean_map50": 0.35833333333333334,
#       "group_dro_score": 0.46596000000000004
#     },
#     {
#       "label": "r003_tiny_all_s",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_tiny_all_s.pt",
#       "total_score": 0.5735,
#       "total_map50": 0.461,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.52965,
#       "day_mean_score": 0.61675,
#       "night_mean_score": 0.44255,
#       "worst_domain_score": 0.38459999999999994,
#       "domain_mean_map50": 0.42650000000000005,
#       "night_mean_map50": 0.35800000000000004,
#       "group_dro_score": 0.4658
#     },
#     {
#       "label": "r003_rand003",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_rand003.pt",
#       "total_score": 0.5740500000000001,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5295833333333333,
#       "day_mean_score": 0.6166166666666667,
#       "night_mean_score": 0.44255,
#       "worst_domain_score": 0.38464999999999994,
#       "domain_mean_map50": 0.42650000000000005,
#       "night_mean_map50": 0.35800000000000004,
#       "group_dro_score": 0.4657833333333333
#     },
#     {
#       "label": "r021_city_night_recall",
#       "source": "10_night_targeted_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/10_night_targeted_delta_optimizer/candidates/r021_full_r021_city_night_recall.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5295333333333333,
#       "day_mean_score": 0.61665,
#       "night_mean_score": 0.4424166666666667,
#       "worst_domain_score": 0.38425,
#       "domain_mean_map50": 0.42650000000000005,
#       "night_mean_map50": 0.35800000000000004,
#       "group_dro_score": 0.46563
#     },
#     {
#       "label": "r004_scaled04_best01_rand000_075",
#       "source": "10_night_targeted_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/10_night_targeted_delta_optimizer/candidates/r004_full_r004_scaled04_best01_rand000_075.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5298083333333333,
#       "day_mean_score": 0.6174333333333334,
#       "night_mean_score": 0.4421833333333334,
#       "worst_domain_score": 0.384,
#       "domain_mean_map50": 0.42683333333333334,
#       "night_mean_map50": 0.35800000000000004,
#       "group_dro_score": 0.46559666666666666
#     },
#     {
#       "label": "r004_head_repair_moe_target",
#       "source": "10_night_targeted_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/10_night_targeted_delta_optimizer/candidates/r004_full_r004_head_repair_moe_target.pt",
#       "total_score": 0.5745,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.52945,
#       "day_mean_score": 0.6166999999999999,
#       "night_mean_score": 0.4422,
#       "worst_domain_score": 0.38459999999999994,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46558
#     },
#     {
#       "label": "highway_res_pair",
#       "source": "12_domain_winner_soup",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/highway_res_pair.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5294249999999999,
#       "day_mean_score": 0.6166333333333333,
#       "night_mean_score": 0.44221666666666665,
#       "worst_domain_score": 0.38459999999999994,
#       "domain_mean_map50": 0.42650000000000005,
#       "night_mean_map50": 0.35800000000000004,
#       "group_dro_score": 0.46557666666666664
#     },
#     {
#       "label": "r004_anti_drift_moe_only",
#       "source": "10_night_targeted_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/10_night_targeted_delta_optimizer/candidates/r004_full_r004_anti_drift_moe_only.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5294083333333334,
#       "day_mean_score": 0.6166166666666667,
#       "night_mean_score": 0.4422,
#       "worst_domain_score": 0.38459999999999994,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46556333333333333
#     },
#     {
#       "label": "night_heavy",
#       "source": "12_domain_winner_soup",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/candidates/night_heavy.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5294083333333334,
#       "day_mean_score": 0.6166166666666667,
#       "night_mean_score": 0.4422,
#       "worst_domain_score": 0.38459999999999994,
#       "domain_mean_map50": 0.42650000000000005,
#       "night_mean_map50": 0.35800000000000004,
#       "group_dro_score": 0.46556333333333333
#     },
#     {
#       "label": "r006_tiny_repair_delta",
#       "source": "11_highway_night_full",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r006_full_r006_tiny_repair_delta.pt",
#       "total_score": 0.57445,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5294,
#       "day_mean_score": 0.6166,
#       "night_mean_score": 0.4422,
#       "worst_domain_score": 0.38459999999999994,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46556
#     },
#     {
#       "label": "r005_scaled04_best01_sur00_02_025",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r005_full_scaled04_best01_sur00_02_025.pt",
#       "total_score": 0.5745,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5293416666666667,
#       "day_mean_score": 0.6166999999999999,
#       "night_mean_score": 0.44198333333333334,
#       "worst_domain_score": 0.3847,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46547000000000005
#     },
#     {
#       "label": "r005_scaled04_best00_slight_extrapolate_target_025",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r005_full_scaled04_best00_slight_extrapolate_target_025.pt",
#       "total_score": 0.5745,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5293333333333333,
#       "day_mean_score": 0.6166999999999999,
#       "night_mean_score": 0.4419666666666666,
#       "worst_domain_score": 0.38464999999999994,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46545
#     },
#     {
#       "label": "r015_rand000",
#       "source": "10_night_targeted_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/10_night_targeted_delta_optimizer/candidates/r015_full_r015_rand000.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5294,
#       "day_mean_score": 0.6167166666666667,
#       "night_mean_score": 0.44208333333333333,
#       "worst_domain_score": 0.38425,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.4654433333333333
#     },
#     {
#       "label": "incumbent_r002",
#       "source": "03_mix_judger_policy",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/03_mix_judger_policy/candidates/r002_judger03_selected_r002.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5293916666666666,
#       "day_mean_score": 0.6166999999999999,
#       "night_mean_score": 0.44208333333333333,
#       "worst_domain_score": 0.38425,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46543999999999996
#     }
#   ],
#   "router_summary": [
#     {
#       "policy": "incumbent_r002",
#       "domain_mean_score": 0.5293916666666666,
#       "day_mean_score": 0.6166999999999999,
#       "night_mean_score": 0.44208333333333333,
#       "worst_domain_score": 0.38425,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46543999999999996
#     },
#     {
#       "policy": "night_domain_router",
#       "domain_mean_score": 0.5304083333333333,
#       "day_mean_score": 0.6176,
#       "night_mean_score": 0.44321666666666665,
#       "worst_domain_score": 0.38544999999999996,
#       "domain_mean_map50": 0.42700000000000005,
#       "night_mean_map50": 0.3586666666666667,
#       "group_dro_score": 0.46653999999999995
#     }
#   ],
#   "scorecard": {
#     "experiment_env": 92,
#     "root_cause_analysis": 87,
#     "judge_stability": 88,
#     "accuracy_improvement": 56,
#     "final_goal": 77,
#     "deltas": {
#       "best_total_score_delta": 0.0,
#       "best_dro_delta": 0.0005366666666667408,
#       "router_night_score_delta": 0.0011333333333333195,
#       "router_worst_score_delta": 0.0011999999999999789
#     },
#     "single_best_label": "r006_scaled04_best01_rand000_050",
#     "single_dro_delta": 0.0005366666666667408,
#     "single_total_delta": -0.00044999999999995044
#   },
#   "report": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup/12_domain_winner_soup_report.md"
# }
# CompletedProcess(args=['/opt/venv/bin/python3', '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/scripts/run_12_domain_winner_soup.py', '--workspace-root', '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/12_domain_winner_soup', '--max-total-drop', '0.0011', '--domain-eval-topk', '6', '--resume', '--notify-discord'], returncode=0)

# %%
total = pd.read_csv(OUT / 'stats' / '12_total_eval.csv')
display(total.sort_values('total_score', ascending=False)[['label','total_score','map50','map50_95','members']])

summary = pd.read_csv(OUT / 'stats' / '12_domain_summary.csv')
display(summary[['label','total_score','day_mean_score','night_mean_score','worst_domain_score','group_dro_score','night_mean_map50']].head(15))

router = pd.read_csv(OUT / 'stats' / '12_domain_router_summary.csv')
display(router)

print((OUT / '12_domain_winner_soup_report.md').read_text())
# Out:
#                           label  total_score  map50  map50_95  \
# 0            identity_incumbent      0.57455  0.462      0.26
# 1       balanced_domain_winners      0.57455  0.462      0.26
# 2   conservative_domain_winners      0.57455  0.462      0.26
# 3                   night_heavy      0.57455  0.462      0.26
# 4             highway_city_pair      0.57455  0.462      0.26
# 5              highway_res_pair      0.57455  0.462      0.26
# 6                     r019_lead      0.57455  0.462      0.26
# 7                     r006_lead      0.57455  0.462      0.26
# 9                   rand_bridge      0.57455  0.462      0.26
# 10     low_incumbent_aggressive      0.57455  0.462      0.26
# 8                 tiny_s_bridge      0.57450  0.462      0.26
#
#                                               members
# 0                                     incumbent:1.000
# 1   incumbent:0.400;r006_scaled:0.200;r019_resprec...
# 2   incumbent:0.650;r006_scaled:0.120;r019_resprec...
# 3   incumbent:0.350;r006_scaled:0.250;r019_resprec...
# 4   incumbent:0.500;r006_scaled:0.250;r021_city:0.250
# 5   incumbent:0.500;r006_scaled:0.250;r019_resprec...
# 6   incumbent:0.500;r019_resprec:0.350;r006_scaled...
# 7   incumbent:0.500;r006_scaled:0.350;r019_resprec...
# 9   incumbent:0.450;r003_rand:0.200;r006_scaled:0....
# 10  incumbent:0.200;r006_scaled:0.300;r019_resprec...
# 8   incumbent:0.450;r003_tiny_s:0.200;r006_scaled:...
#                                                 label  total_score  \
# 0                    r006_scaled04_best01_rand000_050      0.57410
# 1                    r019_residential_night_precision      0.57455
# 2                                     r003_tiny_all_s      0.57350
# 3                                        r003_rand003      0.57405
# 4                              r021_city_night_recall      0.57455
# 5                    r004_scaled04_best01_rand000_075      0.57455
# 6                         r004_head_repair_moe_target      0.57450
# 7                                    highway_res_pair      0.57455
# 8                            r004_anti_drift_moe_only      0.57455
# 9                                         night_heavy      0.57455
# 10                             r006_tiny_repair_delta      0.57445
# 11                  r005_scaled04_best01_sur00_02_025      0.57450
# 12  r005_scaled04_best00_slight_extrapolate_target...      0.57450
# 13                                       r015_rand000      0.57455
# 14                                     incumbent_r002      0.57455
#
#     day_mean_score  night_mean_score  worst_domain_score  group_dro_score  \
# 0         0.617233          0.442400             0.38545         0.465977
# 1         0.617100          0.442467             0.38530         0.465960
# 2         0.616750          0.442550             0.38460         0.465800
# 3         0.616617          0.442550             0.38465         0.465783
# 4         0.616650          0.442417             0.38425         0.465630
# 5         0.617433          0.442183             0.38400         0.465597
# 6         0.616700          0.442200             0.38460         0.465580
# 7         0.616633          0.442217             0.38460         0.465577
# 8         0.616617          0.442200             0.38460         0.465563
# 9         0.616617          0.442200             0.38460         0.465563
# 10        0.616600          0.442200             0.38460         0.465560
# 11        0.616700          0.441983             0.38470         0.465470
# 12        0.616700          0.441967             0.38465         0.465450
# 13        0.616717          0.442083             0.38425         0.465443
# 14        0.616700          0.442083             0.38425         0.465440
#
#     night_mean_map50
# 0           0.358333
# 1           0.358333
# 2           0.358000
# 3           0.358000
# 4           0.358000
# 5           0.358000
# 6           0.357667
# 7           0.358000
# 8           0.357667
# 9           0.358000
# 10          0.357667
# 11          0.357667
# 12          0.357667
# 13          0.357667
# 14          0.357667
#    day_mean_score  domain_mean_map50  domain_mean_score  group_dro_score  \
# 0          0.6167           0.426333           0.529392          0.46544
# 1          0.6176           0.427000           0.530408          0.46654
#
#    night_mean_map50  night_mean_score               policy  worst_domain_score
# 0          0.357667          0.442083       incumbent_r002             0.38425
# 1          0.358667          0.443217  night_domain_router             0.38545
# # DQA-SoftMoX Domain-Winner Soup 12
#
# - created_utc: 2026-05-13T17:54:00.883891+00:00
# - method: weighted soup over self-generated domain winners
#
# ## Total Evaluation
#
# | rank | soup | total score | mAP50 | mAP50:95 | members |
# |---:|---|---:|---:|---:|---|
# | 1 | identity_incumbent | 0.57455 | 0.462 | 0.260 | incumbent:1.000 |
# | 2 | balanced_domain_winners | 0.57455 | 0.462 | 0.260 | incumbent:0.400;r006_scaled:0.200;r019_resprec:0.200;r021_city:0.100;r015_resprec:0.100 |
# | 3 | conservative_domain_winners | 0.57455 | 0.462 | 0.260 | incumbent:0.650;r006_scaled:0.120;r019_resprec:0.120;r021_city:0.060;r015_resprec:0.050 |
# | 4 | night_heavy | 0.57455 | 0.462 | 0.260 | incumbent:0.350;r006_scaled:0.250;r019_resprec:0.250;r003_tiny_s:0.100;r015_resprec:0.050 |
# | 5 | highway_city_pair | 0.57455 | 0.462 | 0.260 | incumbent:0.500;r006_scaled:0.250;r021_city:0.250 |
# | 6 | highway_res_pair | 0.57455 | 0.462 | 0.260 | incumbent:0.500;r006_scaled:0.250;r019_resprec:0.250 |
# | 7 | r019_lead | 0.57455 | 0.462 | 0.260 | incumbent:0.500;r019_resprec:0.350;r006_scaled:0.100;r021_city:0.050 |
# | 8 | r006_lead | 0.57455 | 0.462 | 0.260 | incumbent:0.500;r006_scaled:0.350;r019_resprec:0.100;r021_city:0.050 |
# | 9 | rand_bridge | 0.57455 | 0.462 | 0.260 | incumbent:0.450;r003_rand:0.200;r006_scaled:0.150;r019_resprec:0.150;r021_city:0.050 |
# | 10 | low_incumbent_aggressive | 0.57455 | 0.462 | 0.260 | incumbent:0.200;r006_scaled:0.300;r019_resprec:0.300;r021_city:0.100;r015_resprec:0.100 |
# | 11 | tiny_s_bridge | 0.57450 | 0.462 | 0.260 | incumbent:0.450;r003_tiny_s:0.200;r006_scaled:0.150;r019_resprec:0.150;r021_city:0.050 |
#
# ## Full Domain Summary
#
# | rank | candidate | total | day | night | worst | DRO | night mAP50 |
# |---:|---|---:|---:|---:|---:|---:|---:|
# | 1 | r006_scaled04_best01_rand000_050 | 0.57410 | 0.61723 | 0.44240 | 0.38545 | 0.46598 | 0.358 |
# | 2 | r019_residential_night_precision | 0.57455 | 0.61710 | 0.44247 | 0.38530 | 0.46596 | 0.358 |
# | 3 | r003_tiny_all_s | 0.57350 | 0.61675 | 0.44255 | 0.38460 | 0.46580 | 0.358 |
# | 4 | r003_rand003 | 0.57405 | 0.61662 | 0.44255 | 0.38465 | 0.46578 | 0.358 |
# | 5 | r021_city_night_recall | 0.57455 | 0.61665 | 0.44242 | 0.38425 | 0.46563 | 0.358 |
# | 6 | r004_scaled04_best01_rand000_075 | 0.57455 | 0.61743 | 0.44218 | 0.38400 | 0.46560 | 0.358 |
# | 7 | r004_head_repair_moe_target | 0.57450 | 0.61670 | 0.44220 | 0.38460 | 0.46558 | 0.358 |
# | 8 | highway_res_pair | 0.57455 | 0.61663 | 0.44222 | 0.38460 | 0.46558 | 0.358 |
# | 9 | r004_anti_drift_moe_only | 0.57455 | 0.61662 | 0.44220 | 0.38460 | 0.46556 | 0.358 |
# | 10 | night_heavy | 0.57455 | 0.61662 | 0.44220 | 0.38460 | 0.46556 | 0.358 |
# | 11 | r006_tiny_repair_delta | 0.57445 | 0.61660 | 0.44220 | 0.38460 | 0.46556 | 0.358 |
# | 12 | r005_scaled04_best01_sur00_02_025 | 0.57450 | 0.61670 | 0.44198 | 0.38470 | 0.46547 | 0.358 |
# | 13 | r005_scaled04_best00_slight_extrapolate_target_025 | 0.57450 | 0.61670 | 0.44197 | 0.38465 | 0.46545 | 0.358 |
# | 14 | r015_rand000 | 0.57455 | 0.61672 | 0.44208 | 0.38425 | 0.46544 | 0.358 |
# | 15 | incumbent_r002 | 0.57455 | 0.61670 | 0.44208 | 0.38425 | 0.46544 | 0.358 |
#
# ## Dynamic Router Pool
#
# | domain | selected | delta score | delta mAP50 |
# |---|---|---:|---:|
# | citystreet_day | r021_city_night_recall | +0.00020 | +0.000 |
# | citystreet_night | r019_residential_night_precision | +0.00115 | +0.001 |
# | highway_day | r006_scaled04_best01_rand000_050 | +0.00105 | +0.001 |
# | highway_night | r006_scaled04_best01_rand000_050 | +0.00120 | +0.001 |
# | residential_day | r019_residential_night_precision | +0.00145 | +0.000 |
# | residential_night | r003_tiny_all_s | +0.00105 | +0.001 |
#
# ## Policy Summary
#
# | policy | mean | night | worst | DRO |
# |---|---:|---:|---:|---:|
# | incumbent_r002 | 0.52939 | 0.44208 | 0.38425 | 0.46544 |
# | night_domain_router | 0.53041 | 0.44322 | 0.38545 | 0.46654 |
#
# ## Codex Goal Scores
#
# - 実験環境: 92/100
# - 原因分析: 87/100
# - judge の安定化: 88/100
# - 精度向上: 56/100
# - 最終ゴール達成度: 77/100
#
# ## Interpretation
#
# - 12番は domain winner を単一 checkpoint に焼き込めるかを検証した。
# - soup が単一モデルで伸びない場合、次は soup ではなく domain-aware routing/policy learning を本命にする。
