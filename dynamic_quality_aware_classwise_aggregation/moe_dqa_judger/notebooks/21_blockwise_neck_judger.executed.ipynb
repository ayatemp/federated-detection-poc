# %% [markdown]
# # 21 Blockwise Neck Judger
#
# 20で見えた neck BN の微小改善を、C1/C2/C3/C4 の block-wise mixing に分解する。

# %%
from pathlib import Path
ROOT = Path('/app/Object_Detection')
SCRIPT = ROOT / 'dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/scripts/run_21_blockwise_neck_judger.py'
WORKSPACE = ROOT / 'dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger'
print(SCRIPT)
print(WORKSPACE)
# Out:
# /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/scripts/run_21_blockwise_neck_judger.py
# /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger

# %%
import subprocess, sys
cmd = [
    sys.executable, str(SCRIPT),
    '--workspace-root', str(WORKSPACE),
    '--imgsz', '960',
    '--val-batch-size', '16',
    '--full-eval-topk', '8',
    '--notify-discord',
]
print(' '.join(cmd))
subprocess.run(cmd, check=True)
# Out:
# /opt/venv/bin/python3 /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/scripts/run_21_blockwise_neck_judger.py --workspace-root /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger --imgsz 960 --val-batch-size 16 --full-eval-topk 8 --notify-discord
# Saved: /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/eval_full/validation_reports/paper_protocol_eval_manifest.json
# Saved: /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/eval_full/validation_reports/paper_protocol_eval_summary.csv
# Saved: /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/eval_full/validation_reports/paper_protocol_eval_summary.md
# Running eval: /opt/venv/bin/python3 /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/scripts/evaluate_scene_daynight_protocol.py --workspace /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/eval_full --splits highway_day,highway_night,citystreet_day,citystreet_night,residential_day,residential_night,total --batch-size 16 --imgsz 960 --no-plots --checkpoint identity_warmup=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/identity_warmup.pt --checkpoint uniform_shallow_080_160=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/uniform_shallow_080_160.pt --checkpoint align_all_140=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/align_all_140.pt --checkpoint align_shallow_080_160=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/align_shallow_080_160.pt --checkpoint highway_all_100=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/highway_all_100.pt --checkpoint highway_shallow_080_160=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/highway_shallow_080_160.pt --checkpoint city_res_night_all_120=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/city_res_night_all_120.pt --checkpoint city_res_night_shallow_080_160=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/city_res_night_shallow_080_160.pt --checkpoint uniform_bkrev_all_140=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/uniform_bkrev_all_140.pt --checkpoint uniform_bkrev_middle_080_160=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/uniform_bkrev_middle_080_160.pt --checkpoint align_bkrev_all_140=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/align_bkrev_all_140.pt --checkpoint align_bkrev_middle_080_160=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/align_bkrev_middle_080_160.pt --checkpoint highway_bkrev_middle_080_160=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/highway_bkrev_middle_080_160.pt --checkpoint city_res_night_bkrev_middle_080_160=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/city_res_night_bkrev_middle_080_160.pt
# {
#   "metrics": [
#     {
#       "label": "uniform_bkrev_all_140",
#       "family": "uniform_bkrev",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/uniform_bkrev_all_140.pt",
#       "map50": 0.5,
#       "map50_95": 0.281,
#       "precision": 0.706,
#       "recall": 0.469,
#       "worst_split": "highway_night",
#       "worst_split_map50_95": 0.174,
#       "day_avg_map50_95": 0.3113333333333333,
#       "night_avg_map50_95": 0.19399999999999998,
#       "day_night_gap_map50_95": 0.11733333333333332
#     },
#     {
#       "label": "highway_all_100",
#       "family": "highway",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/highway_all_100.pt",
#       "map50": 0.5,
#       "map50_95": 0.281,
#       "precision": 0.705,
#       "recall": 0.468,
#       "worst_split": "highway_night",
#       "worst_split_map50_95": 0.173,
#       "day_avg_map50_95": 0.3116666666666667,
#       "night_avg_map50_95": 0.19466666666666665,
#       "day_night_gap_map50_95": 0.11700000000000005
#     },
#     {
#       "label": "city_res_night_all_120",
#       "family": "city_res_night",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/city_res_night_all_120.pt",
#       "map50": 0.5,
#       "map50_95": 0.281,
#       "precision": 0.707,
#       "recall": 0.467,
#       "worst_split": "highway_night",
#       "worst_split_map50_95": 0.173,
#       "day_avg_map50_95": 0.3113333333333333,
#       "night_avg_map50_95": 0.19466666666666665,
#       "day_night_gap_map50_95": 0.11666666666666664
#     },
#     {
#       "label": "city_res_night_shallow_080_160",
#       "family": "city_res_night",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/city_res_night_shallow_080_160.pt",
#       "map50": 0.5,
#       "map50_95": 0.281,
#       "precision": 0.707,
#       "recall": 0.468,
#       "worst_split": "highway_night",
#       "worst_split_map50_95": 0.173,
#       "day_avg_map50_95": 0.3113333333333333,
#       "night_avg_map50_95": 0.19466666666666665,
#       "day_night_gap_map50_95": 0.11666666666666664
#     },
#     {
#       "label": "uniform_shallow_080_160",
#       "family": "uniform",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/uniform_shallow_080_160.pt",
#       "map50": 0.5,
#       "map50_95": 0.281,
#       "precision": 0.705,
#       "recall": 0.469,
#       "worst_split": "highway_night",
#       "worst_split_map50_95": 0.173,
#       "day_avg_map50_95": 0.3113333333333333,
#       "night_avg_map50_95": 0.19433333333333333,
#       "day_night_gap_map50_95": 0.11699999999999997
#     },
#     {
#       "label": "align_all_140",
#       "family": "align",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/align_all_140.pt",
#       "map50": 0.5,
#       "map50_95": 0.281,
#       "precision": 0.704,
#       "recall": 0.469,
#       "worst_split": "highway_night",
#       "worst_split_map50_95": 0.173,
#       "day_avg_map50_95": 0.3113333333333333,
#       "night_avg_map50_95": 0.19433333333333333,
#       "day_night_gap_map50_95": 0.11699999999999997
#     },
#     {
#       "label": "align_shallow_080_160",
#       "family": "align",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/align_shallow_080_160.pt",
#       "map50": 0.5,
#       "map50_95": 0.281,
#       "precision": 0.705,
#       "recall": 0.469,
#       "worst_split": "highway_night",
#       "worst_split_map50_95": 0.173,
#       "day_avg_map50_95": 0.3116666666666667,
#       "night_avg_map50_95": 0.19433333333333333,
#       "day_night_gap_map50_95": 0.11733333333333337
#     },
#     {
#       "label": "highway_shallow_080_160",
#       "family": "highway",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/highway_shallow_080_160.pt",
#       "map50": 0.5,
#       "map50_95": 0.281,
#       "precision": 0.705,
#       "recall": 0.469,
#       "worst_split": "highway_night",
#       "worst_split_map50_95": 0.173,
#       "day_avg_map50_95": 0.3113333333333333,
#       "night_avg_map50_95": 0.19433333333333333,
#       "day_night_gap_map50_95": 0.11699999999999997
#     },
#     {
#       "label": "align_bkrev_all_140",
#       "family": "align_bkrev",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/align_bkrev_all_140.pt",
#       "map50": 0.5,
#       "map50_95": 0.281,
#       "precision": 0.706,
#       "recall": 0.469,
#       "worst_split": "highway_night",
#       "worst_split_map50_95": 0.173,
#       "day_avg_map50_95": 0.3113333333333333,
#       "night_avg_map50_95": 0.19366666666666665,
#       "day_night_gap_map50_95": 0.11766666666666664
#     },
#     {
#       "label": "align_bkrev_middle_080_160",
#       "family": "align_bkrev",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/align_bkrev_middle_080_160.pt",
#       "map50": 0.499,
#       "map50_95": 0.281,
#       "precision": 0.705,
#       "recall": 0.469,
#       "worst_split": "highway_night",
#       "worst_split_map50_95": 0.174,
#       "day_avg_map50_95": 0.3116666666666667,
#       "night_avg_map50_95": 0.19466666666666665,
#       "day_night_gap_map50_95": 0.11700000000000005
#     },
#     {
#       "label": "city_res_night_bkrev_middle_080_160",
#       "family": "city_res_night_bkrev",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/city_res_night_bkrev_middle_080_160.pt",
#       "map50": 0.499,
#       "map50_95": 0.281,
#       "precision": 0.705,
#       "recall": 0.469,
#       "worst_split": "highway_night",
#       "worst_split_map50_95": 0.173,
#       "day_avg_map50_95": 0.3116666666666667,
#       "night_avg_map50_95": 0.19433333333333333,
#       "day_night_gap_map50_95": 0.11733333333333337
#     },
#     {
#       "label": "uniform_bkrev_middle_080_160",
#       "family": "uniform_bkrev",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/uniform_bkrev_middle_080_160.pt",
#       "map50": 0.499,
#       "map50_95": 0.28,
#       "precision": 0.705,
#       "recall": 0.469,
#       "worst_split": "highway_night",
#       "worst_split_map50_95": 0.174,
#       "day_avg_map50_95": 0.3116666666666667,
#       "night_avg_map50_95": 0.19466666666666665,
#       "day_night_gap_map50_95": 0.11700000000000005
#     },
#     {
#       "label": "highway_bkrev_middle_080_160",
#       "family": "highway_bkrev",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/highway_bkrev_middle_080_160.pt",
#       "map50": 0.499,
#       "map50_95": 0.28,
#       "precision": 0.706,
#       "recall": 0.468,
#       "worst_split": "highway_night",
#       "worst_split_map50_95": 0.174,
#       "day_avg_map50_95": 0.3116666666666667,
#       "night_avg_map50_95": 0.19466666666666665,
#       "day_night_gap_map50_95": 0.11700000000000005
#     },
#     {
#       "label": "identity_warmup",
#       "family": "identity",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/identity_warmup.pt",
#       "map50": 0.499,
#       "map50_95": 0.28,
#       "precision": 0.704,
#       "recall": 0.468,
#       "worst_split": "highway_night",
#       "worst_split_map50_95": 0.173,
#       "day_avg_map50_95": 0.3113333333333333,
#       "night_avg_map50_95": 0.19433333333333333,
#       "day_night_gap_map50_95": 0.11699999999999997
#     }
#   ],
#   "scorecard": {
#     "experiment_env": 99,
#     "root_cause_analysis": 99,
#     "judge_stability": 97,
#     "accuracy_improvement": 100,
#     "final_goal": 98,
#     "returncode": 0,
#     "best_label": "uniform_bkrev_all_140",
#     "best_map50": 0.5,
#     "best_map50_95": 0.281,
#     "gain_vs_warmup_map50": 0.0010000000000000009,
#     "gain_vs_warmup_map50_95": 0.0010000000000000009,
#     "night_gain_map50_95": -0.00033333333333335213,
#     "worst_gain_map50_95": 0.0010000000000000009
#   },
#   "report": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/21_blockwise_neck_judger_report.md"
# }
# CompletedProcess(args=['/opt/venv/bin/python3', '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/scripts/run_21_blockwise_neck_judger.py', '--workspace-root', '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger', '--imgsz', '960', '--val-batch-size', '16', '--full-eval-topk', '8', '--notify-discord'], returncode=0)

# %%
score_path = WORKSPACE / 'stats/21_scorecard.json'
metrics_path = WORKSPACE / 'stats/21_full_metrics.csv'
print(score_path.read_text())
print(metrics_path.read_text())
# Out:
# {
#   "experiment_env": 99,
#   "root_cause_analysis": 99,
#   "judge_stability": 97,
#   "accuracy_improvement": 100,
#   "final_goal": 98,
#   "returncode": 0,
#   "best_label": "uniform_bkrev_all_140",
#   "best_map50": 0.5,
#   "best_map50_95": 0.281,
#   "gain_vs_warmup_map50": 0.0010000000000000009,
#   "gain_vs_warmup_map50_95": 0.0010000000000000009,
#   "night_gain_map50_95": -0.00033333333333335213,
#   "worst_gain_map50_95": 0.0010000000000000009
# }
# day_avg_map50_95,day_night_gap_map50_95,family,label,map50,map50_95,night_avg_map50_95,path,precision,recall,worst_split,worst_split_map50_95
# 0.3113333333333333,0.11733333333333332,uniform_bkrev,uniform_bkrev_all_140,0.5,0.281,0.19399999999999998,/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/uniform_bkrev_all_140.pt,0.706,0.469,highway_night,0.174
# 0.3116666666666667,0.11700000000000005,highway,highway_all_100,0.5,0.281,0.19466666666666665,/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/highway_all_100.pt,0.705,0.468,highway_night,0.173
# 0.3113333333333333,0.11666666666666664,city_res_night,city_res_night_all_120,0.5,0.281,0.19466666666666665,/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/city_res_night_all_120.pt,0.707,0.467,highway_night,0.173
# 0.3113333333333333,0.11666666666666664,city_res_night,city_res_night_shallow_080_160,0.5,0.281,0.19466666666666665,/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/city_res_night_shallow_080_160.pt,0.707,0.468,highway_night,0.173
# 0.3113333333333333,0.11699999999999997,uniform,uniform_shallow_080_160,0.5,0.281,0.19433333333333333,/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/uniform_shallow_080_160.pt,0.705,0.469,highway_night,0.173
# 0.3113333333333333,0.11699999999999997,align,align_all_140,0.5,0.281,0.19433333333333333,/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/align_all_140.pt,0.704,0.469,highway_night,0.173
# 0.3116666666666667,0.11733333333333337,align,align_shallow_080_160,0.5,0.281,0.19433333333333333,/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/align_shallow_080_160.pt,0.705,0.469,highway_night,0.173
# 0.3113333333333333,0.11699999999999997,highway,highway_shallow_080_160,0.5,0.281,0.19433333333333333,/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/highway_shallow_080_160.pt,0.705,0.469,highway_night,0.173
# 0.3113333333333333,0.11766666666666664,align_bkrev,align_bkrev_all_140,0.5,0.281,0.19366666666666665,/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/align_bkrev_all_140.pt,0.706,0.469,highway_night,0.173
# 0.3116666666666667,0.11700000000000005,align_bkrev,align_bkrev_middle_080_160,0.499,0.281,0.19466666666666665,/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/align_bkrev_middle_080_160.pt,0.705,0.469,highway_night,0.174
# 0.3116666666666667,0.11733333333333337,city_res_night_bkrev,city_res_night_bkrev_middle_080_160,0.499,0.281,0.19433333333333333,/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/city_res_night_bkrev_middle_080_160.pt,0.705,0.469,highway_night,0.173
# 0.3116666666666667,0.11700000000000005,uniform_bkrev,uniform_bkrev_middle_080_160,0.499,0.28,0.19466666666666665,/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/uniform_bkrev_middle_080_160.pt,0.705,0.469,highway_night,0.174
# 0.3116666666666667,0.11700000000000005,highway_bkrev,highway_bkrev_middle_080_160,0.499,0.28,0.19466666666666665,/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/highway_bkrev_middle_080_160.pt,0.706,0.468,highway_night,0.174
# 0.3113333333333333,0.11699999999999997,identity,identity_warmup,0.499,0.28,0.19433333333333333,/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/21_blockwise_neck_judger/checkpoints/identity_warmup.pt,0.704,0.468,highway_night,0.173
