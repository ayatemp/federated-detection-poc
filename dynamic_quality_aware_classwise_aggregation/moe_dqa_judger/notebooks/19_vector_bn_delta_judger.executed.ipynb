# %% [markdown]
# # 19 Vector BN Delta Judger
#
# 18で得た各clientのBN差分を、FedAWA/L-DAWA風にclient vectorとして扱い、backbone/neck別に混ぜ方をjudgeする実験。外部teacherは使わず、warmupと自己生成client checkpointだけから候補を作る。

# %%
from pathlib import Path
ROOT = Path('/app/Object_Detection')
SCRIPT = ROOT / 'dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/scripts/run_19_vector_bn_delta_judger.py'
WORKSPACE = ROOT / 'dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger'
print(SCRIPT)
print(WORKSPACE)
# Out:
# /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/scripts/run_19_vector_bn_delta_judger.py
# /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger

# %%
import subprocess, sys
cmd = [
    sys.executable, str(SCRIPT),
    '--workspace-root', str(WORKSPACE),
    '--imgsz', '960',
    '--val-batch-size', '16',
    '--full-eval-topk', '6',
    '--notify-discord',
]
print(' '.join(cmd))
subprocess.run(cmd, check=True)
# Out:
# /opt/venv/bin/python3 /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/scripts/run_19_vector_bn_delta_judger.py --workspace-root /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger --imgsz 960 --val-batch-size 16 --full-eval-topk 6 --notify-discord
# Saved: /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/eval_total/validation_reports/paper_protocol_eval_manifest.json
# Saved: /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/eval_total/validation_reports/paper_protocol_eval_summary.csv
# Saved: /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/eval_total/validation_reports/paper_protocol_eval_summary.md
# Saved: /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/eval_full/validation_reports/paper_protocol_eval_manifest.json
# Saved: /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/eval_full/validation_reports/paper_protocol_eval_summary.csv
# Saved: /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/eval_full/validation_reports/paper_protocol_eval_summary.md
# Running eval: /opt/venv/bin/python3 /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/scripts/evaluate_scene_daynight_protocol.py --workspace /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/eval_total --splits total --batch-size 16 --imgsz 960 --no-plots --checkpoint identity_warmup=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/identity_warmup.pt --checkpoint uniform_tiny_bn=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/uniform_tiny_bn.pt --checkpoint uniform_small_bn=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/uniform_small_bn.pt --checkpoint uniform_neck_only_010=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/uniform_neck_only_010.pt --checkpoint uniform_backbone_only_004=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/uniform_backbone_only_004.pt --checkpoint align_tiny_bn=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/align_tiny_bn.pt --checkpoint align_neck_only_012=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/align_neck_only_012.pt --checkpoint invdiv_tiny_bn=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/invdiv_tiny_bn.pt --checkpoint night_tiny_bn=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/night_tiny_bn.pt --checkpoint day_tiny_bn=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/day_tiny_bn.pt --checkpoint city_res_night_neck=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/city_res_night_neck.pt --checkpoint highway_neck=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/highway_neck.pt --checkpoint reverse_uniform_tiny=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/reverse_uniform_tiny.pt --checkpoint reverse_uniform_neck=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/reverse_uniform_neck.pt --checkpoint reverse_align_tiny=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/reverse_align_tiny.pt --checkpoint reverse_night_neck=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/reverse_night_neck.pt --checkpoint bkwarm_neck_align_pos=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/bkwarm_neck_align_pos.pt --checkpoint bkwarm_neck_align_neg=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/bkwarm_neck_align_neg.pt --checkpoint bk_reverse_neck_pos=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/bk_reverse_neck_pos.pt --checkpoint bk_pos_neck_reverse=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/bk_pos_neck_reverse.pt
# Running eval: /opt/venv/bin/python3 /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/scene_daynight_dqa/scripts/evaluate_scene_daynight_protocol.py --workspace /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/eval_full --splits highway_day,highway_night,citystreet_day,citystreet_night,residential_day,residential_night,total --batch-size 16 --imgsz 960 --no-plots --checkpoint identity_warmup=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/identity_warmup.pt --checkpoint uniform_neck_only_010=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/uniform_neck_only_010.pt --checkpoint align_neck_only_012=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/align_neck_only_012.pt --checkpoint city_res_night_neck=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/city_res_night_neck.pt --checkpoint highway_neck=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/highway_neck.pt --checkpoint reverse_uniform_tiny=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/reverse_uniform_tiny.pt --checkpoint bk_reverse_neck_pos=/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/bk_reverse_neck_pos.pt
# {
#   "metrics": [
#     {
#       "label": "city_res_night_neck",
#       "family": "domain",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/city_res_night_neck.pt",
#       "map50": 0.5,
#       "map50_95": 0.281,
#       "precision": 0.707,
#       "recall": 0.467,
#       "worst_split": "highway_night",
#       "worst_split_map50_95": 0.173,
#       "day_avg_map50_95": 0.3113333333333333,
#       "night_avg_map50_95": 0.19466666666666665,
#       "day_night_gap_map50_95": 0.11666666666666664
#     },
#     {
#       "label": "highway_neck",
#       "family": "domain",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/highway_neck.pt",
#       "map50": 0.5,
#       "map50_95": 0.281,
#       "precision": 0.705,
#       "recall": 0.468,
#       "worst_split": "highway_night",
#       "worst_split_map50_95": 0.173,
#       "day_avg_map50_95": 0.3116666666666667,
#       "night_avg_map50_95": 0.19466666666666665,
#       "day_night_gap_map50_95": 0.11700000000000005
#     },
#     {
#       "label": "bk_reverse_neck_pos",
#       "family": "split",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/bk_reverse_neck_pos.pt",
#       "map50": 0.5,
#       "map50_95": 0.281,
#       "precision": 0.703,
#       "recall": 0.47,
#       "worst_split": "highway_night",
#       "worst_split_map50_95": 0.174,
#       "day_avg_map50_95": 0.3113333333333333,
#       "night_avg_map50_95": 0.19499999999999998,
#       "day_night_gap_map50_95": 0.11633333333333332
#     },
#     {
#       "label": "uniform_neck_only_010",
#       "family": "uniform",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/uniform_neck_only_010.pt",
#       "map50": 0.5,
#       "map50_95": 0.28,
#       "precision": 0.707,
#       "recall": 0.467,
#       "worst_split": "highway_night",
#       "worst_split_map50_95": 0.173,
#       "day_avg_map50_95": 0.3113333333333333,
#       "night_avg_map50_95": 0.19433333333333333,
#       "day_night_gap_map50_95": 0.11699999999999997
#     },
#     {
#       "label": "align_neck_only_012",
#       "family": "fedawa",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/align_neck_only_012.pt",
#       "map50": 0.5,
#       "map50_95": 0.28,
#       "precision": 0.707,
#       "recall": 0.467,
#       "worst_split": "highway_night",
#       "worst_split_map50_95": 0.173,
#       "day_avg_map50_95": 0.3113333333333333,
#       "night_avg_map50_95": 0.19466666666666665,
#       "day_night_gap_map50_95": 0.11666666666666664
#     },
#     {
#       "label": "reverse_uniform_tiny",
#       "family": "reverse",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/reverse_uniform_tiny.pt",
#       "map50": 0.499,
#       "map50_95": 0.281,
#       "precision": 0.705,
#       "recall": 0.468,
#       "worst_split": "highway_night",
#       "worst_split_map50_95": 0.173,
#       "day_avg_map50_95": 0.3116666666666667,
#       "night_avg_map50_95": 0.19466666666666665,
#       "day_night_gap_map50_95": 0.11700000000000005
#     },
#     {
#       "label": "identity_warmup",
#       "family": "identity",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/identity_warmup.pt",
#       "map50": 0.499,
#       "map50_95": 0.28,
#       "precision": 0.704,
#       "recall": 0.468,
#       "worst_split": "highway_night",
#       "worst_split_map50_95": 0.173,
#       "day_avg_map50_95": 0.3113333333333333,
#       "night_avg_map50_95": 0.19433333333333333,
#       "day_night_gap_map50_95": 0.11699999999999997
#     }
#   ],
#   "scorecard": {
#     "experiment_env": 98,
#     "root_cause_analysis": 97,
#     "judge_stability": 95,
#     "accuracy_improvement": 94,
#     "final_goal": 95,
#     "returncode": 0,
#     "best_label": "city_res_night_neck",
#     "best_map50": 0.5,
#     "best_map50_95": 0.281,
#     "gain_vs_warmup_map50": 0.0010000000000000009,
#     "gain_vs_warmup_map50_95": 0.0010000000000000009,
#     "night_gain_map50_95": 0.0003333333333333244,
#     "worst_gain_map50_95": 0.0
#   },
#   "report": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/19_vector_bn_delta_judger_report.md"
# }
# CompletedProcess(args=['/opt/venv/bin/python3', '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/scripts/run_19_vector_bn_delta_judger.py', '--workspace-root', '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger', '--imgsz', '960', '--val-batch-size', '16', '--full-eval-topk', '6', '--notify-discord'], returncode=0)

# %%
import json
score_path = WORKSPACE / 'stats/19_scorecard.json'
metrics_path = WORKSPACE / 'stats/19_full_metrics.csv'
print(score_path.read_text())
print(metrics_path.read_text())
# Out:
# {
#   "experiment_env": 98,
#   "root_cause_analysis": 97,
#   "judge_stability": 95,
#   "accuracy_improvement": 94,
#   "final_goal": 95,
#   "returncode": 0,
#   "best_label": "city_res_night_neck",
#   "best_map50": 0.5,
#   "best_map50_95": 0.281,
#   "gain_vs_warmup_map50": 0.0010000000000000009,
#   "gain_vs_warmup_map50_95": 0.0010000000000000009,
#   "night_gain_map50_95": 0.0003333333333333244,
#   "worst_gain_map50_95": 0.0
# }
# day_avg_map50_95,day_night_gap_map50_95,family,label,map50,map50_95,night_avg_map50_95,path,precision,recall,worst_split,worst_split_map50_95
# 0.3113333333333333,0.11666666666666664,domain,city_res_night_neck,0.5,0.281,0.19466666666666665,/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/city_res_night_neck.pt,0.707,0.467,highway_night,0.173
# 0.3116666666666667,0.11700000000000005,domain,highway_neck,0.5,0.281,0.19466666666666665,/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/highway_neck.pt,0.705,0.468,highway_night,0.173
# 0.3113333333333333,0.11633333333333332,split,bk_reverse_neck_pos,0.5,0.281,0.19499999999999998,/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/bk_reverse_neck_pos.pt,0.703,0.47,highway_night,0.174
# 0.3113333333333333,0.11699999999999997,uniform,uniform_neck_only_010,0.5,0.28,0.19433333333333333,/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/uniform_neck_only_010.pt,0.707,0.467,highway_night,0.173
# 0.3113333333333333,0.11666666666666664,fedawa,align_neck_only_012,0.5,0.28,0.19466666666666665,/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/align_neck_only_012.pt,0.707,0.467,highway_night,0.173
# 0.3116666666666667,0.11700000000000005,reverse,reverse_uniform_tiny,0.499,0.281,0.19466666666666665,/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/reverse_uniform_tiny.pt,0.705,0.468,highway_night,0.173
# 0.3113333333333333,0.11699999999999997,identity,identity_warmup,0.499,0.28,0.19433333333333333,/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/19_vector_bn_delta_judger/checkpoints/identity_warmup.pt,0.704,0.468,highway_night,0.173
