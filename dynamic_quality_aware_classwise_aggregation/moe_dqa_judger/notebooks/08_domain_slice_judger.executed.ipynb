# %% [markdown]
# # 08 Domain-Slice Judger
#
# 07 removed round drift but several candidates tie on total mAP.  This notebook
# evaluates the plateau candidates on six paper domain slices and ranks them with
# a night/worst-domain aware objective.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path('/app/Object_Detection')
PROJECT = ROOT / 'dynamic_quality_aware_classwise_aggregation' / 'moe_dqa_judger'
OUT = PROJECT / 'output' / '08_domain_slice_judger'
OUT
# Out:
# PosixPath('/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger')

# %%
import subprocess, sys

cmd = [
    sys.executable,
    str(PROJECT / 'scripts' / 'run_08_domain_slice_judger.py'),
    '--workspace-root', str(OUT),
    '--max-candidates', '9',
    '--val-batch-size', '32',
    '--notify-discord',
]
print(' '.join(cmd))
subprocess.run(cmd, cwd=ROOT, check=True)
# Out:
# /opt/venv/bin/python3 /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/scripts/run_08_domain_slice_judger.py --workspace-root /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger --max-candidates 9 --val-batch-size 32 --notify-discord
# {
#   "manifest": {
#     "created_utc": "2026-05-13T15:13:34.735907+00:00",
#     "protocol": "dqa_softmox_domain_slice_judger_v1",
#     "method": "group-DRO style domain/night slice selection over plateau candidates",
#     "papers_used": [
#       "Group DRO / worst-group validation",
#       "Distributionally Robust Federated Averaging"
#     ]
#   },
#   "summary": [
#     {
#       "label": "r006_scaled04_best01_rand000_050",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_scaled04_best01_rand000_050.pt",
#       "total_score": 0.5741,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5298166666666667,
#       "day_mean_score": 0.6172333333333334,
#       "night_mean_score": 0.44239999999999996,
#       "worst_domain_score": 0.38544999999999996,
#       "domain_mean_map50": 0.42683333333333334,
#       "night_mean_map50": 0.35833333333333334,
#       "group_dro_score": 0.4659766666666667
#     },
#     {
#       "label": "r003_tiny_all_s",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_tiny_all_s.pt",
#       "total_score": 0.5735,
#       "total_map50": 0.461,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.52965,
#       "day_mean_score": 0.61675,
#       "night_mean_score": 0.44255,
#       "worst_domain_score": 0.38459999999999994,
#       "domain_mean_map50": 0.42650000000000005,
#       "night_mean_map50": 0.35800000000000004,
#       "group_dro_score": 0.4658
#     },
#     {
#       "label": "r003_rand003",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_rand003.pt",
#       "total_score": 0.5740500000000001,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5295833333333333,
#       "day_mean_score": 0.6166166666666667,
#       "night_mean_score": 0.44255,
#       "worst_domain_score": 0.38464999999999994,
#       "domain_mean_map50": 0.42650000000000005,
#       "night_mean_map50": 0.35800000000000004,
#       "group_dro_score": 0.4657833333333333
#     },
#     {
#       "label": "r005_scaled04_best01_sur00_02_025",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r005_full_scaled04_best01_sur00_02_025.pt",
#       "total_score": 0.5745,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5293416666666667,
#       "day_mean_score": 0.6166999999999999,
#       "night_mean_score": 0.44198333333333334,
#       "worst_domain_score": 0.3847,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46547000000000005
#     },
#     {
#       "label": "r005_scaled04_best00_slight_extrapolate_target_025",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r005_full_scaled04_best00_slight_extrapolate_target_025.pt",
#       "total_score": 0.5745,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5293333333333333,
#       "day_mean_score": 0.6166999999999999,
#       "night_mean_score": 0.4419666666666666,
#       "worst_domain_score": 0.38464999999999994,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46545
#     },
#     {
#       "label": "incumbent_r002",
#       "source": "03_mix_judger_policy",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/03_mix_judger_policy/candidates/r002_judger03_selected_r002.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5293916666666666,
#       "day_mean_score": 0.6166999999999999,
#       "night_mean_score": 0.44208333333333333,
#       "worst_domain_score": 0.38425,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46543999999999996
#     },
#     {
#       "label": "r004_scaled04_best00_rand008_050",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_scaled04_best00_rand008_050.pt",
#       "total_score": 0.5741,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.529275,
#       "day_mean_score": 0.61665,
#       "night_mean_score": 0.44189999999999996,
#       "worst_domain_score": 0.38449999999999995,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46537000000000006
#     },
#     {
#       "label": "r006_anti_drift_head",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_anti_drift_head.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.529125,
#       "day_mean_score": 0.61685,
#       "night_mean_score": 0.4414,
#       "worst_domain_score": 0.38425,
#       "domain_mean_map50": 0.42616666666666664,
#       "night_mean_map50": 0.35733333333333334,
#       "group_dro_score": 0.46506000000000003
#     },
#     {
#       "label": "r004_anti_drift_head",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_anti_drift_head.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.529225,
#       "day_mean_score": 0.6167333333333334,
#       "night_mean_score": 0.4417166666666667,
#       "worst_domain_score": 0.38315,
#       "domain_mean_map50": 0.42616666666666664,
#       "night_mean_map50": 0.35733333333333334,
#       "group_dro_score": 0.4650066666666667
#     }
#   ],
#   "rows": [
#     {
#       "label": "incumbent_r002",
#       "source": "03_mix_judger_policy",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/03_mix_judger_policy/candidates/r002_judger03_selected_r002.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "highway_day",
#       "group": "day",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_incumbent_r002_highway_day.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/03_mix_judger_policy/candidates/r002_judger03_selected_r002.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/highway_day.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_incumbent_r002_highway_day --exist-ok --no-plots",
#       "images": 1290.0,
#       "labels": 20532.0,
#       "precision": 0.786,
#       "recall": 0.39,
#       "map50": 0.441,
#       "map50_95": 0.249,
#       "domain_score": 0.54765
#     },
#     {
#       "label": "incumbent_r002",
#       "source": "03_mix_judger_policy",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/03_mix_judger_policy/candidates/r002_judger03_selected_r002.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "highway_night",
#       "group": "night",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_incumbent_r002_highway_night.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/03_mix_judger_policy/candidates/r002_judger03_selected_r002.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/highway_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_incumbent_r002_highway_night --exist-ok --no-plots",
#       "images": 1007.0,
#       "labels": 12708.0,
#       "precision": 0.537,
#       "recall": 0.286,
#       "map50": 0.308,
#       "map50_95": 0.177,
#       "domain_score": 0.38425
#     },
#     {
#       "label": "incumbent_r002",
#       "source": "03_mix_judger_policy",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/03_mix_judger_policy/candidates/r002_judger03_selected_r002.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "citystreet_day",
#       "group": "day",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_incumbent_r002_citystreet_day.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/03_mix_judger_policy/candidates/r002_judger03_selected_r002.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/citystreet_day.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_incumbent_r002_citystreet_day --exist-ok --no-plots",
#       "images": 3067.0,
#       "labels": 69855.0,
#       "precision": 0.738,
#       "recall": 0.461,
#       "map50": 0.506,
#       "map50_95": 0.291,
#       "domain_score": 0.6309
#     },
#     {
#       "label": "incumbent_r002",
#       "source": "03_mix_judger_policy",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/03_mix_judger_policy/candidates/r002_judger03_selected_r002.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "citystreet_night",
#       "group": "night",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_incumbent_r002_citystreet_night.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/03_mix_judger_policy/candidates/r002_judger03_selected_r002.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/citystreet_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_incumbent_r002_citystreet_night --exist-ok --no-plots",
#       "images": 2582.0,
#       "labels": 47259.0,
#       "precision": 0.609,
#       "recall": 0.371,
#       "map50": 0.376,
#       "map50_95": 0.2,
#       "domain_score": 0.46455
#     },
#     {
#       "label": "incumbent_r002",
#       "source": "03_mix_judger_policy",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/03_mix_judger_policy/candidates/r002_judger03_selected_r002.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "residential_day",
#       "group": "day",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_incumbent_r002_residential_day.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/03_mix_judger_policy/candidates/r002_judger03_selected_r002.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/residential_day.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_incumbent_r002_residential_day --exist-ok --no-plots",
#       "images": 862.0,
#       "labels": 14881.0,
#       "precision": 0.708,
#       "recall": 0.473,
#       "map50": 0.538,
#       "map50_95": 0.314,
#       "domain_score": 0.67155
#     },
#     {
#       "label": "incumbent_r002",
#       "source": "03_mix_judger_policy",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/03_mix_judger_policy/candidates/r002_judger03_selected_r002.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "residential_night",
#       "group": "night",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_incumbent_r002_residential_night.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/03_mix_judger_policy/candidates/r002_judger03_selected_r002.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/residential_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_incumbent_r002_residential_night --exist-ok --no-plots",
#       "images": 279.0,
#       "labels": 4184.0,
#       "precision": 0.657,
#       "recall": 0.334,
#       "map50": 0.389,
#       "map50_95": 0.205,
#       "domain_score": 0.47745
#     },
#     {
#       "label": "r003_tiny_all_s",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_tiny_all_s.pt",
#       "total_score": 0.5735,
#       "total_map50": 0.461,
#       "total_map50_95": 0.26,
#       "domain": "highway_day",
#       "group": "day",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r003_tiny_all_s_highway_day.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_tiny_all_s.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/highway_day.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r003_tiny_all_s_highway_day --exist-ok --no-plots",
#       "images": 1290.0,
#       "labels": 20532.0,
#       "precision": 0.784,
#       "recall": 0.39,
#       "map50": 0.441,
#       "map50_95": 0.249,
#       "domain_score": 0.54765
#     },
#     {
#       "label": "r003_tiny_all_s",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_tiny_all_s.pt",
#       "total_score": 0.5735,
#       "total_map50": 0.461,
#       "total_map50_95": 0.26,
#       "domain": "highway_night",
#       "group": "night",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r003_tiny_all_s_highway_night.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_tiny_all_s.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/highway_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r003_tiny_all_s_highway_night --exist-ok --no-plots",
#       "images": 1007.0,
#       "labels": 12708.0,
#       "precision": 0.538,
#       "recall": 0.286,
#       "map50": 0.308,
#       "map50_95": 0.178,
#       "domain_score": 0.38459999999999994
#     },
#     {
#       "label": "r003_tiny_all_s",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_tiny_all_s.pt",
#       "total_score": 0.5735,
#       "total_map50": 0.461,
#       "total_map50_95": 0.26,
#       "domain": "citystreet_day",
#       "group": "day",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r003_tiny_all_s_citystreet_day.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_tiny_all_s.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/citystreet_day.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r003_tiny_all_s_citystreet_day --exist-ok --no-plots",
#       "images": 3067.0,
#       "labels": 69855.0,
#       "precision": 0.734,
#       "recall": 0.463,
#       "map50": 0.506,
#       "map50_95": 0.291,
#       "domain_score": 0.631
#     },
#     {
#       "label": "r003_tiny_all_s",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_tiny_all_s.pt",
#       "total_score": 0.5735,
#       "total_map50": 0.461,
#       "total_map50_95": 0.26,
#       "domain": "citystreet_night",
#       "group": "night",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r003_tiny_all_s_citystreet_night.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_tiny_all_s.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/citystreet_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r003_tiny_all_s_citystreet_night --exist-ok --no-plots",
#       "images": 2582.0,
#       "labels": 47259.0,
#       "precision": 0.61,
#       "recall": 0.371,
#       "map50": 0.376,
#       "map50_95": 0.2,
#       "domain_score": 0.46455
#     },
#     {
#       "label": "r003_tiny_all_s",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_tiny_all_s.pt",
#       "total_score": 0.5735,
#       "total_map50": 0.461,
#       "total_map50_95": 0.26,
#       "domain": "residential_day",
#       "group": "day",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r003_tiny_all_s_residential_day.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_tiny_all_s.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/residential_day.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r003_tiny_all_s_residential_day --exist-ok --no-plots",
#       "images": 862.0,
#       "labels": 14881.0,
#       "precision": 0.707,
#       "recall": 0.474,
#       "map50": 0.538,
#       "map50_95": 0.314,
#       "domain_score": 0.6716
#     },
#     {
#       "label": "r003_tiny_all_s",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_tiny_all_s.pt",
#       "total_score": 0.5735,
#       "total_map50": 0.461,
#       "total_map50_95": 0.26,
#       "domain": "residential_night",
#       "group": "night",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r003_tiny_all_s_residential_night.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_tiny_all_s.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/residential_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r003_tiny_all_s_residential_night --exist-ok --no-plots",
#       "images": 279.0,
#       "labels": 4184.0,
#       "precision": 0.656,
#       "recall": 0.335,
#       "map50": 0.39,
#       "map50_95": 0.205,
#       "domain_score": 0.4785
#     },
#     {
#       "label": "r003_rand003",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_rand003.pt",
#       "total_score": 0.5740500000000001,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "highway_day",
#       "group": "day",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r003_rand003_highway_day.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_rand003.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/highway_day.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r003_rand003_highway_day --exist-ok --no-plots",
#       "images": 1290.0,
#       "labels": 20532.0,
#       "precision": 0.785,
#       "recall": 0.39,
#       "map50": 0.441,
#       "map50_95": 0.248,
#       "domain_score": 0.5473
#     },
#     {
#       "label": "r003_rand003",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_rand003.pt",
#       "total_score": 0.5740500000000001,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "highway_night",
#       "group": "night",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r003_rand003_highway_night.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_rand003.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/highway_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r003_rand003_highway_night --exist-ok --no-plots",
#       "images": 1007.0,
#       "labels": 12708.0,
#       "precision": 0.537,
#       "recall": 0.287,
#       "map50": 0.308,
#       "map50_95": 0.178,
#       "domain_score": 0.38464999999999994
#     },
#     {
#       "label": "r003_rand003",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_rand003.pt",
#       "total_score": 0.5740500000000001,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "citystreet_day",
#       "group": "day",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r003_rand003_citystreet_day.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_rand003.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/citystreet_day.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r003_rand003_citystreet_day --exist-ok --no-plots",
#       "images": 3067.0,
#       "labels": 69855.0,
#       "precision": 0.734,
#       "recall": 0.463,
#       "map50": 0.506,
#       "map50_95": 0.291,
#       "domain_score": 0.631
#     },
#     {
#       "label": "r003_rand003",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_rand003.pt",
#       "total_score": 0.5740500000000001,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "citystreet_night",
#       "group": "night",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r003_rand003_citystreet_night.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_rand003.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/citystreet_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r003_rand003_citystreet_night --exist-ok --no-plots",
#       "images": 2582.0,
#       "labels": 47259.0,
#       "precision": 0.609,
#       "recall": 0.371,
#       "map50": 0.377,
#       "map50_95": 0.2,
#       "domain_score": 0.46555
#     },
#     {
#       "label": "r003_rand003",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_rand003.pt",
#       "total_score": 0.5740500000000001,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "residential_day",
#       "group": "day",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r003_rand003_residential_day.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_rand003.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/residential_day.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r003_rand003_residential_day --exist-ok --no-plots",
#       "images": 862.0,
#       "labels": 14881.0,
#       "precision": 0.707,
#       "recall": 0.473,
#       "map50": 0.538,
#       "map50_95": 0.314,
#       "domain_score": 0.67155
#     },
#     {
#       "label": "r003_rand003",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_rand003.pt",
#       "total_score": 0.5740500000000001,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "residential_night",
#       "group": "night",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r003_rand003_residential_night.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_rand003.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/residential_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r003_rand003_residential_night --exist-ok --no-plots",
#       "images": 279.0,
#       "labels": 4184.0,
#       "precision": 0.66,
#       "recall": 0.334,
#       "map50": 0.389,
#       "map50_95": 0.205,
#       "domain_score": 0.47745
#     },
#     {
#       "label": "r004_scaled04_best00_rand008_050",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_scaled04_best00_rand008_050.pt",
#       "total_score": 0.5741,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "highway_day",
#       "group": "day",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r004_scaled04_best00_rand008_050_highway_day.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_scaled04_best00_rand008_050.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/highway_day.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r004_scaled04_best00_rand008_050_highway_day --exist-ok --no-plots",
#       "images": 1290.0,
#       "labels": 20532.0,
#       "precision": 0.784,
#       "recall": 0.391,
#       "map50": 0.441,
#       "map50_95": 0.248,
#       "domain_score": 0.54735
#     },
#     {
#       "label": "r004_scaled04_best00_rand008_050",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_scaled04_best00_rand008_050.pt",
#       "total_score": 0.5741,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "highway_night",
#       "group": "night",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r004_scaled04_best00_rand008_050_highway_night.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_scaled04_best00_rand008_050.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/highway_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r004_scaled04_best00_rand008_050_highway_night --exist-ok --no-plots",
#       "images": 1007.0,
#       "labels": 12708.0,
#       "precision": 0.543,
#       "recall": 0.284,
#       "map50": 0.308,
#       "map50_95": 0.178,
#       "domain_score": 0.38449999999999995
#     },
#     {
#       "label": "r004_scaled04_best00_rand008_050",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_scaled04_best00_rand008_050.pt",
#       "total_score": 0.5741,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "citystreet_day",
#       "group": "day",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r004_scaled04_best00_rand008_050_citystreet_day.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_scaled04_best00_rand008_050.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/citystreet_day.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r004_scaled04_best00_rand008_050_citystreet_day --exist-ok --no-plots",
#       "images": 3067.0,
#       "labels": 69855.0,
#       "precision": 0.733,
#       "recall": 0.464,
#       "map50": 0.506,
#       "map50_95": 0.291,
#       "domain_score": 0.63105
#     },
#     {
#       "label": "r004_scaled04_best00_rand008_050",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_scaled04_best00_rand008_050.pt",
#       "total_score": 0.5741,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "citystreet_night",
#       "group": "night",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r004_scaled04_best00_rand008_050_citystreet_night.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_scaled04_best00_rand008_050.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/citystreet_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r004_scaled04_best00_rand008_050_citystreet_night --exist-ok --no-plots",
#       "images": 2582.0,
#       "labels": 47259.0,
#       "precision": 0.655,
#       "recall": 0.354,
#       "map50": 0.377,
#       "map50_95": 0.2,
#       "domain_score": 0.4647
#     },
#     {
#       "label": "r004_scaled04_best00_rand008_050",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_scaled04_best00_rand008_050.pt",
#       "total_score": 0.5741,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "residential_day",
#       "group": "day",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r004_scaled04_best00_rand008_050_residential_day.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_scaled04_best00_rand008_050.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/residential_day.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r004_scaled04_best00_rand008_050_residential_day --exist-ok --no-plots",
#       "images": 862.0,
#       "labels": 14881.0,
#       "precision": 0.706,
#       "recall": 0.473,
#       "map50": 0.538,
#       "map50_95": 0.314,
#       "domain_score": 0.67155
#     },
#     {
#       "label": "r004_scaled04_best00_rand008_050",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_scaled04_best00_rand008_050.pt",
#       "total_score": 0.5741,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "residential_night",
#       "group": "night",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r004_scaled04_best00_rand008_050_residential_night.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_scaled04_best00_rand008_050.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/residential_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r004_scaled04_best00_rand008_050_residential_night --exist-ok --no-plots",
#       "images": 279.0,
#       "labels": 4184.0,
#       "precision": 0.654,
#       "recall": 0.335,
#       "map50": 0.388,
#       "map50_95": 0.205,
#       "domain_score": 0.4765
#     },
#     {
#       "label": "r004_anti_drift_head",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_anti_drift_head.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "highway_day",
#       "group": "day",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r004_anti_drift_head_highway_day.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_anti_drift_head.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/highway_day.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r004_anti_drift_head_highway_day --exist-ok --no-plots",
#       "images": 1290.0,
#       "labels": 20532.0,
#       "precision": 0.786,
#       "recall": 0.39,
#       "map50": 0.441,
#       "map50_95": 0.249,
#       "domain_score": 0.54765
#     },
#     {
#       "label": "r004_anti_drift_head",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_anti_drift_head.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "highway_night",
#       "group": "night",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r004_anti_drift_head_highway_night.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_anti_drift_head.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/highway_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r004_anti_drift_head_highway_night --exist-ok --no-plots",
#       "images": 1007.0,
#       "labels": 12708.0,
#       "precision": 0.544,
#       "recall": 0.284,
#       "map50": 0.307,
#       "map50_95": 0.177,
#       "domain_score": 0.38315
#     },
#     {
#       "label": "r004_anti_drift_head",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_anti_drift_head.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "citystreet_day",
#       "group": "day",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r004_anti_drift_head_citystreet_day.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_anti_drift_head.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/citystreet_day.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r004_anti_drift_head_citystreet_day --exist-ok --no-plots",
#       "images": 3067.0,
#       "labels": 69855.0,
#       "precision": 0.733,
#       "recall": 0.463,
#       "map50": 0.506,
#       "map50_95": 0.291,
#       "domain_score": 0.631
#     },
#     {
#       "label": "r004_anti_drift_head",
#       "source": "07_incumbent_delta",
# ...
#     },
#     {
#       "label": "r006_scaled04_best01_rand000_050",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_scaled04_best01_rand000_050.pt",
#       "total_score": 0.5741,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "citystreet_day",
#       "group": "day",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r006_scaled04_best01_rand000_050_citystreet_day.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_scaled04_best01_rand000_050.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/citystreet_day.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r006_scaled04_best01_rand000_050_citystreet_day --exist-ok --no-plots",
#       "images": 3067.0,
#       "labels": 69855.0,
#       "precision": 0.734,
#       "recall": 0.464,
#       "map50": 0.506,
#       "map50_95": 0.291,
#       "domain_score": 0.63105
#     },
#     {
#       "label": "r006_scaled04_best01_rand000_050",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_scaled04_best01_rand000_050.pt",
#       "total_score": 0.5741,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "citystreet_night",
#       "group": "night",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r006_scaled04_best01_rand000_050_citystreet_night.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_scaled04_best01_rand000_050.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/citystreet_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r006_scaled04_best01_rand000_050_citystreet_night --exist-ok --no-plots",
#       "images": 2582.0,
#       "labels": 47259.0,
#       "precision": 0.637,
#       "recall": 0.36,
#       "map50": 0.377,
#       "map50_95": 0.2,
#       "domain_score": 0.465
#     },
#     {
#       "label": "r006_scaled04_best01_rand000_050",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_scaled04_best01_rand000_050.pt",
#       "total_score": 0.5741,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "residential_day",
#       "group": "day",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r006_scaled04_best01_rand000_050_residential_day.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_scaled04_best01_rand000_050.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/residential_day.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r006_scaled04_best01_rand000_050_residential_day --exist-ok --no-plots",
#       "images": 862.0,
#       "labels": 14881.0,
#       "precision": 0.704,
#       "recall": 0.474,
#       "map50": 0.538,
#       "map50_95": 0.315,
#       "domain_score": 0.67195
#     },
#     {
#       "label": "r006_scaled04_best01_rand000_050",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_scaled04_best01_rand000_050.pt",
#       "total_score": 0.5741,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "residential_night",
#       "group": "night",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r006_scaled04_best01_rand000_050_residential_night.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_scaled04_best01_rand000_050.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/residential_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r006_scaled04_best01_rand000_050_residential_night --exist-ok --no-plots",
#       "images": 279.0,
#       "labels": 4184.0,
#       "precision": 0.661,
#       "recall": 0.334,
#       "map50": 0.389,
#       "map50_95": 0.203,
#       "domain_score": 0.47675
#     },
#     {
#       "label": "r006_anti_drift_head",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_anti_drift_head.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "highway_day",
#       "group": "day",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r006_anti_drift_head_highway_day.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_anti_drift_head.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/highway_day.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r006_anti_drift_head_highway_day --exist-ok --no-plots",
#       "images": 1290.0,
#       "labels": 20532.0,
#       "precision": 0.785,
#       "recall": 0.39,
#       "map50": 0.441,
#       "map50_95": 0.249,
#       "domain_score": 0.54765
#     },
#     {
#       "label": "r006_anti_drift_head",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_anti_drift_head.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "highway_night",
#       "group": "night",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r006_anti_drift_head_highway_night.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_anti_drift_head.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/highway_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r006_anti_drift_head_highway_night --exist-ok --no-plots",
#       "images": 1007.0,
#       "labels": 12708.0,
#       "precision": 0.537,
#       "recall": 0.286,
#       "map50": 0.308,
#       "map50_95": 0.177,
#       "domain_score": 0.38425
#     },
#     {
#       "label": "r006_anti_drift_head",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_anti_drift_head.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "citystreet_day",
#       "group": "day",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r006_anti_drift_head_citystreet_day.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_anti_drift_head.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/citystreet_day.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r006_anti_drift_head_citystreet_day --exist-ok --no-plots",
#       "images": 3067.0,
#       "labels": 69855.0,
#       "precision": 0.733,
#       "recall": 0.463,
#       "map50": 0.506,
#       "map50_95": 0.291,
#       "domain_score": 0.631
#     },
#     {
#       "label": "r006_anti_drift_head",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_anti_drift_head.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "citystreet_night",
#       "group": "night",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r006_anti_drift_head_citystreet_night.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_anti_drift_head.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/citystreet_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r006_anti_drift_head_citystreet_night --exist-ok --no-plots",
#       "images": 2582.0,
#       "labels": 47259.0,
#       "precision": 0.608,
#       "recall": 0.371,
#       "map50": 0.376,
#       "map50_95": 0.2,
#       "domain_score": 0.46455
#     },
#     {
#       "label": "r006_anti_drift_head",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_anti_drift_head.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "residential_day",
#       "group": "day",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r006_anti_drift_head_residential_day.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_anti_drift_head.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/residential_day.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r006_anti_drift_head_residential_day --exist-ok --no-plots",
#       "images": 862.0,
#       "labels": 14881.0,
#       "precision": 0.707,
#       "recall": 0.473,
#       "map50": 0.538,
#       "map50_95": 0.315,
#       "domain_score": 0.6718999999999999
#     },
#     {
#       "label": "r006_anti_drift_head",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_anti_drift_head.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain": "residential_night",
#       "group": "night",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_logs/domain08_r006_anti_drift_head_residential_night.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_anti_drift_head.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/configs/residential_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger/validation_runs --name domain08_r006_anti_drift_head_residential_night --exist-ok --no-plots",
#       "images": 279.0,
#       "labels": 4184.0,
#       "precision": 0.658,
#       "recall": 0.334,
#       "map50": 0.388,
#       "map50_95": 0.202,
#       "domain_score": 0.4754
#     }
#   ]
# }
# CompletedProcess(args=['/opt/venv/bin/python3', '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/scripts/run_08_domain_slice_judger.py', '--workspace-root', '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/08_domain_slice_judger', '--max-candidates', '9', '--val-batch-size', '32', '--notify-discord'], returncode=0)

# %%
summary = pd.read_csv(OUT / 'stats' / '08_domain_summary.csv')
display(summary[['label','total_score','day_mean_score','night_mean_score','worst_domain_score','group_dro_score','night_mean_map50']])

domain = pd.read_csv(OUT / 'stats' / '08_domain_eval.csv')
display(domain[['label','domain','group','map50','map50_95','precision','recall','domain_score']].head(60))

print((OUT / '08_domain_slice_judger_report.md').read_text())
# Out:
#                                                label  total_score  \
# 0                   r006_scaled04_best01_rand000_050      0.57410
# 1                                    r003_tiny_all_s      0.57350
# 2                                       r003_rand003      0.57405
# 3                  r005_scaled04_best01_sur00_02_025      0.57450
# 4  r005_scaled04_best00_slight_extrapolate_target...      0.57450
# 5                                     incumbent_r002      0.57455
# 6                   r004_scaled04_best00_rand008_050      0.57410
# 7                               r006_anti_drift_head      0.57455
# 8                               r004_anti_drift_head      0.57455
#
#    day_mean_score  night_mean_score  worst_domain_score  group_dro_score  \
# 0        0.617233          0.442400             0.38545         0.465977
# 1        0.616750          0.442550             0.38460         0.465800
# 2        0.616617          0.442550             0.38465         0.465783
# 3        0.616700          0.441983             0.38470         0.465470
# 4        0.616700          0.441967             0.38465         0.465450
# 5        0.616700          0.442083             0.38425         0.465440
# 6        0.616650          0.441900             0.38450         0.465370
# 7        0.616850          0.441400             0.38425         0.465060
# 8        0.616733          0.441717             0.38315         0.465007
#
#    night_mean_map50
# 0          0.358333
# 1          0.358000
# 2          0.358000
# 3          0.357667
# 4          0.357667
# 5          0.357667
# 6          0.357667
# 7          0.357333
# 8          0.357333
#                                                 label             domain  \
# 0                                      incumbent_r002        highway_day
# 1                                      incumbent_r002      highway_night
# 2                                      incumbent_r002     citystreet_day
# 3                                      incumbent_r002   citystreet_night
# 4                                      incumbent_r002    residential_day
# 5                                      incumbent_r002  residential_night
# 6                                     r003_tiny_all_s        highway_day
# 7                                     r003_tiny_all_s      highway_night
# 8                                     r003_tiny_all_s     citystreet_day
# 9                                     r003_tiny_all_s   citystreet_night
# 10                                    r003_tiny_all_s    residential_day
# 11                                    r003_tiny_all_s  residential_night
# 12                                       r003_rand003        highway_day
# 13                                       r003_rand003      highway_night
# 14                                       r003_rand003     citystreet_day
# 15                                       r003_rand003   citystreet_night
# 16                                       r003_rand003    residential_day
# 17                                       r003_rand003  residential_night
# 18                   r004_scaled04_best00_rand008_050        highway_day
# 19                   r004_scaled04_best00_rand008_050      highway_night
# 20                   r004_scaled04_best00_rand008_050     citystreet_day
# 21                   r004_scaled04_best00_rand008_050   citystreet_night
# 22                   r004_scaled04_best00_rand008_050    residential_day
# 23                   r004_scaled04_best00_rand008_050  residential_night
# 24                               r004_anti_drift_head        highway_day
# 25                               r004_anti_drift_head      highway_night
# 26                               r004_anti_drift_head     citystreet_day
# 27                               r004_anti_drift_head   citystreet_night
# 28                               r004_anti_drift_head    residential_day
# 29                               r004_anti_drift_head  residential_night
# 30                  r005_scaled04_best01_sur00_02_025        highway_day
# 31                  r005_scaled04_best01_sur00_02_025      highway_night
# 32                  r005_scaled04_best01_sur00_02_025     citystreet_day
# 33                  r005_scaled04_best01_sur00_02_025   citystreet_night
# 34                  r005_scaled04_best01_sur00_02_025    residential_day
# 35                  r005_scaled04_best01_sur00_02_025  residential_night
# 36  r005_scaled04_best00_slight_extrapolate_target...        highway_day
# 37  r005_scaled04_best00_slight_extrapolate_target...      highway_night
# 38  r005_scaled04_best00_slight_extrapolate_target...     citystreet_day
# 39  r005_scaled04_best00_slight_extrapolate_target...   citystreet_night
# 40  r005_scaled04_best00_slight_extrapolate_target...    residential_day
# 41  r005_scaled04_best00_slight_extrapolate_target...  residential_night
# 42                   r006_scaled04_best01_rand000_050        highway_day
# 43                   r006_scaled04_best01_rand000_050      highway_night
# 44                   r006_scaled04_best01_rand000_050     citystreet_day
# 45                   r006_scaled04_best01_rand000_050   citystreet_night
# 46                   r006_scaled04_best01_rand000_050    residential_day
# 47                   r006_scaled04_best01_rand000_050  residential_night
# 48                               r006_anti_drift_head        highway_day
# 49                               r006_anti_drift_head      highway_night
# 50                               r006_anti_drift_head     citystreet_day
# 51                               r006_anti_drift_head   citystreet_night
# 52                               r006_anti_drift_head    residential_day
# 53                               r006_anti_drift_head  residential_night
#
#     group  map50  map50_95  precision  recall  domain_score
# 0     day  0.441     0.249      0.786   0.390       0.54765
# 1   night  0.308     0.177      0.537   0.286       0.38425
# 2     day  0.506     0.291      0.738   0.461       0.63090
# 3   night  0.376     0.200      0.609   0.371       0.46455
# 4     day  0.538     0.314      0.708   0.473       0.67155
# 5   night  0.389     0.205      0.657   0.334       0.47745
# 6     day  0.441     0.249      0.784   0.390       0.54765
# 7   night  0.308     0.178      0.538   0.286       0.38460
# 8     day  0.506     0.291      0.734   0.463       0.63100
# 9   night  0.376     0.200      0.610   0.371       0.46455
# 10    day  0.538     0.314      0.707   0.474       0.67160
# 11  night  0.390     0.205      0.656   0.335       0.47850
# 12    day  0.441     0.248      0.785   0.390       0.54730
# 13  night  0.308     0.178      0.537   0.287       0.38465
# 14    day  0.506     0.291      0.734   0.463       0.63100
# 15  night  0.377     0.200      0.609   0.371       0.46555
# 16    day  0.538     0.314      0.707   0.473       0.67155
# 17  night  0.389     0.205      0.660   0.334       0.47745
# 18    day  0.441     0.248      0.784   0.391       0.54735
# 19  night  0.308     0.178      0.543   0.284       0.38450
# 20    day  0.506     0.291      0.733   0.464       0.63105
# 21  night  0.377     0.200      0.655   0.354       0.46470
# 22    day  0.538     0.314      0.706   0.473       0.67155
# 23  night  0.388     0.205      0.654   0.335       0.47650
# 24    day  0.441     0.249      0.786   0.390       0.54765
# 25  night  0.307     0.177      0.544   0.284       0.38315
# 26    day  0.506     0.291      0.733   0.463       0.63100
# 27  night  0.376     0.200      0.611   0.371       0.46455
# 28    day  0.538     0.314      0.707   0.473       0.67155
# 29  night  0.389     0.205      0.658   0.334       0.47745
# 30    day  0.441     0.249      0.785   0.390       0.54765
# 31  night  0.308     0.178      0.535   0.288       0.38470
# 32    day  0.506     0.291      0.738   0.461       0.63090
# 33  night  0.376     0.200      0.612   0.370       0.46450
# 34    day  0.538     0.314      0.707   0.473       0.67155
# 35  night  0.389     0.203      0.657   0.334       0.47675
# 36    day  0.441     0.249      0.785   0.390       0.54765
# 37  night  0.308     0.178      0.535   0.287       0.38465
# 38    day  0.506     0.291      0.738   0.461       0.63090
# 39  night  0.376     0.200      0.612   0.370       0.46450
# 40    day  0.538     0.314      0.707   0.473       0.67155
# 41  night  0.389     0.203      0.655   0.334       0.47675
# 42    day  0.442     0.249      0.782   0.391       0.54870
# 43  night  0.309     0.178      0.544   0.283       0.38545
# 44    day  0.506     0.291      0.734   0.464       0.63105
# 45  night  0.377     0.200      0.637   0.360       0.46500
# 46    day  0.538     0.315      0.704   0.474       0.67195
# 47  night  0.389     0.203      0.661   0.334       0.47675
# 48    day  0.441     0.249      0.785   0.390       0.54765
# 49  night  0.308     0.177      0.537   0.286       0.38425
# 50    day  0.506     0.291      0.733   0.463       0.63100
# 51  night  0.376     0.200      0.608   0.371       0.46455
# 52    day  0.538     0.315      0.707   0.473       0.67190
# 53  night  0.388     0.202      0.658   0.334       0.47540
# # DQA-SoftMoX Domain-Slice Judger 08
#
# - created_utc: 2026-05-13T15:24:59.661116+00:00
# - candidates: 9
# - domains: 6
#
# | rank | candidate | total score | day score | night score | worst score | DRO score | night mAP50 |
# |---:|---|---:|---:|---:|---:|---:|---:|
# | 1 | r006_scaled04_best01_rand000_050 | 0.5741 | 0.6172 | 0.4424 | 0.3854 | 0.4660 | 0.358 |
# | 2 | r003_tiny_all_s | 0.5735 | 0.6168 | 0.4425 | 0.3846 | 0.4658 | 0.358 |
# | 3 | r003_rand003 | 0.5741 | 0.6166 | 0.4425 | 0.3846 | 0.4658 | 0.358 |
# | 4 | r005_scaled04_best01_sur00_02_025 | 0.5745 | 0.6167 | 0.4420 | 0.3847 | 0.4655 | 0.358 |
# | 5 | r005_scaled04_best00_slight_extrapolate_target_025 | 0.5745 | 0.6167 | 0.4420 | 0.3846 | 0.4654 | 0.358 |
# | 6 | incumbent_r002 | 0.5746 | 0.6167 | 0.4421 | 0.3842 | 0.4654 | 0.358 |
# | 7 | r004_scaled04_best00_rand008_050 | 0.5741 | 0.6167 | 0.4419 | 0.3845 | 0.4654 | 0.358 |
# | 8 | r006_anti_drift_head | 0.5746 | 0.6169 | 0.4414 | 0.3842 | 0.4651 | 0.357 |
# | 9 | r004_anti_drift_head | 0.5746 | 0.6167 | 0.4417 | 0.3831 | 0.4650 | 0.357 |
