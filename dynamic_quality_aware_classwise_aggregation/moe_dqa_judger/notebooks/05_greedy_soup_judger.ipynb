# %% [markdown]
# # 05 Greedy Soup Judger
#
# This experiment changes the objective: instead of always choosing a fresh round
# mixture, it builds a monotonic global model by greedily adding only checkpoints
# that improve the proxy score.  This is inspired by model soups and gives the
# judger a built-in "do not get worse as rounds/candidates increase" mechanism.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path('/app/Object_Detection')
PROJECT = ROOT / 'dynamic_quality_aware_classwise_aggregation' / 'moe_dqa_judger'
OUT = PROJECT / 'output' / '05_greedy_soup_judger'
OUT
# Out:
# PosixPath('/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/05_greedy_soup_judger')

# %%
import subprocess, sys

cmd = [
    sys.executable,
    str(PROJECT / 'scripts' / 'run_05_greedy_soup_judger.py'),
    '--workspace-root', str(OUT),
    '--max-round', '6',
    '--mini-images', '512',
    '--max-candidates', '36',
    '--greedy-limit', '24',
    '--full-eval-last', '6',
    '--val-batch-size', '32',
    '--notify-discord',
    '--force',
]
print(' '.join(cmd))
subprocess.run(cmd, cwd=ROOT, check=True)
# Out:
# /opt/venv/bin/python3 /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/scripts/run_05_greedy_soup_judger.py --workspace-root /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/05_greedy_soup_judger --max-round 6 --mini-images 512 --max-candidates 36 --greedy-limit 24 --full-eval-last 6 --val-batch-size 32 --notify-discord --force
# {
#   "manifest": {
#     "created_utc": "2026-05-13T14:00:38.648322+00:00",
#     "protocol": "dqa_softmox_greedy_soup_judger_v0",
#     "method": "greedy proxy-monotonic model soup over self-generated checkpoints",
#     "workspace": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/05_greedy_soup_judger",
#     "source_workspace": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa/output/01_dqa_fedmox_yolo_full",
#     "max_round": 6,
#     "mini_images": 512
#   },
#   "accepted": [
#     {
#       "step": 1,
#       "action": "seed",
#       "candidate": "r001_best02_sur01_01",
#       "accepted": true,
#       "member_count": 1,
#       "score": 0.6481,
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/02_mix_weight_optimizer_expanded/candidates/r001_best02_sur01_01.pt",
#       "map50": 0.522,
#       "map50_95": 0.291
#     }
#   ],
#   "full": [
#     {
#       "step": 1,
#       "action": "seed",
#       "candidate": "r001_best02_sur01_01",
#       "accepted": true,
#       "member_count": 1,
#       "score": 0.57395,
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/02_mix_weight_optimizer_expanded/candidates/r001_best02_sur01_01.pt",
#       "map50": 0.462,
#       "map50_95": 0.259,
#       "eval_scope": "full_total",
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/05_greedy_soup_judger/validation_logs/full_r001_best02_sur01_01.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/02_mix_weight_optimizer_expanded/candidates/r001_best02_sur01_01.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa/output/01_dqa_fedmox_yolo_full/validation_reports/paper_protocol_configs/scene_daynight_total.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/05_greedy_soup_judger/validation_runs --name full_r001_best02_sur01_01 --exist-ok --no-plots",
#       "images": 9087.0,
#       "labels": 169419.0,
#       "precision": 0.709,
#       "recall": 0.426
#     }
#   ]
# }
# CompletedProcess(args=['/opt/venv/bin/python3', '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/scripts/run_05_greedy_soup_judger.py', '--workspace-root', '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/05_greedy_soup_judger', '--max-round', '6', '--mini-images', '512', '--max-candidates', '36', '--greedy-limit', '24', '--full-eval-last', '6', '--val-batch-size', '32', '--notify-discord', '--force'], returncode=0)

# %%
steps = pd.read_csv(OUT / 'stats' / '05_greedy_soup_steps.csv')
display(steps[steps['accepted'] == True][['step','candidate','member_count','map50','map50_95','score']])

full = pd.read_csv(OUT / 'stats' / '05_greedy_soup_full_eval.csv')
display(full[['step','candidate','member_count','map50','map50_95','precision','recall','score']])

print((OUT / '05_greedy_soup_judger_report.md').read_text())
# Out:
#    step             candidate  member_count  map50  map50_95   score
# 0     1  r001_best02_sur01_01             1  0.522     0.291  0.6481
#    step             candidate  member_count  map50  map50_95  precision  \
# 0     1  r001_best02_sur01_01             1  0.462     0.259      0.709
#
#    recall    score
# 0   0.426  0.57395
# # DQA-SoftMoX Greedy Soup Judger 05
#
# - created_utc: 2026-05-13T14:09:42.897913+00:00
# - pool_size: 45
# - evaluated_individuals: 36
#
# ## Accepted Mini Path
#
# | step | candidate | members | mini mAP50 | mini mAP50:95 | mini score |
# |---:|---|---:|---:|---:|---:|
# | 1 | r001_best02_sur01_01 | 1 | 0.522 | 0.291 | 0.6481 |
#
# ## Full Evaluation
#
# | step | candidate | members | mAP50 | mAP50:95 | score |
# |---:|---|---:|---:|---:|---:|
# | 1 | r001_best02_sur01_01 | 1 | 0.462 | 0.259 | 0.5739 |
