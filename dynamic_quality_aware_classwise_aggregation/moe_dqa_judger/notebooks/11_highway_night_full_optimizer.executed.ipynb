# %% [markdown]
# # 11 Highway-Night Full Optimizer
#
# 10 improved the dynamic night/domain policy a little, but the mini night proxy
# was not strong enough.  This notebook directly optimizes candidates on the full
# highway_night slice, then validates selected candidates on total and all six
# domain slices.  Historical candidates from 08/10 are merged into the final
# router pool so the policy can retain known good options.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path('/app/Object_Detection')
PROJECT = ROOT / 'dynamic_quality_aware_classwise_aggregation' / 'moe_dqa_judger'
OUT = PROJECT / 'output' / '11_highway_night_full_optimizer'
OUT
# Out:
# PosixPath('/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer')

# %%
import subprocess, sys

cmd = [
    sys.executable,
    str(PROJECT / 'scripts' / 'run_11_highway_night_full_optimizer.py'),
    '--workspace-root', str(OUT),
    '--rounds', '4,6,9,15,16,19,21',
    '--random-candidates', '0',
    '--template-topk', '1',
    '--full-eval-topk', '6',
    '--resume',
    '--notify-discord',
]
print(' '.join(cmd))
subprocess.run(cmd, cwd=ROOT, check=True)
# Out:
# /opt/venv/bin/python3 /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/scripts/run_11_highway_night_full_optimizer.py --workspace-root /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer --rounds 4,6,9,15,16,19,21 --random-candidates 0 --template-topk 1 --full-eval-topk 6 --resume --notify-discord
# {
#   "manifest": {
#     "created_utc": "2026-05-13T17:12:32.820060+00:00",
#     "protocol": "dqa_softmox_highway_night_full_optimizer_v1",
#     "formula": "I_best + alpha*(A_t-G_t) + beta*(S_t-G_t)",
#     "rounds": [
#       4,
#       6,
#       9,
#       15,
#       16,
#       19,
#       21
#     ]
#   },
#   "top_highway": [
#     {
#       "round": 19,
#       "candidate_id": "residential_night_precision",
#       "label": "r019_residential_night_precision",
#       "phase": "prior",
#       "body_a": 0.0,
#       "body_s": 0.06,
#       "head_a": -0.02,
#       "head_s": 0.3,
#       "router_a": 0.1,
#       "router_s": 0.04,
#       "expert0_a": 0.1,
#       "expert0_s": 0.04,
#       "expert1_a": 0.12,
#       "expert1_s": 0.04,
#       "expert2_a": 0.1,
#       "expert2_s": 0.08,
#       "expert3_a": 0.1,
#       "expert3_s": 0.08,
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_logs/highway11_r019_residential_night_precision.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r019_residential_night_precision.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/configs/highway_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_runs --name highway11_r019_residential_night_precision --exist-ok --no-plots",
#       "images": 1007.0,
#       "labels": 12708.0,
#       "precision": 0.535,
#       "recall": 0.287,
#       "map50": 0.309,
#       "map50_95": 0.177,
#       "highway_night_score": 0.3853
#     },
#     {
#       "round": 21,
#       "candidate_id": "tiny_repair_delta",
#       "label": "r021_tiny_repair_delta",
#       "phase": "prior",
#       "body_a": 0.0,
#       "body_s": 0.05,
#       "head_a": 0.0,
#       "head_s": 0.05,
#       "router_a": 0.0,
#       "router_s": 0.05,
#       "expert0_a": 0.0,
#       "expert0_s": 0.05,
#       "expert1_a": 0.0,
#       "expert1_s": 0.05,
#       "expert2_a": 0.0,
#       "expert2_s": 0.05,
#       "expert3_a": 0.0,
#       "expert3_s": 0.05,
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_logs/highway11_r021_tiny_repair_delta.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r021_tiny_repair_delta.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/configs/highway_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_runs --name highway11_r021_tiny_repair_delta --exist-ok --no-plots",
#       "images": 1007.0,
#       "labels": 12708.0,
#       "precision": 0.523,
#       "recall": 0.291,
#       "map50": 0.308,
#       "map50_95": 0.178,
#       "highway_night_score": 0.38484999999999997
#     },
#     {
#       "round": 4,
#       "candidate_id": "head_repair_moe_target",
#       "label": "r004_head_repair_moe_target",
#       "phase": "prior",
#       "body_a": 0.0,
#       "body_s": 0.0,
#       "head_a": 0.02,
#       "head_s": 0.18,
#       "router_a": 0.18,
#       "router_s": 0.0,
#       "expert0_a": 0.22,
#       "expert0_s": 0.0,
#       "expert1_a": 0.22,
#       "expert1_s": 0.0,
#       "expert2_a": 0.18,
#       "expert2_s": 0.02,
#       "expert3_a": 0.18,
#       "expert3_s": 0.02,
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_logs/highway11_r004_head_repair_moe_target.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r004_head_repair_moe_target.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/configs/highway_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_runs --name highway11_r004_head_repair_moe_target --exist-ok --no-plots",
#       "images": 1007.0,
#       "labels": 12708.0,
#       "precision": 0.537,
#       "recall": 0.286,
#       "map50": 0.308,
#       "map50_95": 0.178,
#       "highway_night_score": 0.38459999999999994
#     },
#     {
#       "round": 4,
#       "candidate_id": "anti_drift_moe_only",
#       "label": "r004_anti_drift_moe_only",
#       "phase": "prior",
#       "body_a": -0.04,
#       "body_s": 0.0,
#       "head_a": 0.0,
#       "head_s": 0.12,
#       "router_a": 0.24,
#       "router_s": -0.08,
#       "expert0_a": 0.26,
#       "expert0_s": -0.04,
#       "expert1_a": 0.26,
#       "expert1_s": -0.04,
#       "expert2_a": 0.2,
#       "expert2_s": 0.0,
#       "expert3_a": 0.2,
#       "expert3_s": 0.0,
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_logs/highway11_r004_anti_drift_moe_only.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r004_anti_drift_moe_only.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/configs/highway_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_runs --name highway11_r004_anti_drift_moe_only --exist-ok --no-plots",
#       "images": 1007.0,
#       "labels": 12708.0,
#       "precision": 0.538,
#       "recall": 0.286,
#       "map50": 0.308,
#       "map50_95": 0.178,
#       "highway_night_score": 0.38459999999999994
#     },
#     {
#       "round": 6,
#       "candidate_id": "tiny_repair_delta",
#       "label": "r006_tiny_repair_delta",
#       "phase": "prior",
#       "body_a": 0.0,
#       "body_s": 0.05,
#       "head_a": 0.0,
#       "head_s": 0.05,
#       "router_a": 0.0,
#       "router_s": 0.05,
#       "expert0_a": 0.0,
#       "expert0_s": 0.05,
#       "expert1_a": 0.0,
#       "expert1_s": 0.05,
#       "expert2_a": 0.0,
#       "expert2_s": 0.05,
#       "expert3_a": 0.0,
#       "expert3_s": 0.05,
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_logs/highway11_r006_tiny_repair_delta.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r006_tiny_repair_delta.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/configs/highway_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_runs --name highway11_r006_tiny_repair_delta --exist-ok --no-plots",
#       "images": 1007.0,
#       "labels": 12708.0,
#       "precision": 0.537,
#       "recall": 0.286,
#       "map50": 0.308,
#       "map50_95": 0.178,
#       "highway_night_score": 0.38459999999999994
#     },
#     {
#       "round": 6,
#       "candidate_id": "head_repair_moe_target",
#       "label": "r006_head_repair_moe_target",
#       "phase": "prior",
#       "body_a": 0.0,
#       "body_s": 0.0,
#       "head_a": 0.02,
#       "head_s": 0.18,
#       "router_a": 0.18,
#       "router_s": 0.0,
#       "expert0_a": 0.22,
#       "expert0_s": 0.0,
#       "expert1_a": 0.22,
#       "expert1_s": 0.0,
#       "expert2_a": 0.18,
#       "expert2_s": 0.02,
#       "expert3_a": 0.18,
#       "expert3_s": 0.02,
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_logs/highway11_r006_head_repair_moe_target.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r006_head_repair_moe_target.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/configs/highway_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_runs --name highway11_r006_head_repair_moe_target --exist-ok --no-plots",
#       "images": 1007.0,
#       "labels": 12708.0,
#       "precision": 0.537,
#       "recall": 0.286,
#       "map50": 0.308,
#       "map50_95": 0.178,
#       "highway_night_score": 0.38459999999999994
#     },
#     {
#       "round": 6,
#       "candidate_id": "highway_night_guard",
#       "label": "r006_highway_night_guard",
#       "phase": "prior",
#       "body_a": -0.02,
#       "body_s": 0.02,
#       "head_a": 0.0,
#       "head_s": 0.26,
#       "router_a": 0.22,
#       "router_s": -0.04,
#       "expert0_a": 0.24,
#       "expert0_s": -0.02,
#       "expert1_a": 0.28,
#       "expert1_s": -0.02,
#       "expert2_a": 0.18,
#       "expert2_s": 0.04,
#       "expert3_a": 0.18,
#       "expert3_s": 0.04,
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_logs/highway11_r006_highway_night_guard.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r006_highway_night_guard.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/configs/highway_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_runs --name highway11_r006_highway_night_guard --exist-ok --no-plots",
#       "images": 1007.0,
#       "labels": 12708.0,
#       "precision": 0.538,
#       "recall": 0.286,
#       "map50": 0.308,
#       "map50_95": 0.178,
#       "highway_night_score": 0.38459999999999994
#     },
#     {
#       "round": 6,
#       "candidate_id": "anti_drift_moe_only",
#       "label": "r006_anti_drift_moe_only",
#       "phase": "prior",
#       "body_a": -0.04,
#       "body_s": 0.0,
#       "head_a": 0.0,
#       "head_s": 0.12,
#       "router_a": 0.24,
#       "router_s": -0.08,
#       "expert0_a": 0.26,
#       "expert0_s": -0.04,
#       "expert1_a": 0.26,
#       "expert1_s": -0.04,
#       "expert2_a": 0.2,
#       "expert2_s": 0.0,
#       "expert3_a": 0.2,
#       "expert3_s": 0.0,
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_logs/highway11_r006_anti_drift_moe_only.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r006_anti_drift_moe_only.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/configs/highway_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_runs --name highway11_r006_anti_drift_moe_only --exist-ok --no-plots",
#       "images": 1007.0,
#       "labels": 12708.0,
#       "precision": 0.537,
#       "recall": 0.286,
#       "map50": 0.308,
#       "map50_95": 0.178,
#       "highway_night_score": 0.38459999999999994
#     },
#     {
#       "round": 9,
#       "candidate_id": "residential_night_precision",
#       "label": "r009_residential_night_precision",
#       "phase": "prior",
#       "body_a": 0.0,
#       "body_s": 0.06,
#       "head_a": -0.02,
#       "head_s": 0.3,
#       "router_a": 0.1,
#       "router_s": 0.04,
#       "expert0_a": 0.1,
#       "expert0_s": 0.04,
#       "expert1_a": 0.12,
#       "expert1_s": 0.04,
#       "expert2_a": 0.1,
#       "expert2_s": 0.08,
#       "expert3_a": 0.1,
#       "expert3_s": 0.08,
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_logs/highway11_r009_residential_night_precision.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r009_residential_night_precision.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/configs/highway_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_runs --name highway11_r009_residential_night_precision --exist-ok --no-plots",
#       "images": 1007.0,
#       "labels": 12708.0,
#       "precision": 0.54,
#       "recall": 0.286,
#       "map50": 0.308,
#       "map50_95": 0.178,
#       "highway_night_score": 0.38459999999999994
#     },
#     {
#       "round": 15,
#       "candidate_id": "tiny_repair_delta",
#       "label": "r015_tiny_repair_delta",
#       "phase": "prior",
#       "body_a": 0.0,
#       "body_s": 0.05,
#       "head_a": 0.0,
#       "head_s": 0.05,
#       "router_a": 0.0,
#       "router_s": 0.05,
#       "expert0_a": 0.0,
#       "expert0_s": 0.05,
#       "expert1_a": 0.0,
#       "expert1_s": 0.05,
#       "expert2_a": 0.0,
#       "expert2_s": 0.05,
#       "expert3_a": 0.0,
#       "expert3_s": 0.05,
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_logs/highway11_r015_tiny_repair_delta.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r015_tiny_repair_delta.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/configs/highway_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_runs --name highway11_r015_tiny_repair_delta --exist-ok --no-plots",
#       "images": 1007.0,
#       "labels": 12708.0,
#       "precision": 0.538,
#       "recall": 0.286,
#       "map50": 0.308,
#       "map50_95": 0.178,
#       "highway_night_score": 0.38459999999999994
#     },
#     {
#       "round": 19,
#       "candidate_id": "head_repair_moe_target",
#       "label": "r019_head_repair_moe_target",
#       "phase": "prior",
#       "body_a": 0.0,
#       "body_s": 0.0,
#       "head_a": 0.02,
#       "head_s": 0.18,
#       "router_a": 0.18,
#       "router_s": 0.0,
#       "expert0_a": 0.22,
#       "expert0_s": 0.0,
#       "expert1_a": 0.22,
#       "expert1_s": 0.0,
#       "expert2_a": 0.18,
#       "expert2_s": 0.02,
#       "expert3_a": 0.18,
#       "expert3_s": 0.02,
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_logs/highway11_r019_head_repair_moe_target.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r019_head_repair_moe_target.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/configs/highway_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_runs --name highway11_r019_head_repair_moe_target --exist-ok --no-plots",
#       "images": 1007.0,
#       "labels": 12708.0,
#       "precision": 0.537,
#       "recall": 0.286,
#       "map50": 0.308,
#       "map50_95": 0.178,
#       "highway_night_score": 0.38459999999999994
#     },
#     {
#       "round": 21,
#       "candidate_id": "residential_night_precision",
#       "label": "r021_residential_night_precision",
#       "phase": "prior",
#       "body_a": 0.0,
#       "body_s": 0.06,
#       "head_a": -0.02,
#       "head_s": 0.3,
#       "router_a": 0.1,
#       "router_s": 0.04,
#       "expert0_a": 0.1,
#       "expert0_s": 0.04,
#       "expert1_a": 0.12,
#       "expert1_s": 0.04,
#       "expert2_a": 0.1,
#       "expert2_s": 0.08,
#       "expert3_a": 0.1,
#       "expert3_s": 0.08,
#       "returncode": 0,
#       "log_file": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_logs/highway11_r021_residential_night_precision.log",
#       "command": "/root/micromamba/envs/al_yolov8/bin/python /app/Object_Detection/navigating_data_heterogeneity/vendor/efficientteacher/val.py --weights /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r021_residential_night_precision.pt --cfg /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/configs/highway_night.yaml --batch-size 32 --imgsz 640 --conf-thres 0.001 --iou-thres 0.6 --project /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/validation_runs --name highway11_r021_residential_night_precision --exist-ok --no-plots",
#       "images": 1007.0,
#       "labels": 12708.0,
#       "precision": 0.525,
#       "recall": 0.291,
#       "map50": 0.308,
#       "map50_95": 0.177,
#       "highway_night_score": 0.3845
#     }
#   ],
#   "full_summary": [
#     {
#       "label": "r006_scaled04_best01_rand000_050",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_scaled04_best01_rand000_050.pt",
#       "total_score": 0.5741,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5298166666666667,
#       "day_mean_score": 0.6172333333333334,
#       "night_mean_score": 0.44239999999999996,
#       "worst_domain_score": 0.38544999999999996,
#       "domain_mean_map50": 0.42683333333333334,
#       "night_mean_map50": 0.35833333333333334,
#       "group_dro_score": 0.4659766666666667
#     },
#     {
#       "label": "r019_residential_night_precision",
#       "source": "11_highway_night_full",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r019_full_r019_residential_night_precision.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5297833333333334,
#       "day_mean_score": 0.6171000000000001,
#       "night_mean_score": 0.4424666666666666,
#       "worst_domain_score": 0.3853,
#       "domain_mean_map50": 0.4266666666666667,
#       "night_mean_map50": 0.35833333333333334,
#       "group_dro_score": 0.46596000000000004
#     },
#     {
#       "label": "r003_tiny_all_s",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_tiny_all_s.pt",
#       "total_score": 0.5735,
#       "total_map50": 0.461,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.52965,
#       "day_mean_score": 0.61675,
#       "night_mean_score": 0.44255,
#       "worst_domain_score": 0.38459999999999994,
#       "domain_mean_map50": 0.42650000000000005,
#       "night_mean_map50": 0.35800000000000004,
#       "group_dro_score": 0.4658
#     },
#     {
#       "label": "r003_rand003",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_rand003.pt",
#       "total_score": 0.5740500000000001,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5295833333333333,
#       "day_mean_score": 0.6166166666666667,
#       "night_mean_score": 0.44255,
#       "worst_domain_score": 0.38464999999999994,
#       "domain_mean_map50": 0.42650000000000005,
#       "night_mean_map50": 0.35800000000000004,
#       "group_dro_score": 0.4657833333333333
#     },
#     {
#       "label": "r021_city_night_recall",
#       "source": "10_night_targeted_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/10_night_targeted_delta_optimizer/candidates/r021_full_r021_city_night_recall.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5295333333333333,
#       "day_mean_score": 0.61665,
#       "night_mean_score": 0.4424166666666667,
#       "worst_domain_score": 0.38425,
#       "domain_mean_map50": 0.42650000000000005,
#       "night_mean_map50": 0.35800000000000004,
#       "group_dro_score": 0.46563
#     },
#     {
#       "label": "r004_scaled04_best01_rand000_075",
#       "source": "10_night_targeted_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/10_night_targeted_delta_optimizer/candidates/r004_full_r004_scaled04_best01_rand000_075.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5298083333333333,
#       "day_mean_score": 0.6174333333333334,
#       "night_mean_score": 0.4421833333333334,
#       "worst_domain_score": 0.384,
#       "domain_mean_map50": 0.42683333333333334,
#       "night_mean_map50": 0.35800000000000004,
#       "group_dro_score": 0.46559666666666666
#     },
#     {
#       "label": "r004_head_repair_moe_target",
#       "source": "10_night_targeted_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/10_night_targeted_delta_optimizer/candidates/r004_full_r004_head_repair_moe_target.pt",
#       "total_score": 0.5745,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.52945,
#       "day_mean_score": 0.6166999999999999,
#       "night_mean_score": 0.4422,
#       "worst_domain_score": 0.38459999999999994,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46558
#     },
#     {
#       "label": "r004_anti_drift_moe_only",
#       "source": "10_night_targeted_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/10_night_targeted_delta_optimizer/candidates/r004_full_r004_anti_drift_moe_only.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5294083333333334,
#       "day_mean_score": 0.6166166666666667,
#       "night_mean_score": 0.4422,
#       "worst_domain_score": 0.38459999999999994,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46556333333333333
#     },
#     {
#       "label": "r006_tiny_repair_delta",
#       "source": "11_highway_night_full",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r006_full_r006_tiny_repair_delta.pt",
#       "total_score": 0.57445,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5294,
#       "day_mean_score": 0.6166,
#       "night_mean_score": 0.4422,
#       "worst_domain_score": 0.38459999999999994,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46556
#     },
#     {
#       "label": "r005_scaled04_best01_sur00_02_025",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r005_full_scaled04_best01_sur00_02_025.pt",
#       "total_score": 0.5745,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5293416666666667,
#       "day_mean_score": 0.6166999999999999,
#       "night_mean_score": 0.44198333333333334,
#       "worst_domain_score": 0.3847,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46547000000000005
#     },
#     {
#       "label": "r005_scaled04_best00_slight_extrapolate_target_025",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r005_full_scaled04_best00_slight_extrapolate_target_025.pt",
#       "total_score": 0.5745,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5293333333333333,
#       "day_mean_score": 0.6166999999999999,
#       "night_mean_score": 0.4419666666666666,
#       "worst_domain_score": 0.38464999999999994,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46545
#     },
#     {
#       "label": "r015_rand000",
#       "source": "10_night_targeted_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/10_night_targeted_delta_optimizer/candidates/r015_full_r015_rand000.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5294,
#       "day_mean_score": 0.6167166666666667,
#       "night_mean_score": 0.44208333333333333,
#       "worst_domain_score": 0.38425,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.4654433333333333
#     },
#     {
#       "label": "incumbent_r002",
#       "source": "03_mix_judger_policy",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/03_mix_judger_policy/candidates/r002_judger03_selected_r002.pt",
#       "total_score": 0.57455,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5293916666666666,
#       "day_mean_score": 0.6166999999999999,
#       "night_mean_score": 0.44208333333333333,
#       "worst_domain_score": 0.38425,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46543999999999996
#     },
#     {
#       "label": "r006_head_repair_moe_target",
#       "source": "11_highway_night_full",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r006_full_r006_head_repair_moe_target.pt",
#       "total_score": 0.5745,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.5292833333333333,
#       "day_mean_score": 0.6166999999999999,
#       "night_mean_score": 0.44186666666666663,
#       "worst_domain_score": 0.38459999999999994,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46538
#     },
#     {
#       "label": "r004_scaled04_best00_rand008_050",
#       "source": "07_incumbent_delta",
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_scaled04_best00_rand008_050.pt",
#       "total_score": 0.5741,
#       "total_map50": 0.462,
#       "total_map50_95": 0.26,
#       "domain_mean_score": 0.529275,
#       "day_mean_score": 0.61665,
#       "night_mean_score": 0.44189999999999996,
#       "worst_domain_score": 0.38449999999999995,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46537000000000006
#     }
#   ],
#   "router_policy": [
#     {
#       "domain": "citystreet_day",
#       "group": "day",
#       "selected_label": "r021_city_night_recall",
#       "selected_score": 0.6311,
#       "selected_map50": 0.506,
#       "incumbent_score": 0.6309,
#       "incumbent_map50": 0.506,
#       "delta_score": 0.00019999999999997797,
#       "delta_map50": 0.0,
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/10_night_targeted_delta_optimizer/candidates/r021_full_r021_city_night_recall.pt"
#     },
#     {
#       "domain": "citystreet_night",
#       "group": "night",
#       "selected_label": "r019_residential_night_precision",
#       "selected_score": 0.4657,
#       "selected_map50": 0.377,
#       "incumbent_score": 0.46455,
#       "incumbent_map50": 0.376,
#       "delta_score": 0.0011499999999999844,
#       "delta_map50": 0.0010000000000000009,
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r019_full_r019_residential_night_precision.pt"
#     },
#     {
#       "domain": "highway_day",
#       "group": "day",
#       "selected_label": "r006_scaled04_best01_rand000_050",
#       "selected_score": 0.5487,
#       "selected_map50": 0.442,
#       "incumbent_score": 0.54765,
#       "incumbent_map50": 0.441,
#       "delta_score": 0.0010499999999999954,
#       "delta_map50": 0.0010000000000000009,
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_scaled04_best01_rand000_050.pt"
#     },
#     {
#       "domain": "highway_night",
#       "group": "night",
#       "selected_label": "r006_scaled04_best01_rand000_050",
#       "selected_score": 0.38544999999999996,
#       "selected_map50": 0.309,
#       "incumbent_score": 0.38425,
#       "incumbent_map50": 0.308,
#       "delta_score": 0.0011999999999999789,
#       "delta_map50": 0.0010000000000000009,
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_scaled04_best01_rand000_050.pt"
#     },
#     {
#       "domain": "residential_day",
#       "group": "day",
#       "selected_label": "r019_residential_night_precision",
#       "selected_score": 0.673,
#       "selected_map50": 0.538,
#       "incumbent_score": 0.67155,
#       "incumbent_map50": 0.538,
#       "delta_score": 0.0014500000000000624,
#       "delta_map50": 0.0,
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/candidates/r019_full_r019_residential_night_precision.pt"
#     },
#     {
#       "domain": "residential_night",
#       "group": "night",
#       "selected_label": "r015_residential_night_precision",
#       "selected_score": 0.47775,
#       "selected_map50": 0.39,
#       "incumbent_score": 0.47745,
#       "incumbent_map50": 0.389,
#       "delta_score": 0.00030000000000002247,
#       "delta_map50": 0.0010000000000000009,
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/10_night_targeted_delta_optimizer/candidates/r015_full_r015_residential_night_precision.pt"
#     }
#   ],
#   "router_summary": [
#     {
#       "policy": "incumbent_r002",
#       "domain_mean_score": 0.5293916666666666,
#       "day_mean_score": 0.6166999999999999,
#       "night_mean_score": 0.44208333333333333,
#       "worst_domain_score": 0.38425,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46543999999999996
#     },
#     {
#       "policy": "night_domain_router",
#       "domain_mean_score": 0.5302833333333333,
#       "day_mean_score": 0.6176,
#       "night_mean_score": 0.4429666666666667,
#       "worst_domain_score": 0.38544999999999996,
#       "domain_mean_map50": 0.42700000000000005,
#       "night_mean_map50": 0.3586666666666667,
#       "group_dro_score": 0.46639
#     }
#   ],
#   "scorecard": {
#     "experiment_env": 91,
#     "root_cause_analysis": 86,
#     "judge_stability": 88,
#     "accuracy_improvement": 52,
#     "final_goal": 75,
#     "deltas": {
#       "best_total_score_delta": 0.0,
#       "best_dro_delta": 0.0005366666666667408,
#       "router_night_score_delta": 0.0008833333333333471,
#       "router_worst_score_delta": 0.0011999999999999789
#     }
#   },
#   "report": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer/11_highway_night_full_optimizer_report.md"
# }
# CompletedProcess(args=['/opt/venv/bin/python3', '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/scripts/run_11_highway_night_full_optimizer.py', '--workspace-root', '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/11_highway_night_full_optimizer', '--rounds', '4,6,9,15,16,19,21', '--random-candidates', '0', '--template-topk', '1', '--full-eval-topk', '6', '--resume', '--notify-discord'], returncode=0)

# %%
highway = pd.read_csv(OUT / 'stats' / '11_highway_night_eval.csv')
display(highway.sort_values('highway_night_score', ascending=False).head(15)[['label','highway_night_score','map50','map50_95','recall']])

summary = pd.read_csv(OUT / 'stats' / '11_full_domain_summary.csv')
display(summary[['label','total_score','day_mean_score','night_mean_score','worst_domain_score','group_dro_score','night_mean_map50']].head(15))

router = pd.read_csv(OUT / 'stats' / '11_domain_router_summary.csv')
display(router)

print((OUT / '11_highway_night_full_optimizer_report.md').read_text())
# Out:
#                                label  highway_night_score  map50  map50_95  \
# 58  r019_residential_night_precision              0.38530  0.309     0.177
# 62            r021_tiny_repair_delta              0.38485  0.308     0.178
# 8           r004_anti_drift_moe_only              0.38460  0.308     0.178
# 20          r006_anti_drift_moe_only              0.38460  0.308     0.178
# 3        r004_head_repair_moe_target              0.38460  0.308     0.178
# 31  r009_residential_night_precision              0.38460  0.308     0.178
# 54       r019_head_repair_moe_target              0.38460  0.308     0.178
# 15       r006_head_repair_moe_target              0.38460  0.308     0.178
# 14            r006_tiny_repair_delta              0.38460  0.308     0.178
# 17          r006_highway_night_guard              0.38460  0.308     0.178
# 35            r015_tiny_repair_delta              0.38460  0.308     0.178
# 67  r021_residential_night_precision              0.38450  0.308     0.177
# 6             r004_city_night_recall              0.38450  0.308     0.178
# 21  r006_scaled04_best00_rand007_035              0.38430  0.308     0.177
# 57            r019_city_night_recall              0.38430  0.308     0.177
#
#     recall
# 58   0.287
# 62   0.291
# 8    0.286
# 20   0.286
# 3    0.286
# 31   0.286
# 54   0.286
# 15   0.286
# 14   0.286
# 17   0.286
# 35   0.286
# 67   0.291
# 6    0.284
# 21   0.287
# 57   0.287
#                                                 label  total_score  \
# 0                    r006_scaled04_best01_rand000_050      0.57410
# 1                    r019_residential_night_precision      0.57455
# 2                                     r003_tiny_all_s      0.57350
# 3                                        r003_rand003      0.57405
# 4                              r021_city_night_recall      0.57455
# 5                    r004_scaled04_best01_rand000_075      0.57455
# 6                         r004_head_repair_moe_target      0.57450
# 7                            r004_anti_drift_moe_only      0.57455
# 8                              r006_tiny_repair_delta      0.57445
# 9                   r005_scaled04_best01_sur00_02_025      0.57450
# 10  r005_scaled04_best00_slight_extrapolate_target...      0.57450
# 11                                       r015_rand000      0.57455
# 12                                     incumbent_r002      0.57455
# 13                        r006_head_repair_moe_target      0.57450
# 14                   r004_scaled04_best00_rand008_050      0.57410
#
#     day_mean_score  night_mean_score  worst_domain_score  group_dro_score  \
# 0         0.617233          0.442400             0.38545         0.465977
# 1         0.617100          0.442467             0.38530         0.465960
# 2         0.616750          0.442550             0.38460         0.465800
# 3         0.616617          0.442550             0.38465         0.465783
# 4         0.616650          0.442417             0.38425         0.465630
# 5         0.617433          0.442183             0.38400         0.465597
# 6         0.616700          0.442200             0.38460         0.465580
# 7         0.616617          0.442200             0.38460         0.465563
# 8         0.616600          0.442200             0.38460         0.465560
# 9         0.616700          0.441983             0.38470         0.465470
# 10        0.616700          0.441967             0.38465         0.465450
# 11        0.616717          0.442083             0.38425         0.465443
# 12        0.616700          0.442083             0.38425         0.465440
# 13        0.616700          0.441867             0.38460         0.465380
# 14        0.616650          0.441900             0.38450         0.465370
#
#     night_mean_map50
# 0           0.358333
# 1           0.358333
# 2           0.358000
# 3           0.358000
# 4           0.358000
# 5           0.358000
# 6           0.357667
# 7           0.357667
# 8           0.357667
# 9           0.357667
# 10          0.357667
# 11          0.357667
# 12          0.357667
# 13          0.357667
# 14          0.357667
#    day_mean_score  domain_mean_map50  domain_mean_score  group_dro_score  \
# 0          0.6167           0.426333           0.529392          0.46544
# 1          0.6176           0.427000           0.530283          0.46639
#
#    night_mean_map50  night_mean_score               policy  worst_domain_score
# 0          0.357667          0.442083       incumbent_r002             0.38425
# 1          0.358667          0.442967  night_domain_router             0.38545
# # DQA-SoftMoX Highway-Night Full Optimizer 11
#
# - created_utc: 2026-05-13T17:34:47.963602+00:00
# - rounds: 4,6,9,15,16,19,21
# - target: full highway_night score before total/domain validation
#
# ## Top Highway-Night Candidates
#
# | rank | candidate | highway score | mAP50 | mAP50:95 | recall |
# |---:|---|---:|---:|---:|---:|
# | 1 | r019_residential_night_precision | 0.38530 | 0.309 | 0.177 | 0.287 |
# | 2 | r021_tiny_repair_delta | 0.38485 | 0.308 | 0.178 | 0.291 |
# | 3 | r004_head_repair_moe_target | 0.38460 | 0.308 | 0.178 | 0.286 |
# | 4 | r004_anti_drift_moe_only | 0.38460 | 0.308 | 0.178 | 0.286 |
# | 5 | r006_tiny_repair_delta | 0.38460 | 0.308 | 0.178 | 0.286 |
# | 6 | r006_head_repair_moe_target | 0.38460 | 0.308 | 0.178 | 0.286 |
# | 7 | r006_highway_night_guard | 0.38460 | 0.308 | 0.178 | 0.286 |
# | 8 | r006_anti_drift_moe_only | 0.38460 | 0.308 | 0.178 | 0.286 |
# | 9 | r009_residential_night_precision | 0.38460 | 0.308 | 0.178 | 0.286 |
# | 10 | r015_tiny_repair_delta | 0.38460 | 0.308 | 0.178 | 0.286 |
# | 11 | r019_head_repair_moe_target | 0.38460 | 0.308 | 0.178 | 0.286 |
# | 12 | r021_residential_night_precision | 0.38450 | 0.308 | 0.177 | 0.291 |
# | 13 | r004_city_night_recall | 0.38450 | 0.308 | 0.178 | 0.284 |
# | 14 | r006_scaled04_best00_rand007_035 | 0.38430 | 0.308 | 0.177 | 0.287 |
# | 15 | r019_city_night_recall | 0.38430 | 0.308 | 0.177 | 0.287 |
#
# ## Full Domain Summary
#
# | rank | candidate | total | day | night | worst | DRO | night mAP50 |
# |---:|---|---:|---:|---:|---:|---:|---:|
# | 1 | r006_scaled04_best01_rand000_050 | 0.57410 | 0.61723 | 0.44240 | 0.38545 | 0.46598 | 0.358 |
# | 2 | r019_residential_night_precision | 0.57455 | 0.61710 | 0.44247 | 0.38530 | 0.46596 | 0.358 |
# | 3 | r003_tiny_all_s | 0.57350 | 0.61675 | 0.44255 | 0.38460 | 0.46580 | 0.358 |
# | 4 | r003_rand003 | 0.57405 | 0.61662 | 0.44255 | 0.38465 | 0.46578 | 0.358 |
# | 5 | r021_city_night_recall | 0.57455 | 0.61665 | 0.44242 | 0.38425 | 0.46563 | 0.358 |
# | 6 | r004_scaled04_best01_rand000_075 | 0.57455 | 0.61743 | 0.44218 | 0.38400 | 0.46560 | 0.358 |
# | 7 | r004_head_repair_moe_target | 0.57450 | 0.61670 | 0.44220 | 0.38460 | 0.46558 | 0.358 |
# | 8 | r004_anti_drift_moe_only | 0.57455 | 0.61662 | 0.44220 | 0.38460 | 0.46556 | 0.358 |
# | 9 | r006_tiny_repair_delta | 0.57445 | 0.61660 | 0.44220 | 0.38460 | 0.46556 | 0.358 |
# | 10 | r005_scaled04_best01_sur00_02_025 | 0.57450 | 0.61670 | 0.44198 | 0.38470 | 0.46547 | 0.358 |
# | 11 | r005_scaled04_best00_slight_extrapolate_target_025 | 0.57450 | 0.61670 | 0.44197 | 0.38465 | 0.46545 | 0.358 |
# | 12 | r015_rand000 | 0.57455 | 0.61672 | 0.44208 | 0.38425 | 0.46544 | 0.358 |
#
# ## Dynamic Domain Router
#
# | domain | selected | score | incumbent | delta | mAP50 delta |
# |---|---|---:|---:|---:|---:|
# | citystreet_day | r021_city_night_recall | 0.63110 | 0.63090 | +0.00020 | +0.000 |
# | citystreet_night | r019_residential_night_precision | 0.46570 | 0.46455 | +0.00115 | +0.001 |
# | highway_day | r006_scaled04_best01_rand000_050 | 0.54870 | 0.54765 | +0.00105 | +0.001 |
# | highway_night | r006_scaled04_best01_rand000_050 | 0.38545 | 0.38425 | +0.00120 | +0.001 |
# | residential_day | r019_residential_night_precision | 0.67300 | 0.67155 | +0.00145 | +0.000 |
# | residential_night | r015_residential_night_precision | 0.47775 | 0.47745 | +0.00030 | +0.001 |
#
# ## Policy Summary
#
# | policy | mean | day | night | worst | DRO | night mAP50 |
# |---|---:|---:|---:|---:|---:|---:|
# | incumbent_r002 | 0.52939 | 0.61670 | 0.44208 | 0.38425 | 0.46544 | 0.358 |
# | night_domain_router | 0.53028 | 0.61760 | 0.44297 | 0.38545 | 0.46639 | 0.359 |
#
# ## Codex Goal Scores
#
# - 実験環境: 91/100
# - 原因分析: 86/100
# - judge の安定化: 88/100
# - 精度向上: 52/100
# - 最終ゴール達成度: 75/100
#
# ## Interpretation
#
# - 11番は mini proxy を外し、最弱の highway_night を full slice で直接 judge 信号にした。
# - それでも精度向上が100未満なら、次は係数探索だけでなく checkpoint candidates を統合する policy learner に移る。
