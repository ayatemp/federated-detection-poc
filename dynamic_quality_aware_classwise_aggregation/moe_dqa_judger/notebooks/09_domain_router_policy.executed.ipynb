# %% [markdown]
# # 09 Domain Router Policy
#
# 08 showed that the plateau candidates trade off different day/night domains.
# This notebook builds an oracle domain-router policy from those results.  It is
# not the final deployable method, but it tells us whether dynamic domain-specific
# selection has real headroom.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path('/app/Object_Detection')
PROJECT = ROOT / 'dynamic_quality_aware_classwise_aggregation' / 'moe_dqa_judger'
OUT = PROJECT / 'output' / '09_domain_router_policy'
OUT
# Out:
# PosixPath('/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/09_domain_router_policy')

# %%
import subprocess, sys

cmd = [
    sys.executable,
    str(PROJECT / 'scripts' / 'run_09_domain_router_policy.py'),
    '--workspace-root', str(OUT),
    '--min-total-score', '0.5735',
    '--notify-discord',
]
print(' '.join(cmd))
subprocess.run(cmd, cwd=ROOT, check=True)
# Out:
# /opt/venv/bin/python3 /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/scripts/run_09_domain_router_policy.py --workspace-root /app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/09_domain_router_policy --min-total-score 0.5735 --notify-discord
# {
#   "policy": [
#     {
#       "domain": "citystreet_day",
#       "group": "day",
#       "selected_label": "r004_scaled04_best00_rand008_050",
#       "selected_score": 0.63105,
#       "selected_map50": 0.506,
#       "selected_map50_95": 0.291,
#       "incumbent_score": 0.6309,
#       "incumbent_map50": 0.506,
#       "incumbent_map50_95": 0.291,
#       "delta_score": 0.00014999999999998348,
#       "delta_map50": 0.0,
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r004_full_scaled04_best00_rand008_050.pt"
#     },
#     {
#       "domain": "citystreet_night",
#       "group": "night",
#       "selected_label": "r003_rand003",
#       "selected_score": 0.46555,
#       "selected_map50": 0.377,
#       "selected_map50_95": 0.2,
#       "incumbent_score": 0.46455,
#       "incumbent_map50": 0.376,
#       "incumbent_map50_95": 0.2,
#       "delta_score": 0.0010000000000000009,
#       "delta_map50": 0.0010000000000000009,
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_rand003.pt"
#     },
#     {
#       "domain": "highway_day",
#       "group": "day",
#       "selected_label": "r006_scaled04_best01_rand000_050",
#       "selected_score": 0.5487,
#       "selected_map50": 0.442,
#       "selected_map50_95": 0.249,
#       "incumbent_score": 0.54765,
#       "incumbent_map50": 0.441,
#       "incumbent_map50_95": 0.249,
#       "delta_score": 0.0010499999999999954,
#       "delta_map50": 0.0010000000000000009,
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_scaled04_best01_rand000_050.pt"
#     },
#     {
#       "domain": "highway_night",
#       "group": "night",
#       "selected_label": "r006_scaled04_best01_rand000_050",
#       "selected_score": 0.38544999999999996,
#       "selected_map50": 0.309,
#       "selected_map50_95": 0.178,
#       "incumbent_score": 0.38425,
#       "incumbent_map50": 0.308,
#       "incumbent_map50_95": 0.177,
#       "delta_score": 0.0011999999999999789,
#       "delta_map50": 0.0010000000000000009,
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_scaled04_best01_rand000_050.pt"
#     },
#     {
#       "domain": "residential_day",
#       "group": "day",
#       "selected_label": "r006_scaled04_best01_rand000_050",
#       "selected_score": 0.67195,
#       "selected_map50": 0.538,
#       "selected_map50_95": 0.315,
#       "incumbent_score": 0.67155,
#       "incumbent_map50": 0.538,
#       "incumbent_map50_95": 0.314,
#       "delta_score": 0.00040000000000006697,
#       "delta_map50": 0.0,
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r006_full_scaled04_best01_rand000_050.pt"
#     },
#     {
#       "domain": "residential_night",
#       "group": "night",
#       "selected_label": "r003_tiny_all_s",
#       "selected_score": 0.4785,
#       "selected_map50": 0.39,
#       "selected_map50_95": 0.205,
#       "incumbent_score": 0.47745,
#       "incumbent_map50": 0.389,
#       "incumbent_map50_95": 0.205,
#       "delta_score": 0.0010499999999999954,
#       "delta_map50": 0.0010000000000000009,
#       "path": "/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/07_incumbent_delta_judger/candidates/r003_full_tiny_all_s.pt"
#     }
#   ],
#   "summary": [
#     {
#       "policy": "incumbent_r002",
#       "domain_mean_score": 0.5293916666666666,
#       "day_mean_score": 0.6166999999999999,
#       "night_mean_score": 0.44208333333333333,
#       "worst_domain_score": 0.38425,
#       "domain_mean_map50": 0.4263333333333333,
#       "night_mean_map50": 0.35766666666666663,
#       "group_dro_score": 0.46543999999999996
#     },
#     {
#       "policy": "domain_router_oracle",
#       "domain_mean_score": 0.5302,
#       "day_mean_score": 0.6172333333333334,
#       "night_mean_score": 0.44316666666666665,
#       "worst_domain_score": 0.38544999999999996,
#       "domain_mean_map50": 0.42700000000000005,
#       "night_mean_map50": 0.3586666666666667,
#       "group_dro_score": 0.4664366666666667
#     }
#   ]
# }
# CompletedProcess(args=['/opt/venv/bin/python3', '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/scripts/run_09_domain_router_policy.py', '--workspace-root', '/app/Object_Detection/dynamic_quality_aware_classwise_aggregation/moe_dqa_judger/output/09_domain_router_policy', '--min-total-score', '0.5735', '--notify-discord'], returncode=0)

# %%
policy = pd.read_csv(OUT / 'stats' / '09_domain_router_policy.csv')
display(policy[['domain','selected_label','selected_score','incumbent_score','delta_score','selected_map50','delta_map50']])

summary = pd.read_csv(OUT / 'stats' / '09_domain_router_summary.csv')
display(summary)

print((OUT / '09_domain_router_policy_report.md').read_text())
# Out:
#               domain                    selected_label  selected_score  \
# 0     citystreet_day  r004_scaled04_best00_rand008_050         0.63105
# 1   citystreet_night                      r003_rand003         0.46555
# 2        highway_day  r006_scaled04_best01_rand000_050         0.54870
# 3      highway_night  r006_scaled04_best01_rand000_050         0.38545
# 4    residential_day  r006_scaled04_best01_rand000_050         0.67195
# 5  residential_night                   r003_tiny_all_s         0.47850
#
#    incumbent_score  delta_score  selected_map50  delta_map50
# 0          0.63090      0.00015           0.506        0.000
# 1          0.46455      0.00100           0.377        0.001
# 2          0.54765      0.00105           0.442        0.001
# 3          0.38425      0.00120           0.309        0.001
# 4          0.67155      0.00040           0.538        0.000
# 5          0.47745      0.00105           0.390        0.001
#    day_mean_score  domain_mean_map50  domain_mean_score  group_dro_score  \
# 0        0.616700           0.426333           0.529392         0.465440
# 1        0.617233           0.427000           0.530200         0.466437
#
#    night_mean_map50  night_mean_score                policy  \
# 0          0.357667          0.442083        incumbent_r002
# 1          0.358667          0.443167  domain_router_oracle
#
#    worst_domain_score
# 0             0.38425
# 1             0.38545
# # DQA-SoftMoX Domain Router Policy 09
#
# - created_utc: 2026-05-13T15:26:57.005580+00:00
# - min_total_score: 0.5735
#
# ## Policy
#
# | domain | selected | score | incumbent | delta | mAP50 | delta mAP50 |
# |---|---|---:|---:|---:|---:|---:|
# | citystreet_day | r004_scaled04_best00_rand008_050 | 0.6310 | 0.6309 | +0.0001 | 0.506 | +0.000 |
# | citystreet_night | r003_rand003 | 0.4656 | 0.4646 | +0.0010 | 0.377 | +0.001 |
# | highway_day | r006_scaled04_best01_rand000_050 | 0.5487 | 0.5476 | +0.0010 | 0.442 | +0.001 |
# | highway_night | r006_scaled04_best01_rand000_050 | 0.3854 | 0.3842 | +0.0012 | 0.309 | +0.001 |
# | residential_day | r006_scaled04_best01_rand000_050 | 0.6720 | 0.6715 | +0.0004 | 0.538 | +0.000 |
# | residential_night | r003_tiny_all_s | 0.4785 | 0.4774 | +0.0010 | 0.390 | +0.001 |
#
# ## Summary
#
# | policy | mean | day | night | worst | DRO | night mAP50 |
# |---|---:|---:|---:|---:|---:|---:|
# | incumbent_r002 | 0.5294 | 0.6167 | 0.4421 | 0.3842 | 0.4654 | 0.358 |
# | domain_router_oracle | 0.5302 | 0.6172 | 0.4432 | 0.3854 | 0.4664 | 0.359 |
